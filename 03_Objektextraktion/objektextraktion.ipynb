# %% [markdown]
# # Adaption der Objektextraktion
# Hallo! Wir wollen beliebige, selbstgewählte Objektkategorien auf Fotos (mit einfachem Hintergrund) erkennen. Sie brauchen also Fotos. Laden Sie diese auf Google-Drive hoch, oder nutzen Sie vorerst mal die [Giraffen-Puzzleteile](https://drive.google.com/drive/folders/1hXzFL_2Ot5PM3hvQCsgFhFeHV4wtG8E-?usp=drive_link). Die Daten sind auch im [dsci-Sharepoint-Ordner](https://ostch.sharepoint.com/:f:/r/teams/TS-FHS-IPM/Shared%20Documents/lehre%20und%20weiterbildung/21_Winf_MSc/10%20Module/DSCI/HS2024/Praktikum/Daten_Giraffe?csf=1&web=1&e=0OQ5db) abgelegt.
#
# Ziel dieses Notebooks ist es, den Hintergrund der Bilder so gut zu "verstehen", dass das Skript `objekt_extraction.py` anschliessend aus allen Fotos die Objekte extrahieren kann. Auf einem Foto können mehrere Objekte abgebildet sein, wir extrahieren dann aber pro Objekt ein Bild. "verstehen" bedeutet gewisse Parameterwerte zu bestimmen, mit denen die Objektextraktion zuverlässig funktioniert.
#
# Am Ende dieses Notebooks kennen wir diese Parameterwerte, und es wird das Skript `object_extraction.py` mit diesen Parameterwerten ausgeführt. Es extrahiert von allen Ihren Bildern die Ausschnitte (mit Objekten drin), welche wir für die Klassifizierung später brauchen.
#
# Die Objektextraktion im Skript object_extraction.py kann je nach Beleuchtungsverhältnissen etc. unterschiedlich gut klappen und muss allenfalls adaptiert werden. Mit diesem Notebook können die einzelnen Verarbeitungsschritte dieses Skripts detailliert nachvollzogen werden. Die Parameter, deren Werte wir bestimmen müssen, heissen:

# %% [markdown]
# ## Setup und Zugriff zu den Bilddaten

# %%
#Import python File
import object_extraction as oe

#Import Libraries
from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow
from skimage.measure import label
import os
import logging
import re
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import train_test_split
import shutil
from IPython.display import FileLink

# %%
pr = 408,230 #PREPROCESSING_RESOLUTION, --preprocessing_resolution
fr = 0.05  #FRACTION_OF_ROWS_TO_REMOVE, --fraction_of_rows_to_remove
fc = 0.0   #FRACTION_OF_COLS_TO_REMOVE, --fraction_of_cols_to_remove
vth = 0.3    #VALUE_THRESHOLD, --value_threshold
es = 8     #EROSION_SIZE, --erosion_size
ds = 10     #DILATION_SIZE, --dilation_size
mpx = 8000 #MINIMUM NUMBER OF PIXELS, --minimum_number_of_pixels
Bilddateiendung = 'jpg' #Dateiendung der Bilder, ohne ".", Achtung: 'jpg' ist nicht 'JPG'
fv=0 #value_to_fill: Wert, mit dem die abgeschnittenen Ränder aufgefüllt werden sollen

pfad_zu_daten = Path('./Gipfel_dunkel')
# Path('./Gipfel_dunkel')
Ausgabepfad = Path("./Output")

# %% [markdown]
# Laden wir ein Bild!

# %%
def show_image(im):
    imshow(im)
    ax = plt.gca()
    ax.set_xticks([]); ax.set_yticks([]);
    return ax

def choose_an_image():
    """
    Wähle eine Datei aus <pfad_zu_daten> und stelle es dar
    """
    Bilddatei_Liste = pd.Series(pfad_zu_daten.iterdir())
    fn = Bilddatei_Liste.sample(1).values[0]
    im = oe.load_file(fn)
    return im

im = choose_an_image()
show_image(im)
# Out:
# <Axes: >

# %%
from matplotlib.colors import rgb_to_hsv
rgb_to_hsv(im/255.).shape
hsv_im = rgb_to_hsv(im/255.)
channel_medians = np.median(hsv_im, axis=(0,1))
print(channel_medians)
# Out:
# [0.09090909 0.36956522 0.24313725]

# %% [markdown]
# # Adaption der Parameter
# Wir haben Zugriff auf die Bilddaten, nun möchten wir die Parameterwerte auswählen, welche die Objekte gut vom Hintergrund isolieren. Die Funktion `process_file` erledigt das.
#
# Das Vorgehen dabei ist Folgendes:
# 1. Lade das Bild und reduziere die Auflösung: Parameter **`pr`** enthält ein Tupel mit der Anzahl Pixelzeilen und der Anzahl Pixelspalten. Dies dient hauptsächlich der Beschleunigung der weiteren Verarbeitung.
# 2. Schneide jeweils an den Rändern einen Prozentsatz der Zeilen bzw. Spalten ab: Der Prozentsatz der Zeilen ist durch **`fr`**, jener der Spalten durch **`fc`** gegeben.
# 3. Es wird ein Schwellwert auf den value-Wert (in der hsv-Farbdarstellung) angewendet, um den dunklen (`sign`=+1) oder hellen (`sign`=-1) Hintergrund zu erkennen. Dies ergibt eine Maske (binärer Array), welcher Vordergrundpixel identifiziert.
# 4. Es werden kleine Artefakte auf der Maske durch Erosion und Dilatation entfernt. Die Parameter `es` und `ds` geben die Grössen der Erosions- und Dilatationsmasken an.
# 5. Die Objekte werden ausgeschnitten, d.h. separate Objekte werden identifiziert, und um jedes Objekt wird eine enge rechteckige *Bounding Box* gesetzt.
# 6. Sollte der Ausschnitt weniger als **`mpx`** Pixel enthalten, wird er verworfen. Dies ist nötig, weil manchmal Reflexionen o.ä. zusätzliche kleine Ausschnitte erzeugen, welche aber nicht ein Objekt enthalten.
# 7. Ein neues Bild wird abgespeichert, welches nur noch das (ausgeschnittene) Bildelement enthält.
#
#
# Wenn dies gelingt, sind die Bilder in einer geeigneten Form für Deep Learning.
#
# Im Folgenden wird dieser Vorgang für ein (von Ihnen gewähltes) Bild durchgeführt. Passen Sie die Parameter so an, dass die Extraktion gut gelingt.
# Die Parameter sollten Sie hier anpassen:

# %% [markdown]
# ### Schritt 0: Laden des Bildes

# %%
show_image(im);
aufloesung = im.shape
print(f'Das Bild hat folgende angepasste Auflösung: Höhe: {aufloesung[0]}px, Breite: {aufloesung[1]}px, Farbkanäle: {aufloesung[2]}')
# Out:
# Das Bild hat folgende angepasste Auflösung: Höhe: 5712px, Breite: 3213px, Farbkanäle: 3

# %% [markdown]
# ### Schritt 1: Auflösungsreduktion

# %% [markdown]
# Die Bilder können zu hoch aufgelöst sein für unsere Anwendung, wodurch sich die Rechenzeit der folgenden Operationen vervielfacht. Die Vorverarbeitungsroutine `object_extraction.py` beginnt daher damit, mit der `--preprocessing_resolution` (oder `-pr`) das Bild zu verkleinern:

# %%
#im_resized = (255*resize(im,pr)).astype('uint8') #Wird doch schon in load_file gemacht...
im_resized = oe.resize(im,pr)
show_image(im_resized);
angepasste_Aufloesung = im_resized.shape
print(f'Das Bild hat folgende angepasste Auflösung: Höhe: {angepasste_Aufloesung[0]}px, Breite: {angepasste_Aufloesung[1]}px, Farbkanäle: {angepasste_Aufloesung[2]}')
# Out:
# Das Bild hat folgende angepasste Auflösung: Höhe: 408px, Breite: 230px, Farbkanäle: 3

# %% [markdown]
# ## Schritt 2: Ränder abschneiden
# Als nächstes müssen ev. die Ränder des Bildes überdeckt werden. Damit können Artefakte beseitigt werden, z.B. wenn der schwarze Hintergrund nicht bis an den Rand des Bildes reicht. `fraction_of_rows_to_remove` und `fraction_of_cols_to_remove` geben an, wieviel abgeschnitten wird. Aufgefüllt werden die Pixel mit dem Wert `value_to_fill=0` (in allen Farbkanälen).

# %% [markdown]
# 📋 **Aufgabe 1:** Finden Sie für Ihre Bilder passende Werte für `fraction_of_rows_to_remove` und `fraction_of_cols_to_remove`.

# %%
im_filled = oe.fill_borders(im_resized,value_to_fill=fv,fraction_of_rows_to_remove=fr,
                         fraction_of_cols_to_remove=fc)
show_image(im_filled);

# %% [markdown]
# ## Schritt 3: Hintergrundschwellwert bestimmen
# Wählen Sie zunächst sign=+1 für Schwarzen Hintergrund oder sign=-1 für weissen Hintergrund.
#
# Als nächstes soll ein Schwellwert im Farbraum das Objekt vom Hintergrund isolieren. Wir arbeiten im *hsv*-Raum: hue, saturation und value sind die drei Farbdimensionen, für welche jeweils ein Mindestwert (für sign=+1) bzw. Maximalwert (für sign=-1) für Vordergrundpixel festgelegt werden kann. Berechnet wird konkret: `mask = sign*im_hsv[:,:,2]>value_schwellwert*sign` (etc.).

# %% [markdown]
# 📋 **Aufgabe 2:** Finden Sie Werte für `hue_schwellwert`, `saturation_schwellwert` und `value_schwellwert` so, dass die Maske möglichst gut zum Objektumriss passt. Bei der Wahl der Schwellwerte muss man aufpassen, dass sie nicht nur auf diesem einen Bild passen, sondern auch auf allen anderen!

# %%
mask = oe.generate_mask_with_hsv_threshold(im_filled, hue_threshold=None,saturation_threshold=None,value_threshold=vth) #0-255, 0-255, 0-1

plt.figure();show_image(mask);

masked_image = oe.create_masked_image(im_filled,mask)
plt.figure();show_image(masked_image);

# %% [markdown]
# ## Schritt 4: Erosion und Dilatationsfilgergrössen bestimmen

# %% [markdown]
# Wenn Hintergrundregionen übrigbleiben, dann ergibt dies zusätzliche Trainingsbilder, welche nicht einer Klasse zugeordnet sind- und es kostet auch viel Rechenzeit. Kleine, isolierte Maskenpixel möchten wir daher als nächstes durch Erosion entfernen.

# %% [markdown]
# 📋 **Aufgabe 3:** Finden Sie Werte für es und ds, welche möglichst keine vereinzelte Hintergrundpixel in der Maske übrig lassen:

# %%
morphed_mask = oe.morphology_transform(mask,shape = oe.square,erosion_size=es,dilation_size=ds)
show_image(morphed_mask);
# Out:
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))

# %% [markdown]
# Ev. haben Sie auch Glück, und Sie sehen oben nur eine einzige zusammenhängende gelbe Struktur? Dann können Sie die Werte so lassen, wie sie sind!

# %% [markdown]
# `create_mask` ist nun einfach eine Routine, welche die obigen Schritte der Maskenbildung zusammenfasst. Sie sollte das gleiche Bild `morphed_mask` wie oben erstellen:

# %%
morphed_mask,im_filled  = oe.create_mask(im_resized,
                                      fraction_of_rows_to_remove=fr,fraction_of_cols_to_remove=fc,
                                      hue_threshold=None,saturation_threshold=None,value_threshold=vth,
                                      erosion_size=es,dilation_size=ds)
show_image(morphed_mask);

# %% [markdown]
# Nun wird die Maske benutzt, um das Objekt (oder die Objekte) aus dem Bild auszuschneiden:

# %%
masked_image = oe.create_masked_image(im_filled,morphed_mask)
show_image(masked_image);
#masked_image.shape

# %% [markdown]
# Hier sollte ein Bild zu sehen sein, welches einen komplett schwarzen Hintergrund hat, und nur die relevanten Objekte zeigt. Als nächstes hätten wir gerne von jedem Objekt ein separates Bild, so dass wir darauf unseren Bildklassifikator trainieren können.

# %% [markdown]
# ## Schritt 5: Objekte ausschneiden
# Wir haben den Hintergrund eliminiert. Damit ist es nun leichter, die Objekte voneinander zu trennen. Die Funktion "label" von [scikit-image](https://scikit-image.org/docs/stable/api/skimage.measure.html#skimage.measure.label) tut dies:

# %%
label_img = label(morphed_mask)
show_image(label_img)
plt.colorbar();

# %% [markdown]
# Falls das obige Bild wie eine Maske aussieht: Vermutlich liegt nur ein Bild vor- deren Pixel wird dann mit dem Wert "1" aufgefüllt. Wäre ein zweites Objekt vorhanden, würde dieses mit dem Wert "2" aufgefüllt und wäre in einer leicht anderen Farbe sichtbar. Aus diesem gelabelten Bild werden nun Teilbilder extrahiert, welche jeweils nur ein Objekt enthalten:

# %%
label_img.shape,masked_image.shape
# Out:
# ((408, 230), (408, 230, 3))

# %%
regionlist,regions = oe.extract_regions(label_img,masked_image,fraction_of_rows_to_remove=fr)
regionen = len(regionlist)
print(f"Das Bild hat {regionen} Regionen.")
# Out:
# Das Bild hat 1 Regionen.

# %% [markdown]
# Alle obigen Schritte sind in der Funktion image_preprocessing zusammengefasst:

# %%
regionlist,regions,mask,masked_image = oe.image_preprocessing(im,
                                                           fraction_of_rows_to_remove=fr,
                                                           fraction_of_cols_to_remove=fc,
                                                           value_threshold=vth,
                                                           erosion_size=es,dilation_size=ds)
print(f"Anzahl gefundene Bereiche: {len(regionlist)}")
# Out:
# Anzahl gefundene Bereiche: 64

# %%
label_img.shape,masked_image.shape,len(regions)
# Out:
# ((408, 230), (5712, 3213, 3), 64)

# %%
show_image(masked_image)
# Out:
# <Axes: >

# %% [markdown]
# ## Schritt 6: Kleine Objekte (Artefakte) ignorieren
# Manchmal sind einige der gefundenen Regionen viel zu klein, um echte Objekte zu sein. Es gibt eine Option `--minimum-number-of-pixels` bzw. `-mpx`, welche Regionen unterdrückt, welche zu klein sind. Die Grösse der Regionen wird hier ausgegeben, um diesen Parameter gut einstellen zu können.

# %%
if len(regions)<10:
    for ireg,reg in enumerate(regions):
        print(f"Region {ireg}: {int(reg.area):>6}")
else:
    #for ireg,reg in enumerate(regions):
    #    print(f"{int(reg.area):<3} ",end='')

    plt.hist([reg.area for reg in regions],bins=np.logspace(1,6,100))
    plt.gca().set_xscale('log') #ev. sieht man damit etwas mehr
    plt.gca().set_yscale('log')

# %% [markdown]
# Schauen wir uns die extrahierten Regionen an - es sollten nicht zu viele sein.

# %% [markdown]
# 📋 **Aufgabe 4:** Bestimmen Sie einen geeigneten Wert von `mpx`, so dass nur relevante Regionen übrig bleiben. Tragen Sie den Wert in die Parameterliste ein.
#
# Der `mpx`-Wert wird in der nächsten Zelle verwendet:

# %%
relevante_regionen =  [reg for reg in regions if reg.area >= mpx]
if len(relevante_regionen)<20:
    for reg in relevante_regionen:
        plt.figure();
        plt.imshow(reg.image_intensity);
        plt.xticks([]);plt.yticks([]) # Wir brauchen keine x- und y-Achse
else:
    print(f"Das würde {len(relevante_regionen)} Graphiken erzeugen! Ich mache lieber nichts...")

# %% [markdown]
# Sehen Sie hier Ihre extrahierten Objekte, und keine (oder nur wenige) Artefakte?
# Ja?
# Wirklich?
# **Cool!**
# Dann können wir nun versuchen, alle weiteren Daten zu verarbeiten. Das kann  in der Kommandozeile wie folgt erreicht werden:

# %%
imgfns = list(Path('./Gipfel_dunkel').glob('*.'+Bilddateiendung))
#path('./Gipfel_dunkel')
imgfns[:5]
# Out:
# [PosixPath('Gipfel_dunkel/Laugengipfel_low_light_34.jpg'),
#  PosixPath('Gipfel_dunkel/Laugengipfel_low_light_20.jpg'),
#  PosixPath('Gipfel_dunkel/Laugengipfel_low_light_21.jpg'),
#  PosixPath('Gipfel_dunkel/Laugengipfel_low_light_35.jpg'),
#  PosixPath('Gipfel_dunkel/Laugengipfel_low_light_09.jpg')]

# %%
yta = True #args.yes_to_all
outputpath = Ausgabepfad
outputpath_Ausschnitte = os.path.join(outputpath, 'Ausschnitte')
oe.ask_path_creation(outputpath_Ausschnitte,yes_to_all=yta)

fraction_of_rows_to_remove = float(fr)
fraction_of_cols_to_remove = float(fc)
preprocessing_resolution = [int(f) for f in pr]
# print('preprocessing_resolution ',preprocessing_resolution )
erosion_size= oe.intOrNone(es)
dilation_size= oe.intOrNone(ds)
hue_threshold = None#intOrNone(hth)
value_threshold = vth#None#intOrNone(vth)
saturation_threshold = None #intOrNone(sth)
write_summary_file = False
num_cores = 1 #int(args.num_cores)
minimum_number_of_pixels = int(mpx)

kwargs = {'fraction_of_rows_to_remove':fr,'fraction_of_cols_to_remove':fc,'hue_threshold':hue_threshold,'saturation_threshold':saturation_threshold,'value_threshold':vth,
        'erosion_size':erosion_size,'dilation_size':dilation_size,'min_num_pixels':minimum_number_of_pixels,'outputpath':outputpath_Ausschnitte,'preprocessing_resolution':preprocessing_resolution}
# Out:
# INFO:object_extraction:Der Pfad Output/Ausschnitte konnte nicht gefunden werden.
# INFO:object_extraction:Pfad Output/Ausschnitte wurde erstellt

# %%
NrFilesToProcess = None # None eingeben für alle
kwargs['num_cores']=1
logger = logging.getLogger(__name__)
logger.setLevel(logging.INFO)
oe.main(imgfns[:NrFilesToProcess],kwargs)
# Out:
# Processing images:   0%|          | 0/92 [00:00<?, ?it/s]INFO:object_extraction:Shapes of extracted regions: [(270, 10, 3), (140, 122, 3)]
# INFO:object_extraction:skipping region: num_pix=2474,shape:(270, 10, 3),area:2474.0, as num_pix is < 8000
# Processing images:   1%|          | 1/92 [00:03<04:56,  3.26s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(238, 184, 3), (12, 10, 3)]
# INFO:object_extraction:skipping region: num_pix=116,shape:(12, 10, 3),area:116.0, as num_pix is < 8000
# Processing images:   2%|▏         | 2/92 [00:05<03:42,  2.47s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(179, 169, 3)]
# Processing images:   3%|▎         | 3/92 [00:07<03:15,  2.19s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(245, 10, 3), (144, 125, 3)]
# INFO:object_extraction:skipping region: num_pix=2115,shape:(245, 10, 3),area:2115.0, as num_pix is < 8000
# Processing images:   4%|▍         | 4/92 [00:08<03:01,  2.07s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(184, 161, 3)]
# Processing images:   5%|▌         | 5/92 [00:10<02:54,  2.00s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(143, 111, 3), (16, 7, 3), (10, 6, 3)]
# INFO:object_extraction:skipping region: num_pix=107,shape:(16, 7, 3),area:107.0, as num_pix is < 8000
# INFO:object_extraction:skipping region: num_pix=60,shape:(10, 6, 3),area:60.0, as num_pix is < 8000
# Processing images:   7%|▋         | 6/92 [00:12<02:48,  1.96s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(204, 136, 3)]
# Processing images:   8%|▊         | 7/92 [00:14<02:44,  1.94s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(235, 10, 3), (148, 127, 3)]
# INFO:object_extraction:skipping region: num_pix=1992,shape:(235, 10, 3),area:1992.0, as num_pix is < 8000
# Processing images:   9%|▊         | 8/92 [00:16<02:40,  1.92s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(241, 10, 3), (146, 126, 3)]
# INFO:object_extraction:skipping region: num_pix=2023,shape:(241, 10, 3),area:2023.0, as num_pix is < 8000
# Processing images:  10%|▉         | 9/92 [00:18<02:37,  1.89s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(203, 163, 3)]
# Processing images:  11%|█         | 10/92 [00:20<02:35,  1.89s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(243, 132, 3), (75, 7, 3), (53, 6, 3)]
# INFO:object_extraction:skipping region: num_pix=501,shape:(75, 7, 3),area:501.0, as num_pix is < 8000
# INFO:object_extraction:skipping region: num_pix=318,shape:(53, 6, 3),area:318.0, as num_pix is < 8000
# Processing images:  12%|█▏        | 11/92 [00:22<02:32,  1.88s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(198, 152, 3)]
# Processing images:  13%|█▎        | 12/92 [00:23<02:30,  1.88s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(228, 163, 3), (13, 6, 3), (51, 7, 3)]
# INFO:object_extraction:skipping region: num_pix=78,shape:(13, 6, 3),area:78.0, as num_pix is < 8000
# INFO:object_extraction:skipping region: num_pix=330,shape:(51, 7, 3),area:330.0, as num_pix is < 8000
# Processing images:  14%|█▍        | 13/92 [00:26<02:36,  1.98s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(203, 163, 3)]
# Processing images:  15%|█▌        | 14/92 [00:28<02:32,  1.95s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(187, 184, 3)]
# Processing images:  16%|█▋        | 15/92 [00:29<02:29,  1.94s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(229, 163, 3), (45, 7, 3)]
# INFO:object_extraction:skipping region: num_pix=282,shape:(45, 7, 3),area:282.0, as num_pix is < 8000
# Processing images:  17%|█▋        | 16/92 [00:31<02:27,  1.94s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(135, 133, 3)]
# Processing images:  18%|█▊        | 17/92 [00:34<02:35,  2.07s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(159, 111, 3)]
# Processing images:  20%|█▉        | 18/92 [00:36<02:31,  2.05s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(189, 133, 3)]
# Processing images:  21%|██        | 19/92 [00:38<02:25,  1.99s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(212, 89, 3)]
# Processing images:  22%|██▏       | 20/92 [00:40<02:21,  1.97s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(88, 200, 3)]
# Processing images:  23%|██▎       | 21/92 [00:41<02:18,  1.95s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(176, 111, 3)]
# Processing images:  24%|██▍       | 22/92 [00:43<02:15,  1.93s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(147, 143, 3), (170, 27, 3)]
# INFO:object_extraction:skipping region: num_pix=1928,shape:(170, 27, 3),area:1928.0, as num_pix is < 8000
# Processing images:  25%|██▌       | 23/92 [00:45<02:12,  1.91s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(155, 117, 3)]
# Processing images:  26%|██▌       | 24/92 [00:47<02:09,  1.91s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(169, 89, 3), (28, 21, 3)]
# INFO:object_extraction:skipping region: num_pix=439,shape:(28, 21, 3),area:439.0, as num_pix is < 8000
# Processing images:  27%|██▋       | 25/92 [00:49<02:06,  1.89s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(258, 10, 3), (167, 118, 3), (10, 14, 3), (19, 13, 3)]
# INFO:object_extraction:skipping region: num_pix=2308,shape:(258, 10, 3),area:2308.0, as num_pix is < 8000
# INFO:object_extraction:skipping region: num_pix=140,shape:(10, 14, 3),area:140.0, as num_pix is < 8000
# INFO:object_extraction:skipping region: num_pix=237,shape:(19, 13, 3),area:237.0, as num_pix is < 8000
# Processing images:  28%|██▊       | 26/92 [00:51<02:04,  1.88s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(208, 100, 3)]
# Processing images:  29%|██▉       | 27/92 [00:53<02:02,  1.88s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(152, 152, 3)]
# Processing images:  30%|███       | 28/92 [00:55<02:00,  1.88s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(204, 9, 3), (155, 131, 3)]
# INFO:object_extraction:skipping region: num_pix=1620,shape:(204, 9, 3),area:1620.0, as num_pix is < 8000
# Processing images:  32%|███▏      | 29/92 [00:56<01:58,  1.88s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(200, 9, 3), (155, 131, 3)]
# INFO:object_extraction:skipping region: num_pix=1525,shape:(200, 9, 3),area:1525.0, as num_pix is < 8000
# Processing images:  33%|███▎      | 30/92 [00:58<01:56,  1.87s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(88, 200, 3), (14, 10, 3), (13, 13, 3), (11, 9, 3), (28, 12, 3)]
# INFO:object_extraction:skipping region: num_pix=140,shape:(14, 10, 3),area:140.0, as num_pix is < 8000
# INFO:object_extraction:skipping region: num_pix=166,shape:(13, 13, 3),area:166.0, as num_pix is < 8000
# INFO:object_extraction:skipping region: num_pix=99,shape:(11, 9, 3),area:99.0, as num_pix is < 8000
# INFO:object_extraction:skipping region: num_pix=258,shape:(28, 12, 3),area:258.0, as num_pix is < 8000
# Processing images:  34%|███▎      | 31/92 [01:00<01:54,  1.88s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(175, 110, 3)]
# Processing images:  35%|███▍      | 32/92 [01:02<01:52,  1.87s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(175, 118, 3)]
# Processing images:  36%|███▌      | 33/92 [01:04<01:50,  1.88s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(136, 134, 3), (27, 21, 3)]
# INFO:object_extraction:skipping region: num_pix=424,shape:(27, 21, 3),area:424.0, as num_pix is < 8000
# Processing images:  37%|███▋      | 34/92 [01:06<01:48,  1.87s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(145, 162, 3)]
# Processing images:  38%|███▊      | 35/92 [01:08<01:46,  1.87s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(172, 144, 3), (14, 17, 3)]
# INFO:object_extraction:skipping region: num_pix=221,shape:(14, 17, 3),area:221.0, as num_pix is < 8000
# Processing images:  39%|███▉      | 36/92 [01:10<01:45,  1.88s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(190, 96, 3)]
# Processing images:  40%|████      | 37/92 [01:11<01:43,  1.87s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(152, 174, 3), (71, 39, 3), (29, 15, 3)]
# INFO:object_extraction:skipping region: num_pix=1855,shape:(71, 39, 3),area:1855.0, as num_pix is < 8000
# INFO:object_extraction:skipping region: num_pix=333,shape:(29, 15, 3),area:333.0, as num_pix is < 8000
# Processing images:  41%|████▏     | 38/92 [01:13<01:41,  1.87s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(156, 145, 3)]
# Processing images:  42%|████▏     | 39/92 [01:15<01:40,  1.89s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(208, 7, 3), (189, 109, 3)]
# INFO:object_extraction:skipping region: num_pix=1337,shape:(208, 7, 3),area:1337.0, as num_pix is < 8000
# Processing images:  43%|████▎     | 40/92 [01:17<01:37,  1.88s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(130, 125, 3)]
# Processing images:  45%|████▍     | 41/92 [01:19<01:36,  1.89s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(112, 141, 3)]
# Processing images:  46%|████▌     | 42/92 [01:21<01:34,  1.90s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(142, 7, 3), (124, 173, 3), (12, 6, 3)]
# INFO:object_extraction:skipping region: num_pix=920,shape:(142, 7, 3),area:920.0, as num_pix is < 8000
# INFO:object_extraction:skipping region: num_pix=72,shape:(12, 6, 3),area:72.0, as num_pix is < 8000
# Processing images:  47%|████▋     | 43/92 [01:23<01:39,  2.04s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(190, 96, 3)]
# Processing images:  48%|████▊     | 44/92 [01:25<01:40,  2.10s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(93, 206, 3)]
# Processing images:  49%|████▉     | 45/92 [01:27<01:36,  2.06s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(152, 152, 3)]
# Processing images:  50%|█████     | 46/92 [01:29<01:33,  2.03s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(152, 83, 3)]
# Processing images:  51%|█████     | 47/92 [01:31<01:30,  2.01s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(169, 89, 3), (28, 21, 3)]
# INFO:object_extraction:skipping region: num_pix=439,shape:(28, 21, 3),area:439.0, as num_pix is < 8000
# Processing images:  52%|█████▏    | 48/92 [01:33<01:27,  1.98s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(102, 154, 3)]
# Processing images:  53%|█████▎    | 49/92 [01:35<01:24,  1.96s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(170, 81, 3)]
# Processing images:  54%|█████▍    | 50/92 [01:37<01:22,  1.95s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(192, 184, 3), (22, 14, 3), (10, 10, 3), (12, 12, 3), (31, 29, 3)]
# INFO:object_extraction:skipping region: num_pix=256,shape:(22, 14, 3),area:256.0, as num_pix is < 8000
# INFO:object_extraction:skipping region: num_pix=100,shape:(10, 10, 3),area:100.0, as num_pix is < 8000
# INFO:object_extraction:skipping region: num_pix=143,shape:(12, 12, 3),area:143.0, as num_pix is < 8000
# INFO:object_extraction:skipping region: num_pix=624,shape:(31, 29, 3),area:624.0, as num_pix is < 8000
# Processing images:  55%|█████▌    | 51/92 [01:39<01:20,  1.96s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(10, 6, 3), (107, 9, 3), (112, 141, 3), (13, 7, 3), (38, 7, 3)]
# INFO:object_extraction:skipping region: num_pix=60,shape:(10, 6, 3),area:60.0, as num_pix is < 8000
# INFO:object_extraction:skipping region: num_pix=853,shape:(107, 9, 3),area:853.0, as num_pix is < 8000
# INFO:object_extraction:skipping region: num_pix=89,shape:(13, 7, 3),area:89.0, as num_pix is < 8000
# INFO:object_extraction:skipping region: num_pix=250,shape:(38, 7, 3),area:250.0, as num_pix is < 8000
# Processing images:  57%|█████▋    | 52/92 [01:41<01:17,  1.94s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(156, 145, 3)]
# Processing images:  58%|█████▊    | 53/92 [01:43<01:15,  1.93s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(162, 77, 3)]
# Processing images:  59%|█████▊    | 54/92 [01:45<01:12,  1.92s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(23, 11, 3), (231, 10, 3), (166, 103, 3), (32, 8, 3)]
# INFO:object_extraction:skipping region: num_pix=216,shape:(23, 11, 3),area:216.0, as num_pix is < 8000
# INFO:object_extraction:skipping region: num_pix=1961,shape:(231, 10, 3),area:1961.0, as num_pix is < 8000
# INFO:object_extraction:skipping region: num_pix=226,shape:(32, 8, 3),area:226.0, as num_pix is < 8000
# Processing images:  60%|█████▉    | 55/92 [01:47<01:11,  1.92s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(198, 102, 3), (13, 13, 3)]
# INFO:object_extraction:skipping region: num_pix=166,shape:(13, 13, 3),area:166.0, as num_pix is < 8000
# Processing images:  61%|██████    | 56/92 [01:49<01:09,  1.93s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(174, 148, 3)]
# Processing images:  62%|██████▏   | 57/92 [01:51<01:07,  1.92s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(93, 205, 3)]
# Processing images:  63%|██████▎   | 58/92 [01:52<01:04,  1.90s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(215, 65, 3)]
# Processing images:  64%|██████▍   | 59/92 [01:54<01:02,  1.89s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(160, 91, 3)]
# Processing images:  65%|██████▌   | 60/92 [01:56<01:00,  1.88s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(96, 171, 3)]
# Processing images:  66%|██████▋   | 61/92 [01:58<00:58,  1.89s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(134, 133, 3)]
# ...
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(201, 103, 3), (14, 15, 3)]
# INFO:object_extraction:skipping region: num_pix=200,shape:(14, 15, 3),area:200.0, as num_pix is < 8000
# Processing images:  78%|███████▊  | 72/92 [02:19<00:37,  1.90s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(141, 101, 3)]
# Processing images:  79%|███████▉  | 73/92 [02:21<00:36,  1.91s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(147, 119, 3)]
# Processing images:  80%|████████  | 74/92 [02:23<00:34,  1.90s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(117, 149, 3)]
# Processing images:  82%|████████▏ | 75/92 [02:25<00:32,  1.90s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(367, 225, 3), (148, 9, 3), (12, 7, 3)]
# INFO:object_extraction:skipping region: num_pix=1014,shape:(148, 9, 3),area:1014.0, as num_pix is < 8000
# INFO:object_extraction:skipping region: num_pix=84,shape:(12, 7, 3),area:84.0, as num_pix is < 8000
# Processing images:  83%|████████▎ | 76/92 [02:26<00:25,  1.57s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(160, 139, 3), (25, 6, 3), (14, 6, 3)]
# INFO:object_extraction:skipping region: num_pix=150,shape:(25, 6, 3),area:150.0, as num_pix is < 8000
# INFO:object_extraction:skipping region: num_pix=84,shape:(14, 6, 3),area:84.0, as num_pix is < 8000
# Processing images:  84%|████████▎ | 77/92 [02:28<00:24,  1.67s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(181, 163, 3)]
# Processing images:  85%|████████▍ | 78/92 [02:29<00:24,  1.74s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(198, 151, 3)]
# Processing images:  86%|████████▌ | 79/92 [02:31<00:23,  1.78s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(199, 135, 3)]
# Processing images:  87%|████████▋ | 80/92 [02:33<00:21,  1.82s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(191, 152, 3), (33, 28, 3)]
# INFO:object_extraction:skipping region: num_pix=695,shape:(33, 28, 3),area:695.0, as num_pix is < 8000
# Processing images:  88%|████████▊ | 81/92 [02:35<00:20,  1.84s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(177, 224, 3), (14, 16, 3), (10, 7, 3)]
# INFO:object_extraction:skipping region: num_pix=202,shape:(14, 16, 3),area:202.0, as num_pix is < 8000
# INFO:object_extraction:skipping region: num_pix=70,shape:(10, 7, 3),area:70.0, as num_pix is < 8000
# Processing images:  89%|████████▉ | 82/92 [02:37<00:18,  1.86s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(199, 148, 3)]
# Processing images:  90%|█████████ | 83/92 [02:39<00:16,  1.88s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(181, 163, 3)]
# Processing images:  91%|█████████▏| 84/92 [02:41<00:15,  1.89s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(159, 139, 3), (12, 6, 3)]
# INFO:object_extraction:skipping region: num_pix=72,shape:(12, 6, 3),area:72.0, as num_pix is < 8000
# Processing images:  92%|█████████▏| 85/92 [02:43<00:13,  1.90s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(158, 142, 3)]
# Processing images:  93%|█████████▎| 86/92 [02:45<00:11,  1.92s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(195, 150, 3)]
# Processing images:  95%|█████████▍| 87/92 [02:47<00:09,  1.92s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(170, 167, 3)]
# Processing images:  96%|█████████▌| 88/92 [02:49<00:07,  1.92s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(283, 10, 3), (167, 118, 3), (34, 33, 3), (11, 18, 3), (19, 13, 3)]
# INFO:object_extraction:skipping region: num_pix=2536,shape:(283, 10, 3),area:2536.0, as num_pix is < 8000
# INFO:object_extraction:skipping region: num_pix=584,shape:(34, 33, 3),area:584.0, as num_pix is < 8000
# INFO:object_extraction:skipping region: num_pix=189,shape:(11, 18, 3),area:189.0, as num_pix is < 8000
# INFO:object_extraction:skipping region: num_pix=236,shape:(19, 13, 3),area:236.0, as num_pix is < 8000
# Processing images:  97%|█████████▋| 89/92 [02:51<00:05,  1.93s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(200, 9, 3), (128, 167, 3)]
# INFO:object_extraction:skipping region: num_pix=1592,shape:(200, 9, 3),area:1592.0, as num_pix is < 8000
# Processing images:  98%|█████████▊| 90/92 [02:52<00:03,  1.93s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(192, 9, 3), (127, 167, 3)]
# INFO:object_extraction:skipping region: num_pix=1475,shape:(192, 9, 3),area:1475.0, as num_pix is < 8000
# Processing images:  99%|█████████▉| 91/92 [02:54<00:01,  1.92s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(214, 131, 3)]
# Processing images: 100%|██████████| 92/92 [02:56<00:00,  1.92s/it]
# INFO:object_extraction:Die Bildausschnitte wurden hierher kopiert: Output/Ausschnitte

# %% [markdown]
# Alternativ kann die Ausgabe der folgenden Zelle genutzt werden, um in der Kommandozeile das Skript [object_extraction.py](https://gitlab.ost.ch/beat.toedtli/learning-city-lab/-/blob/main/1_object_extraction/object_extraction.py?ref_type=heads)[im Verzeichnis [1_object_extraction](https://gitlab.ost.ch/beat.toedtli/learning-city-lab/-/tree/main/1_object_extraction?ref_type=heads) auszuführen.

# %%
##cmd = f"python3 '{pfad_zu_object_extraction}/object_extraction.py' \
#-y -o '{Ausgabepfad}' -pr {pr[0]},{pr[1]} -fr {fr} -fc {fc} -es {es} -ds {ds} \
#-vth {vth} -mpx {mpx} f'{pfad_zu_daten_string}/*.{Bilddateiendung}'"
#print("Der Kommandozeilenbefehl lautet:\n",cmd)

# %%
# #Die Ausschnitte sind nun hier:
# print(Ausgabepfad/'Ausschnitte')
# # hier einige Beispiele:
# !ls {'"'+str(Ausgabepfad/'Ausschnitte')+'"'}|head -n 5

# %% [markdown]
# Wir können uns die Ausschnitte anschauen:

# %%
# fn = Ausgabepfad/'Ausschnitte'/'Buttergipfel_light_0_06.jpg'
# if fn.exists():
#     im = plt.imread(fn)
#     show_image(im);

# %% [markdown]
# Bevor wir die Bilder herunterladen, wollen wir sie in Unterordner pro Klasse anordnen.

# %% [markdown]
# # Bilden von Unterordner pro Klasse
# Keras, unsere Deep Learning Bibliothek, hat eine einfache Routine, um Kategorisierte Bilder zu laden: Dazu müssen alle Bilder einer Klasse in einem Unterordner liegen, welcher als Namen die Klassenbezeichnung trägt. Diese Zuordnung kann natürlich von Hand vorgenommen werden. Im Fall des Giraffendatensatzes ist das Klassenlabel aber bereits im Dateinamen der Bilder codiert.

# %% [markdown]
# #### Reguläre Ausdrücke

# %%
# re.sub(r'^([^_]+).*$', r'\1', "Laugengipfel_low_light_0_10.jpg")

# %% [markdown]
# Der reguläre Ausdruck `^([^-]*)-.*$` hat's durchaus in sich, ist aber verständlicher, wenn man folgendes weiss:
# - `^` bezeichnet den Beginn einer Zeichenkette
# - `$` bezeichnet das Ende einer Zeichenkette
# - `.` bezeichnet ein beliebiges Zeichen
# - `*` meint "Null-mal, einmal oder beliebig oft". Gemeint ist hier das Zeichen davor ("."), als "kein oder beliebig viele beliebige Zeichen".
# - `( )` Die Klammern gehören zusammen und bilden eine Gruppe: alle Zeichen dazwischen werden in einer Variablen abgespeichert, welche "\1" heisst. Dies sind die einzigen Zeichen, welche nach der Substitution die verbleibende Zeichenkette ausmachen: Im zweiten Argument von `re.sub` steht, womit ein "gematchtes Muster" (engl. matched pattern) im String ersetzt wird.
# - In eckigen Klammern, `[]`, können Zeichen aufgezählt werden, die auftauchen dürfen. Innerhalb von eckigen Klammern bedeutet `^` *nicht* den Beginn des Strings, sondern eine Negation. Der Ausdruck `[^-]` bezeichnet daher ein beliebiges Zeichen, welches aber nicht das Minuszeichen sein darf.
#
# Insgesamt sagt der Ausdruck `'^([^-]*)-.*$'` also so etwas wie:
# *Eine Zeichenkette matcht, wenn sie mit einer beliebigen Folge von Zeichen beginnt, welche nicht das Zeichen "-" ist, gefolgt von einem Minuszeichen. Diese Zeichen vor dem Minus bilden die Gruppe 1. Nach dieser Gruppe muss also ein "-" folgen, und danach dürfen noch beliebig viele beliebige Zeichen folgen bis zum Ende der Zeichenkette. Ersetze diese ganze Zeichenkette (von Anfang bis Ende) mit der Gruppe.*
#
# In einfacherer Sprache ausgedrückt wird die Zeichenkette vor dem Minuszeichen extrahiert- sie enthält ja den Klassennamen.

# %% [markdown]
# #### Pandas DataFrames
# Pandas DataFrames sind sehr nützliche tabellenartige Strukturen. Sie eignen sich v.a. für die Datenanalyse und Visualisierung von strukturierten Daten. Im Folgenden werden diese genutzt, um das Klassenlabel zu bestimmen, welches für die Erstellung der Baumstruktur nützlich ist.

# %%
#volle_Dateinamen = [full_file_name for full_file_name in (Ausgabepfad/'Ausschnitte').glob('*.'+Bilddateiendung)]
#Basisnamen =  [full_file_name for full_file_name in (Ausgabepfad/'Ausschnitte').glob('*.'+Bilddateiendung)]

#Klassenlabel = [re.sub(r'^([^_]+).*$', r'\1', bn.name) for bn in Basisnamen] #Wende den regulären Ausdruck an
#df = pd.DataFrame({'Dateiname':volle_Dateinamen,'Basisname':Basisnamen,'Klassenlabel':Klassenlabel})
#df


#Erzeuge trrain und testset aus allen Bildern und nicht nur aus Ausschnitten
# pfad_zu_bilder = Path('../02_Alle_Gipfel')

# volle_Dateinamen = [full_file_name for full_file_name in (pfad_zu_bilder).glob('*.'+Bilddateiendung)]
# Basisnamen =  [full_file_name for full_file_name in (pfad_zu_bilder).glob('*.'+Bilddateiendung)]

# Klassenlabel = [re.sub(r'^([^_]+).*$', r'\1', bn.name) for bn in Basisnamen] #Wende den regulären Ausdruck an
# df = pd.DataFrame({'Dateiname':volle_Dateinamen,'Basisname':Basisnamen,'Klassenlabel':Klassenlabel})
# df

# %% [markdown]
# #### Train-Test-Split
# An dieser Stelle lohnt es sich, kurz innezuhalten: Unsere grandiose Strategie ist es, aus Bildern Objekte zu extrahieren und auf diesen dann ein Modell zu trainieren. Aber wir können nicht alle Daten als Trainingsdaten verwenden, sonst haben wir nichts mehr, um die *Generalisierungsfähigkeit* unseres Modells zu messen!
# Die Realität ist, dass wir nur ungern später nochmals neue Daten aufnehmen wollen. Die Liste in `df` oben ist alles, was uns zur Verfügung steht. Es macht daher Sinn, bereits jetzt einen Teil dieser Daten zurückzulegen und zu *schwören* diese Daten nicht für das Training zu benutzen. Wir brauchen ca. 20% *frische* Daten, an denen wir die Verallgemeinerungsfähigkeit unseres Modells überprüfen können.
# [Scikit-Learn](https://scikit-learn.org) bietet uns [hier](https://scikit-learn.org/stable/auto_examples/model_selection/plot_cv_indices.html#sphx-glr-auto-examples-model-selection-plot-cv-indices-py) verschiedene Strategien an, wie wir aus unseren Trainingsdaten einen Testdatensatz absondern können. Wir könnten einfach [zufällig splitten](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.ShuffleSplit.html#sklearn.model_selection.ShuffleSplit). Das ist naiv. Lieber eine [k-fache Kreuzvalidierung](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.KFold.html#sklearn.model_selection.KFold). Aber was, wenn zufälligerweise eine Klasse nur im Testdatensatz auftaucht, und gar nicht im Trainingsdatensatz?! Also [stratifizieren](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.StratifiedKFold.html#sklearn.model_selection.StratifiedKFold) wir. Ok- und was ist, wenn wir überprüfen wollen, dass wir in Bezug auf eine bestimmte Untergruppierung (z.B. nach Geschlecht, Ethnie,...) gut von einer Gruppe auf eine andere verallgemeinern können müssen? Dann darf eine [Gruppe nur in einem Fold vorkommen](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.StratifiedGroupKFold.html#sklearn.model_selection.StratifiedGroupKFold). Sie sehen- richtig zu splitten kann herausfordernd sein!
# Hier jedenfalls möchten wir zumindest stratifizieren. Wir nehmen mal [StratifiedKFold](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.StratifiedKFold.html#sklearn.model_selection.StratifiedKFold), um unsere Daten zu splitten.

# %%
# Xtrain,Xtest,ytrain,ytest = train_test_split(df[['Dateiname','Basisname']],df.Klassenlabel,test_size=0.2,train_size=0.8,stratify =df.Klassenlabel,random_state=42)
# # Das Fixieren des random_state bedeutet, dass immer der gleiche Split gemacht wird. Dadurch wird verhindert, dass durch mehrfaches durchlaufen immer mal wieder andere Daten für das Training
# # benutzt werden. Denn dadurch würde man sich letztlich beim Training alle Daten anschauen, auch die Testdaten. Subtiler Punkt- aber m.E. good practice!
# #Die Grössen der Arrays:
# print(Xtrain.shape,Xtest.shape,ytrain.shape,ytest.shape)
# print("Trainingsdaten")
# display(ytrain.value_counts())
# print("\nTestdaten")
# display(ytest.value_counts())
# print('\nKlassenverhältnis:')
# #Von den Trainingsdaten gibt es in jeder Klasse etwa gleichviel mehr als in den Testdaten:
# ytest.value_counts()/ytrain.value_counts()

# %% [markdown]
# Die Ausgaben oben zeigen die Anzahl Beispiele pro Klasse in den Training- und Testdaten sowie das Verhältnis pro Klasse. Das Verhältnis sollte für alle Klassen etwa gleich gross sein- dies nennt sich *stratifiziertes Training-Test-Splitten*.

# %%
# display(Xtrain.head())
# ytrain

# %% [markdown]
# #### Shutil - High-level File Operations
# Wir kopieren nun die Daten in Unterordner von `pfad_zu_lcl_colab/2_Baumstruktur/`. Die Unterordner sollen die Klassennamen (Farben) sein.

# %%
# #Kopiere die Trainigsdaten
# for Basisname,voller_Dateiname, label in zip(Xtrain.Basisname,Xtrain.Dateiname, ytrain):
#     src = voller_Dateiname
#     #dst = Path('/tmp','2_Baumstruktur',label)
#     dst_train = Ausgabepfad/'Baumstruktur_train'/label

#     dst_train.mkdir(exist_ok=True,parents=True)
#     shutil.copy(src,dst_train/Basisname.name)
# print(f"Trainingsdateien wurden nach {str(dst_train.parent)} kopiert.")
# #Kopiere die Testdaten
# for Basisname,voller_Dateiname, label in zip(Xtest.Basisname,Xtest.Dateiname, ytest):
#     src = voller_Dateiname

#     dst_test = Ausgabepfad/'Baumstruktur_test'/label

#     dst_test.mkdir(exist_ok=True,parents=True)
#     shutil.copy(src,dst_test/Basisname.name)
# print(f"Testdateien wurden nach {str(dst_test.parent)} kopiert.")

# %% [markdown]
# Überprüfen wir die Struktur! Die Klassenverzeichnisse sind hier:

# %%
# !echo "Training-Baumstruktur:"
# !ls "{dst_train.parent}"
# !echo "Test-Baumstruktur:"
# !ls "{dst_test.parent}"

# %% [markdown]
# Und darunter befinden sich die zur Klasse zugehörigen Bilder:

# %%
# !ls "{dst_test.parent}"/*

# %% [markdown]
# Nun wollen wir diese zwei Baumstrukturen herunterladen:

# %%
# ! echo "-Trainingdaten-"
# ! zip -r training_Baumstruktur.zip {dst_train.parent}/*|tail -n5
# ! echo "-Testdaten-"
# ! zip -r testing_Baumstruktur.zip {dst_test.parent}/*|tail -n5

# %% [markdown]
# **Gratulation!!!** Damit sind wir bereit für das Training eines neuronalen Netzes. Weiter geht's im Notebook `2_training/Training.ipynb.

# %%
# #Excel export der Medianwerte (V-channel)
# results = []
# for fn in pfad_zu_daten.iterdir():
#     if fn.suffix.lower() != '.jpg':
#         continue

#     im = oe.load_file(fn)
#     im = oe.resize(im, pr)
#     v_channel = rgb_to_hsv(im)[..., 2]
#     median_v = np.median(v_channel)

#     results.append({
#         'Filename': fn.name,
#         'Median_V': median_v,
#     })

# df_medians = pd.DataFrame(results)

# mean_row = df_medians.mean(numeric_only=True).to_frame().T
# mean_row.insert(0, 'Filename', 'Mittelwert')
# df_medians = pd.concat([df_medians, mean_row], ignore_index=True)

# df_medians.to_csv("Output/median_werte.csv", index=False)
