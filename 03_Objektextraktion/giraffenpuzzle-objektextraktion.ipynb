# %% [markdown]
# # Adaption der Objektextraktion
# Hallo! Wir wollen beliebige, selbstgewählte Objektkategorien auf Fotos (mit einfachem Hintergrund) erkennen. Sie brauchen also Fotos. Laden Sie diese auf Google-Drive hoch, oder nutzen Sie vorerst mal die [Giraffen-Puzzleteile](https://drive.google.com/drive/folders/1hXzFL_2Ot5PM3hvQCsgFhFeHV4wtG8E-?usp=drive_link). Die Daten sind auch im [dsci-Sharepoint-Ordner](https://ostch.sharepoint.com/:f:/r/teams/TS-FHS-IPM/Shared%20Documents/lehre%20und%20weiterbildung/21_Winf_MSc/10%20Module/DSCI/HS2024/Praktikum/Daten_Giraffe?csf=1&web=1&e=0OQ5db) abgelegt.
#
# Ziel dieses Notebooks ist es, den Hintergrund der Bilder so gut zu "verstehen", dass das Skript `objekt_extraction.py` anschliessend aus allen Fotos die Objekte extrahieren kann. Auf einem Foto können mehrere Objekte abgebildet sein, wir extrahieren dann aber pro Objekt ein Bild. "verstehen" bedeutet gewisse Parameterwerte zu bestimmen, mit denen die Objektextraktion zuverlässig funktioniert.
#
# Am Ende dieses Notebooks kennen wir diese Parameterwerte, und es wird das Skript `object_extraction.py` mit diesen Parameterwerten ausgeführt. Es extrahiert von allen Ihren Bildern die Ausschnitte (mit Objekten drin), welche wir für die Klassifizierung später brauchen.
#
# Die Objektextraktion im Skript object_extraction.py kann je nach Beleuchtungsverhältnissen etc. unterschiedlich gut klappen und muss allenfalls adaptiert werden. Mit diesem Notebook können die einzelnen Verarbeitungsschritte dieses Skripts detailliert nachvollzogen werden. Die Parameter, deren Werte wir bestimmen müssen, heissen:

# %%
pr = 398,224 #PREPROCESSING_RESOLUTION, --preprocessing_resolution
fr = 0.05  #FRACTION_OF_ROWS_TO_REMOVE, --fraction_of_rows_to_remove
fc = 0.0   #FRACTION_OF_COLS_TO_REMOVE, --fraction_of_cols_to_remove
vth = 0.6    #VALUE_THRESHOLD, --value_threshold
es = 8     #EROSION_SIZE, --erosion_size
ds = 10     #DILATION_SIZE, --dilation_size
mpx = 8000 #MINIMUM NUMBER OF PIXELS, --minimum_number_of_pixels
Bilddateiendung = 'jpg' #Dateiendung der Bilder, ohne ".", Achtung: 'jpg' ist nicht 'JPG'
fv=0 #value_to_fill: Wert, mit dem die abgeschnittenen Ränder aufgefüllt werden sollen

# %% [markdown]
# ## Setup und Zugriff zu den Bilddaten

# %%
#Import python File
import object_extraction as oe

#Import Libraries
from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow
from skimage.measure import label
import os
import logging
import re
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import train_test_split
import shutil
from IPython.display import FileLink

# %%
pfad_zu_daten = Path('./Gipfel_hell')

# %% [markdown]
# Laden wir ein Bild!

# %%
def show_image(im):
    imshow(im)
    ax = plt.gca()
    ax.set_xticks([]); ax.set_yticks([]);
    return ax

def choose_an_image():
    """
    Wähle eine Datei aus <pfad_zu_daten> und stelle es dar
    """
    Bilddatei_Liste = pd.Series(pfad_zu_daten.iterdir())
    fn = Bilddatei_Liste.sample(1).values[0]
    im = oe.load_file(fn)
    return im

im = choose_an_image()
show_image(im)
# Out:
# <Axes: >

# %%
from matplotlib.colors import rgb_to_hsv
rgb_to_hsv(im/255.).shape
hsv_im = rgb_to_hsv(im/255.)
channel_medians = np.median(hsv_im, axis=(0,1))
print(channel_medians)
# Out:
# [0.09090909 0.14285714 0.50588235]

# %% [markdown]
# # Adaption der Parameter
# Wir haben Zugriff auf die Bilddaten, nun möchten wir die Parameterwerte auswählen, welche die Objekte gut vom Hintergrund isolieren. Die Funktion `process_file` erledigt das.
#
# Das Vorgehen dabei ist Folgendes:
# 1. Lade das Bild und reduziere die Auflösung: Parameter **`pr`** enthält ein Tupel mit der Anzahl Pixelzeilen und der Anzahl Pixelspalten. Dies dient hauptsächlich der Beschleunigung der weiteren Verarbeitung.
# 2. Schneide jeweils an den Rändern einen Prozentsatz der Zeilen bzw. Spalten ab: Der Prozentsatz der Zeilen ist durch **`fr`**, jener der Spalten durch **`fc`** gegeben.
# 3. Es wird ein Schwellwert auf den value-Wert (in der hsv-Farbdarstellung) angewendet, um den dunklen (`sign`=+1) oder hellen (`sign`=-1) Hintergrund zu erkennen. Dies ergibt eine Maske (binärer Array), welcher Vordergrundpixel identifiziert.
# 4. Es werden kleine Artefakte auf der Maske durch Erosion und Dilatation entfernt. Die Parameter `es` und `ds` geben die Grössen der Erosions- und Dilatationsmasken an.
# 5. Die Objekte werden ausgeschnitten, d.h. separate Objekte werden identifiziert, und um jedes Objekt wird eine enge rechteckige *Bounding Box* gesetzt.
# 6. Sollte der Ausschnitt weniger als **`mpx`** Pixel enthalten, wird er verworfen. Dies ist nötig, weil manchmal Reflexionen o.ä. zusätzliche kleine Ausschnitte erzeugen, welche aber nicht ein Objekt enthalten.
# 7. Ein neues Bild wird abgespeichert, welches nur noch das (ausgeschnittene) Bildelement enthält.
#
#
# Wenn dies gelingt, sind die Bilder in einer geeigneten Form für Deep Learning.
#
# Im Folgenden wird dieser Vorgang für ein (von Ihnen gewähltes) Bild durchgeführt. Passen Sie die Parameter so an, dass die Extraktion gut gelingt.
# Die Parameter sollten Sie hier anpassen:

# %% [markdown]
# ### Schritt 0: Laden des Bildes

# %%
show_image(im);
aufloesung = im.shape
print(f'Das Bild hat folgende angepasste Auflösung: Höhe: {aufloesung[0]}px, Breite: {aufloesung[1]}px, Farbkanäle: {aufloesung[2]}')
# Out:
# Das Bild hat folgende angepasste Auflösung: Höhe: 5712px, Breite: 3213px, Farbkanäle: 3

# %% [markdown]
# ### Schritt 1: Auflösungsreduktion

# %% [markdown]
# Die Bilder können zu hoch aufgelöst sein für unsere Anwendung, wodurch sich die Rechenzeit der folgenden Operationen vervielfacht. Die Vorverarbeitungsroutine `object_extraction.py` beginnt daher damit, mit der `--preprocessing_resolution` (oder `-pr`) das Bild zu verkleinern:

# %%
#im_resized = (255*resize(im,pr)).astype('uint8') #Wird doch schon in load_file gemacht...
im_resized = oe.resize(im,pr)
show_image(im_resized);
angepasste_Aufloesung = im_resized.shape
print(f'Das Bild hat folgende angepasste Auflösung: Höhe: {angepasste_Aufloesung[0]}px, Breite: {angepasste_Aufloesung[1]}px, Farbkanäle: {angepasste_Aufloesung[2]}')
# Out:
# Das Bild hat folgende angepasste Auflösung: Höhe: 398px, Breite: 224px, Farbkanäle: 3

# %% [markdown]
# ## Schritt 2: Ränder abschneiden
# Als nächstes müssen ev. die Ränder des Bildes überdeckt werden. Damit können Artefakte beseitigt werden, z.B. wenn der schwarze Hintergrund nicht bis an den Rand des Bildes reicht. `fraction_of_rows_to_remove` und `fraction_of_cols_to_remove` geben an, wieviel abgeschnitten wird. Aufgefüllt werden die Pixel mit dem Wert `value_to_fill=0` (in allen Farbkanälen).

# %% [markdown]
# 📋 **Aufgabe 1:** Finden Sie für Ihre Bilder passende Werte für `fraction_of_rows_to_remove` und `fraction_of_cols_to_remove`.

# %%
im_filled = oe.fill_borders(im_resized,value_to_fill=fv,fraction_of_rows_to_remove=fr,
                         fraction_of_cols_to_remove=fc)
show_image(im_filled);

# %% [markdown]
# ## Schritt 3: Hintergrundschwellwert bestimmen
# Wählen Sie zunächst sign=+1 für Schwarzen Hintergrund oder sign=-1 für weissen Hintergrund.
#
# Als nächstes soll ein Schwellwert im Farbraum das Objekt vom Hintergrund isolieren. Wir arbeiten im *hsv*-Raum: hue, saturation und value sind die drei Farbdimensionen, für welche jeweils ein Mindestwert (für sign=+1) bzw. Maximalwert (für sign=-1) für Vordergrundpixel festgelegt werden kann. Berechnet wird konkret: `mask = sign*im_hsv[:,:,2]>value_schwellwert*sign` (etc.).

# %% [markdown]
# 📋 **Aufgabe 2:** Finden Sie Werte für `hue_schwellwert`, `saturation_schwellwert` und `value_schwellwert` so, dass die Maske möglichst gut zum Objektumriss passt. Bei der Wahl der Schwellwerte muss man aufpassen, dass sie nicht nur auf diesem einen Bild passen, sondern auch auf allen anderen!

# %%
mask = oe.generate_mask_with_hsv_threshold(im_filled, hue_threshold=None,saturation_threshold=None,value_threshold=vth) #0-255, 0-255, 0-1

plt.figure();show_image(mask);

masked_image = oe.create_masked_image(im_filled,mask)
plt.figure();show_image(masked_image);

# %% [markdown]
# ## Schritt 4: Erosion und Dilatationsfilgergrössen bestimmen

# %% [markdown]
# Wenn Hintergrundregionen übrigbleiben, dann ergibt dies zusätzliche Trainingsbilder, welche nicht einer Klasse zugeordnet sind- und es kostet auch viel Rechenzeit. Kleine, isolierte Maskenpixel möchten wir daher als nächstes durch Erosion entfernen.

# %% [markdown]
# 📋 **Aufgabe 3:** Finden Sie Werte für es und ds, welche möglichst keine vereinzelte Hintergrundpixel in der Maske übrig lassen:

# %%
morphed_mask = oe.morphology_transform(mask,shape = oe.square,erosion_size=es,dilation_size=ds)
show_image(morphed_mask);
# Out:
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))

# %% [markdown]
# Ev. haben Sie auch Glück, und Sie sehen oben nur eine einzige zusammenhängende gelbe Struktur? Dann können Sie die Werte so lassen, wie sie sind!

# %% [markdown]
# `create_mask` ist nun einfach eine Routine, welche die obigen Schritte der Maskenbildung zusammenfasst. Sie sollte das gleiche Bild `morphed_mask` wie oben erstellen:

# %%
morphed_mask,im_filled  = oe.create_mask(im_resized,
                                      fraction_of_rows_to_remove=fr,fraction_of_cols_to_remove=fc,
                                      hue_threshold=None,saturation_threshold=None,value_threshold=vth,
                                      erosion_size=es,dilation_size=ds)
show_image(morphed_mask);

# %% [markdown]
# Nun wird die Maske benutzt, um das Objekt (oder die Objekte) aus dem Bild auszuschneiden:

# %%
masked_image = oe.create_masked_image(im_filled,morphed_mask)
show_image(masked_image);
#masked_image.shape

# %% [markdown]
# Hier sollte ein Bild zu sehen sein, welches einen komplett schwarzen Hintergrund hat, und nur die relevanten Objekte zeigt. Als nächstes hätten wir gerne von jedem Objekt ein separates Bild, so dass wir darauf unseren Bildklassifikator trainieren können.

# %% [markdown]
# ## Schritt 5: Objekte ausschneiden
# Wir haben den Hintergrund eliminiert. Damit ist es nun leichter, die Objekte voneinander zu trennen. Die Funktion "label" von [scikit-image](https://scikit-image.org/docs/stable/api/skimage.measure.html#skimage.measure.label) tut dies:

# %%
label_img = label(morphed_mask)
show_image(label_img)
plt.colorbar();

# %% [markdown]
# Falls das obige Bild wie eine Maske aussieht: Vermutlich liegt nur ein Bild vor- deren Pixel wird dann mit dem Wert "1" aufgefüllt. Wäre ein zweites Objekt vorhanden, würde dieses mit dem Wert "2" aufgefüllt und wäre in einer leicht anderen Farbe sichtbar. Aus diesem gelabelten Bild werden nun Teilbilder extrahiert, welche jeweils nur ein Objekt enthalten:

# %%
label_img.shape,masked_image.shape
# Out:
# ((398, 224), (398, 224, 3))

# %%
regionlist,regions = oe.extract_regions(label_img,masked_image,fraction_of_rows_to_remove=fr)
regionen = len(regionlist)
print(f"Das Bild hat {regionen} Regionen.")
# Out:
# Das Bild hat 1 Regionen.

# %% [markdown]
# Alle obigen Schritte sind in der Funktion image_preprocessing zusammengefasst:

# %%
regionlist,regions,mask,masked_image = oe.image_preprocessing(im,
                                                           fraction_of_rows_to_remove=fr,
                                                           fraction_of_cols_to_remove=fc,
                                                           value_threshold=vth,
                                                           erosion_size=es,dilation_size=ds)
print(f"Anzahl gefundene Bereiche: {len(regionlist)}")
# Out:
# Anzahl gefundene Bereiche: 162

# %%
label_img.shape,masked_image.shape,len(regions)
# Out:
# ((398, 224), (5712, 3213, 3), 162)

# %%
show_image(masked_image)
# Out:
# <Axes: >

# %% [markdown]
# ## Schritt 6: Kleine Objekte (Artefakte) ignorieren
# Manchmal sind einige der gefundenen Regionen viel zu klein, um echte Objekte zu sein. Es gibt eine Option `--minimum-number-of-pixels` bzw. `-mpx`, welche Regionen unterdrückt, welche zu klein sind. Die Grösse der Regionen wird hier ausgegeben, um diesen Parameter gut einstellen zu können.

# %%
if len(regions)<10:
    for ireg,reg in enumerate(regions):
        print(f"Region {ireg}: {int(reg.area):>6}")
else:
    #for ireg,reg in enumerate(regions):
    #    print(f"{int(reg.area):<3} ",end='')

    plt.hist([reg.area for reg in regions],bins=np.logspace(1,6,100))
    plt.gca().set_xscale('log') #ev. sieht man damit etwas mehr
    plt.gca().set_yscale('log')

# %% [markdown]
# Schauen wir uns die extrahierten Regionen an - es sollten nicht zu viele sein.

# %% [markdown]
# 📋 **Aufgabe 4:** Bestimmen Sie einen geeigneten Wert von `mpx`, so dass nur relevante Regionen übrig bleiben. Tragen Sie den Wert in die Parameterliste ein.
#
# Der `mpx`-Wert wird in der nächsten Zelle verwendet:

# %%
relevante_regionen =  [reg for reg in regions if reg.area >= mpx]
if len(relevante_regionen)<20:
    for reg in relevante_regionen:
        plt.figure();
        plt.imshow(reg.image_intensity);
        plt.xticks([]);plt.yticks([]) # Wir brauchen keine x- und y-Achse
else:
    print(f"Das würde {len(relevante_regionen)} Graphiken erzeugen! Ich mache lieber nichts...")

# %% [markdown]
# Sehen Sie hier Ihre extrahierten Objekte, und keine (oder nur wenige) Artefakte?
# Ja?
# Wirklich?
# **Cool!**
# Dann können wir nun versuchen, alle weiteren Daten zu verarbeiten. Das kann  in der Kommandozeile wie folgt erreicht werden:

# %%
Ausgabepfad = Path("./Output")
#Ausgabepfad.mkdir(parents=True, exist_ok=True)
Ausgabepfad
# Out:
# PosixPath('Output')

# %%
imgfns = list(Path('./Gipfel_hell').glob('*.'+Bilddateiendung))
imgfns[:5]
# Out:
# [PosixPath('Gipfel_hell/Keimkraft_Gipfel_light_15.jpg'),
#  PosixPath('Gipfel_hell/Laugengipfel_light_19.jpg'),
#  PosixPath('Gipfel_hell/Keimkraft_Gipfel_light_01.jpg'),
#  PosixPath('Gipfel_hell/Keimkraft_Gipfel_light_29.jpg'),
#  PosixPath('Gipfel_hell/Laugengipfel_light_25.jpg')]

# %%
yta = True #args.yes_to_all
outputpath = Ausgabepfad
outputpath_Ausschnitte = os.path.join(outputpath, 'Ausschnitte')
oe.ask_path_creation(outputpath_Ausschnitte,yes_to_all=yta)

fraction_of_rows_to_remove = float(fr)
fraction_of_cols_to_remove = float(fc)
preprocessing_resolution = [int(f) for f in pr]
# print('preprocessing_resolution ',preprocessing_resolution )
erosion_size= oe.intOrNone(es)
dilation_size= oe.intOrNone(ds)
hue_threshold = None#intOrNone(hth)
value_threshold = vth#None#intOrNone(vth)
saturation_threshold = None #intOrNone(sth)
write_summary_file = False
num_cores = 1 #int(args.num_cores)
minimum_number_of_pixels = int(mpx)

kwargs = {'fraction_of_rows_to_remove':fr,'fraction_of_cols_to_remove':fc,'hue_threshold':hue_threshold,'saturation_threshold':saturation_threshold,'value_threshold':vth,
        'erosion_size':erosion_size,'dilation_size':dilation_size,'min_num_pixels':minimum_number_of_pixels,'outputpath':outputpath_Ausschnitte,'preprocessing_resolution':preprocessing_resolution}
# Out:
# INFO:object_extraction:Der Pfad Output/Ausschnitte konnte nicht gefunden werden.
# INFO:object_extraction:Pfad Output/Ausschnitte wurde erstellt

# %%
NrFilesToProcess = None # None eingeben für alle
kwargs['num_cores']=1
logger = logging.getLogger(__name__)
logger.setLevel(logging.INFO)
oe.main(imgfns[:NrFilesToProcess],kwargs)
# Out:
# Processing images:   0%|          | 0/81 [00:00<?, ?it/s]INFO:object_extraction:Shapes of extracted regions: [(246, 224, 3)]
# Processing images:   1%|          | 1/81 [00:03<04:44,  3.56s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(269, 224, 3), (10, 11, 3)]
# INFO:object_extraction:skipping region: num_pix=110,shape:(10, 11, 3),area:110.0, as num_pix is < 8000
# Processing images:   2%|▏         | 2/81 [00:05<03:30,  2.66s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(269, 224, 3)]
# Processing images:   4%|▎         | 3/81 [00:07<03:04,  2.37s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(120, 224, 3), (177, 136, 3)]
# Processing images:   5%|▍         | 4/81 [00:09<02:50,  2.21s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(252, 219, 3)]
# Processing images:   6%|▌         | 5/81 [00:10<02:08,  1.69s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(128, 224, 3), (206, 135, 3)]
# Processing images:   7%|▋         | 6/81 [00:12<02:14,  1.79s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(263, 224, 3)]
# Processing images:   9%|▊         | 7/81 [00:14<02:17,  1.85s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(238, 224, 3)]
# Processing images:  10%|▉         | 8/81 [00:16<02:18,  1.90s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(117, 224, 3), (160, 119, 3), (10, 11, 3)]
# INFO:object_extraction:skipping region: num_pix=110,shape:(10, 11, 3),area:110.0, as num_pix is < 8000
# Processing images:  11%|█         | 9/81 [00:18<02:18,  1.92s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(95, 171, 3), (252, 101, 3)]
# Processing images:  12%|█▏        | 10/81 [00:19<01:50,  1.56s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(277, 207, 3)]
# Processing images:  14%|█▎        | 11/81 [00:19<01:32,  1.31s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(311, 224, 3)]
# Processing images:  15%|█▍        | 12/81 [00:21<01:45,  1.53s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(129, 224, 3), (154, 164, 3)]
# Processing images:  16%|█▌        | 13/81 [00:23<01:52,  1.66s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(112, 224, 3), (109, 207, 3)]
# Processing images:  17%|█▋        | 14/81 [00:25<01:56,  1.74s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(310, 211, 3)]
# Processing images:  19%|█▊        | 15/81 [00:26<01:35,  1.45s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(128, 224, 3), (79, 193, 3)]
# Processing images:  20%|█▉        | 16/81 [00:28<01:44,  1.61s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(131, 224, 3), (138, 151, 3)]
# Processing images:  21%|██        | 17/81 [00:30<01:50,  1.73s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(266, 224, 3), (10, 10, 3)]
# INFO:object_extraction:skipping region: num_pix=100,shape:(10, 10, 3),area:100.0, as num_pix is < 8000
# Processing images:  22%|██▏       | 18/81 [00:32<01:54,  1.82s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(206, 224, 3)]
# Processing images:  23%|██▎       | 19/81 [00:34<01:54,  1.85s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(241, 224, 3)]
# Processing images:  25%|██▍       | 20/81 [00:36<01:54,  1.87s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(269, 224, 3)]
# Processing images:  26%|██▌       | 21/81 [00:37<01:32,  1.55s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(280, 224, 3)]
# Processing images:  27%|██▋       | 22/81 [00:39<01:38,  1.67s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(120, 224, 3), (92, 207, 3)]
# Processing images:  28%|██▊       | 23/81 [00:41<01:42,  1.77s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(206, 224, 3), (17, 15, 3), (13, 13, 3)]
# INFO:object_extraction:skipping region: num_pix=234,shape:(17, 15, 3),area:234.0, as num_pix is < 8000
# INFO:object_extraction:skipping region: num_pix=163,shape:(13, 13, 3),area:163.0, as num_pix is < 8000
# Processing images:  30%|██▉       | 24/81 [00:43<01:44,  1.83s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(310, 205, 3), (11, 5, 3)]
# INFO:object_extraction:skipping region: num_pix=55,shape:(11, 5, 3),area:55.0, as num_pix is < 8000
# Processing images:  31%|███       | 25/81 [00:43<01:24,  1.50s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(212, 224, 3)]
# Processing images:  32%|███▏      | 26/81 [00:45<01:29,  1.64s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(247, 224, 3), (11, 15, 3)]
# INFO:object_extraction:skipping region: num_pix=163,shape:(11, 15, 3),area:163.0, as num_pix is < 8000
# Processing images:  33%|███▎      | 27/81 [00:47<01:33,  1.74s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(130, 224, 3), (99, 150, 3)]
# Processing images:  35%|███▍      | 28/81 [00:49<01:34,  1.79s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(125, 224, 3), (165, 78, 3)]
# INFO:object_extraction:skipping region: num_pix=7820,shape:(165, 78, 3),area:7820.0, as num_pix is < 8000
# Processing images:  36%|███▌      | 29/81 [00:51<01:35,  1.84s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(117, 224, 3), (107, 159, 3)]
# Processing images:  37%|███▋      | 30/81 [00:53<01:35,  1.87s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(264, 224, 3)]
# Processing images:  38%|███▊      | 31/81 [00:55<01:35,  1.90s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(274, 224, 3)]
# Processing images:  40%|███▉      | 32/81 [00:57<01:33,  1.91s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(252, 224, 3)]
# Processing images:  41%|████      | 33/81 [00:59<01:31,  1.91s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(123, 224, 3), (142, 115, 3)]
# Processing images:  42%|████▏     | 34/81 [01:00<01:14,  1.58s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(236, 224, 3)]
# Processing images:  43%|████▎     | 35/81 [01:02<01:18,  1.71s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(221, 224, 3)]
# Processing images:  44%|████▍     | 36/81 [01:04<01:20,  1.79s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(220, 224, 3)]
# Processing images:  46%|████▌     | 37/81 [01:06<01:21,  1.85s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(136, 224, 3), (143, 116, 3)]
# Processing images:  47%|████▋     | 38/81 [01:08<01:20,  1.88s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(120, 224, 3), (158, 100, 3)]
# Processing images:  48%|████▊     | 39/81 [01:10<01:20,  1.92s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(114, 224, 3), (114, 173, 3)]
# Processing images:  49%|████▉     | 40/81 [01:12<01:19,  1.94s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(116, 224, 3), (122, 141, 3)]
# Processing images:  51%|█████     | 41/81 [01:14<01:17,  1.95s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(239, 224, 3)]
# Processing images:  52%|█████▏    | 42/81 [01:15<01:15,  1.94s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(241, 224, 3)]
# Processing images:  53%|█████▎    | 43/81 [01:17<01:14,  1.96s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(127, 224, 3), (146, 106, 3)]
# Processing images:  54%|█████▍    | 44/81 [01:19<01:11,  1.94s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(112, 224, 3), (141, 148, 3)]
# Processing images:  56%|█████▌    | 45/81 [01:22<01:14,  2.06s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(230, 224, 3)]
# Processing images:  57%|█████▋    | 46/81 [01:24<01:11,  2.05s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(118, 224, 3), (122, 141, 3)]
# Processing images:  58%|█████▊    | 47/81 [01:26<01:09,  2.04s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(132, 224, 3), (111, 150, 3)]
# Processing images:  59%|█████▉    | 48/81 [01:28<01:07,  2.03s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(120, 224, 3), (75, 156, 3)]
# Processing images:  60%|██████    | 49/81 [01:30<01:04,  2.02s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(129, 224, 3), (136, 117, 3)]
# Processing images:  62%|██████▏   | 50/81 [01:32<01:02,  2.01s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(245, 210, 3), (18, 47, 3)]
# INFO:object_extraction:skipping region: num_pix=659,shape:(18, 47, 3),area:659.0, as num_pix is < 8000
# Processing images:  63%|██████▎   | 51/81 [01:33<00:49,  1.64s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(253, 224, 3)]
# Processing images:  64%|██████▍   | 52/81 [01:35<00:50,  1.75s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(117, 224, 3), (133, 131, 3), (10, 10, 3)]
# INFO:object_extraction:skipping region: num_pix=100,shape:(10, 10, 3),area:100.0, as num_pix is < 8000
# Processing images:  65%|██████▌   | 53/81 [01:37<00:51,  1.84s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(132, 224, 3), (136, 117, 3)]
# Processing images:  67%|██████▋   | 54/81 [01:39<00:51,  1.90s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(252, 224, 3)]
# Processing images:  68%|██████▊   | 55/81 [01:41<00:50,  1.94s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(131, 224, 3), (136, 117, 3)]
# Processing images:  69%|██████▉   | 56/81 [01:43<00:48,  1.96s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(260, 224, 3), (15, 15, 3)]
# INFO:object_extraction:skipping region: num_pix=212,shape:(15, 15, 3),area:212.0, as num_pix is < 8000
# Processing images:  70%|███████   | 57/81 [01:45<00:47,  1.98s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(272, 224, 3)]
# Processing images:  72%|███████▏  | 58/81 [01:47<00:45,  1.98s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(248, 224, 3)]
# Processing images:  73%|███████▎  | 59/81 [01:49<00:43,  1.99s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(273, 224, 3)]
# Processing images:  74%|███████▍  | 60/81 [01:51<00:41,  1.98s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(252, 224, 3)]
# Processing images:  75%|███████▌  | 61/81 [01:53<00:40,  2.03s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(246, 224, 3)]
# Processing images:  77%|███████▋  | 62/81 [01:55<00:38,  2.02s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(132, 224, 3), (151, 139, 3)]
# Processing images:  78%|███████▊  | 63/81 [01:57<00:36,  2.03s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(119, 224, 3), (99, 164, 3), (10, 10, 3)]
# INFO:object_extraction:skipping region: num_pix=100,shape:(10, 10, 3),area:100.0, as num_pix is < 8000
# Processing images:  79%|███████▉  | 64/81 [01:59<00:34,  2.04s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(252, 224, 3)]
# Processing images:  80%|████████  | 65/81 [02:01<00:32,  2.02s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(279, 224, 3), (25, 12, 3)]
# INFO:object_extraction:skipping region: num_pix=275,shape:(25, 12, 3),area:275.0, as num_pix is < 8000
# Processing images:  81%|████████▏ | 66/81 [02:03<00:30,  2.03s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(119, 224, 3), (99, 164, 3), (10, 10, 3)]
# INFO:object_extraction:skipping region: num_pix=100,shape:(10, 10, 3),area:100.0, as num_pix is < 8000
# Processing images:  83%|████████▎ | 67/81 [02:05<00:28,  2.02s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(226, 224, 3)]
# Processing images:  84%|████████▍ | 68/81 [02:07<00:26,  2.05s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(280, 224, 3)]
# Processing images:  85%|████████▌ | 69/81 [02:09<00:24,  2.05s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(257, 224, 3), (13, 14, 3)]
# INFO:object_extraction:skipping region: num_pix=174,shape:(13, 14, 3),area:174.0, as num_pix is < 8000
# Processing images:  86%|████████▋ | 70/81 [02:11<00:22,  2.03s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(255, 224, 3), (15, 17, 3)]
# INFO:object_extraction:skipping region: num_pix=231,shape:(15, 17, 3),area:231.0, as num_pix is < 8000
# Processing images:  88%|████████▊ | 71/81 [02:13<00:20,  2.02s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(283, 224, 3), (11, 12, 3)]
# INFO:object_extraction:skipping region: num_pix=132,shape:(11, 12, 3),area:132.0, as num_pix is < 8000
# Processing images:  89%|████████▉ | 72/81 [02:15<00:18,  2.01s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(274, 224, 3)]
# Processing images:  90%|█████████ | 73/81 [02:17<00:16,  2.00s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(274, 224, 3), (14, 14, 3)]
# INFO:object_extraction:skipping region: num_pix=188,shape:(14, 14, 3),area:188.0, as num_pix is < 8000
# Processing images:  91%|█████████▏| 74/81 [02:19<00:14,  2.01s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(120, 224, 3), (168, 144, 3)]
# Processing images:  93%|█████████▎| 75/81 [02:21<00:12,  2.02s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(240, 224, 3)]
# Processing images:  94%|█████████▍| 76/81 [02:23<00:10,  2.01s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(265, 224, 3)]
# Processing images:  95%|█████████▌| 77/81 [02:25<00:08,  2.00s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(240, 224, 3)]
# Processing images:  96%|█████████▋| 78/81 [02:27<00:05,  2.00s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(125, 224, 3), (168, 144, 3)]
# Processing images:  98%|█████████▊| 79/81 [02:29<00:04,  2.01s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(274, 224, 3)]
# Processing images:  99%|█████████▉| 80/81 [02:31<00:02,  2.01s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(268, 224, 3), (12, 12, 3)]
# INFO:object_extraction:skipping region: num_pix=143,shape:(12, 12, 3),area:143.0, as num_pix is < 8000
# Processing images: 100%|██████████| 81/81 [02:33<00:00,  1.90s/it]
# INFO:object_extraction:Die Bildausschnitte wurden hierher kopiert: Output/Ausschnitte

# %% [markdown]
# Alternativ kann die Ausgabe der folgenden Zelle genutzt werden, um in der Kommandozeile das Skript [object_extraction.py](https://gitlab.ost.ch/beat.toedtli/learning-city-lab/-/blob/main/1_object_extraction/object_extraction.py?ref_type=heads)[im Verzeichnis [1_object_extraction](https://gitlab.ost.ch/beat.toedtli/learning-city-lab/-/tree/main/1_object_extraction?ref_type=heads) auszuführen.

# %%
##cmd = f"python3 '{pfad_zu_object_extraction}/object_extraction.py' \
#-y -o '{Ausgabepfad}' -pr {pr[0]},{pr[1]} -fr {fr} -fc {fc} -es {es} -ds {ds} \
#-vth {vth} -mpx {mpx} f'{pfad_zu_daten_string}/*.{Bilddateiendung}'"
#print("Der Kommandozeilenbefehl lautet:\n",cmd)

# %%
#Die Ausschnitte sind nun hier:
print(Ausgabepfad/'Ausschnitte')
# hier einige Beispiele:
# !ls {'"'+str(Ausgabepfad/'Ausschnitte')+'"'}|head -n 5
# Out:
# Output/Ausschnitte
# Buttergipfel_light_0_01.jpg
# Buttergipfel_light_0_04.jpg
# Buttergipfel_light_0_06.jpg
# Buttergipfel_light_0_07.jpg
# Buttergipfel_light_0_10.jpg

# %% [markdown]
# Wir können uns die Ausschnitte anschauen:

# %%
fn = Ausgabepfad/'Ausschnitte'/'Buttergipfel_light_0_06.jpg'
if fn.exists():
    im = plt.imread(fn)
    show_image(im);

# %% [markdown]
# Bevor wir die Bilder herunterladen, wollen wir sie in Unterordner pro Klasse anordnen.

# %% [markdown]
# # Bilden von Unterordner pro Klasse
# Keras, unsere Deep Learning Bibliothek, hat eine einfache Routine, um Kategorisierte Bilder zu laden: Dazu müssen alle Bilder einer Klasse in einem Unterordner liegen, welcher als Namen die Klassenbezeichnung trägt. Diese Zuordnung kann natürlich von Hand vorgenommen werden. Im Fall des Giraffendatensatzes ist das Klassenlabel aber bereits im Dateinamen der Bilder codiert.

# %% [markdown]
# #### Reguläre Ausdrücke

# %%
re.sub(r'^([^_]+).*$', r'\1', "Laugengipfel_low_light_0_10.jpg")
# Out:
# 'Laugengipfel'

# %% [markdown]
# Der reguläre Ausdruck `^([^-]*)-.*$` hat's durchaus in sich, ist aber verständlicher, wenn man folgendes weiss:
# - `^` bezeichnet den Beginn einer Zeichenkette
# - `$` bezeichnet das Ende einer Zeichenkette
# - `.` bezeichnet ein beliebiges Zeichen
# - `*` meint "Null-mal, einmal oder beliebig oft". Gemeint ist hier das Zeichen davor ("."), als "kein oder beliebig viele beliebige Zeichen".
# - `( )` Die Klammern gehören zusammen und bilden eine Gruppe: alle Zeichen dazwischen werden in einer Variablen abgespeichert, welche "\1" heisst. Dies sind die einzigen Zeichen, welche nach der Substitution die verbleibende Zeichenkette ausmachen: Im zweiten Argument von `re.sub` steht, womit ein "gematchtes Muster" (engl. matched pattern) im String ersetzt wird.
# - In eckigen Klammern, `[]`, können Zeichen aufgezählt werden, die auftauchen dürfen. Innerhalb von eckigen Klammern bedeutet `^` *nicht* den Beginn des Strings, sondern eine Negation. Der Ausdruck `[^-]` bezeichnet daher ein beliebiges Zeichen, welches aber nicht das Minuszeichen sein darf.
#
# Insgesamt sagt der Ausdruck `'^([^-]*)-.*$'` also so etwas wie:
# *Eine Zeichenkette matcht, wenn sie mit einer beliebigen Folge von Zeichen beginnt, welche nicht das Zeichen "-" ist, gefolgt von einem Minuszeichen. Diese Zeichen vor dem Minus bilden die Gruppe 1. Nach dieser Gruppe muss also ein "-" folgen, und danach dürfen noch beliebig viele beliebige Zeichen folgen bis zum Ende der Zeichenkette. Ersetze diese ganze Zeichenkette (von Anfang bis Ende) mit der Gruppe.*
#
# In einfacherer Sprache ausgedrückt wird die Zeichenkette vor dem Minuszeichen extrahiert- sie enthält ja den Klassennamen.

# %% [markdown]
# #### Pandas DataFrames
# Pandas DataFrames sind sehr nützliche tabellenartige Strukturen. Sie eignen sich v.a. für die Datenanalyse und Visualisierung von strukturierten Daten. Im Folgenden werden diese genutzt, um das Klassenlabel zu bestimmen, welches für die Erstellung der Baumstruktur nützlich ist.

# %%
#volle_Dateinamen = [full_file_name for full_file_name in (Ausgabepfad/'Ausschnitte').glob('*.'+Bilddateiendung)]
#Basisnamen =  [full_file_name for full_file_name in (Ausgabepfad/'Ausschnitte').glob('*.'+Bilddateiendung)]

#Klassenlabel = [re.sub(r'^([^_]+).*$', r'\1', bn.name) for bn in Basisnamen] #Wende den regulären Ausdruck an
#df = pd.DataFrame({'Dateiname':volle_Dateinamen,'Basisname':Basisnamen,'Klassenlabel':Klassenlabel})
#df


#Erzeuge trrain und testset aus allen Bildern und nicht nur aus Ausschnitten
pfad_zu_bilder = Path('../02_Alle_Gipfel')

volle_Dateinamen = [full_file_name for full_file_name in (pfad_zu_bilder).glob('*.'+Bilddateiendung)]
Basisnamen =  [full_file_name for full_file_name in (pfad_zu_bilder).glob('*.'+Bilddateiendung)]

Klassenlabel = [re.sub(r'^([^_]+).*$', r'\1', bn.name) for bn in Basisnamen] #Wende den regulären Ausdruck an
df = pd.DataFrame({'Dateiname':volle_Dateinamen,'Basisname':Basisnamen,'Klassenlabel':Klassenlabel})
df
# Out:
#                                              Dateiname  \
# 0      ../02_Alle_Gipfel/Laugengipfel_low_light_34.jpg
# 1      ../02_Alle_Gipfel/Laugengipfel_low_light_20.jpg
# 2      ../02_Alle_Gipfel/Keimkraft_Gipfel_light_15.jpg
# 3          ../02_Alle_Gipfel/Laugengipfel_light_19.jpg
# 4      ../02_Alle_Gipfel/Keimkraft_Gipfel_light_01.jpg
# ..                                                 ...
# 168    ../02_Alle_Gipfel/Keimkraft_Gipfel_light_30.jpg
# 169  ../02_Alle_Gipfel/Keimkraft_Gipfel_low_light_4...
# 170    ../02_Alle_Gipfel/Keimkraft_Gipfel_light_18.jpg
# 171        ../02_Alle_Gipfel/Laugengipfel_light_14.jpg
# 172    ../02_Alle_Gipfel/Laugengipfel_low_light_11.jpg
#
#                                              Basisname  Klassenlabel
# 0      ../02_Alle_Gipfel/Laugengipfel_low_light_34.jpg  Laugengipfel
# 1      ../02_Alle_Gipfel/Laugengipfel_low_light_20.jpg  Laugengipfel
# 2      ../02_Alle_Gipfel/Keimkraft_Gipfel_light_15.jpg     Keimkraft
# 3          ../02_Alle_Gipfel/Laugengipfel_light_19.jpg  Laugengipfel
# 4      ../02_Alle_Gipfel/Keimkraft_Gipfel_light_01.jpg     Keimkraft
# ..                                                 ...           ...
# 168    ../02_Alle_Gipfel/Keimkraft_Gipfel_light_30.jpg     Keimkraft
# 169  ../02_Alle_Gipfel/Keimkraft_Gipfel_low_light_4...     Keimkraft
# 170    ../02_Alle_Gipfel/Keimkraft_Gipfel_light_18.jpg     Keimkraft
# 171        ../02_Alle_Gipfel/Laugengipfel_light_14.jpg  Laugengipfel
# 172    ../02_Alle_Gipfel/Laugengipfel_low_light_11.jpg  Laugengipfel
#
# [173 rows x 3 columns]

# %% [markdown]
# #### Train-Test-Split
# An dieser Stelle lohnt es sich, kurz innezuhalten: Unsere grandiose Strategie ist es, aus Bildern Objekte zu extrahieren und auf diesen dann ein Modell zu trainieren. Aber wir können nicht alle Daten als Trainingsdaten verwenden, sonst haben wir nichts mehr, um die *Generalisierungsfähigkeit* unseres Modells zu messen!
# Die Realität ist, dass wir nur ungern später nochmals neue Daten aufnehmen wollen. Die Liste in `df` oben ist alles, was uns zur Verfügung steht. Es macht daher Sinn, bereits jetzt einen Teil dieser Daten zurückzulegen und zu *schwören* diese Daten nicht für das Training zu benutzen. Wir brauchen ca. 20% *frische* Daten, an denen wir die Verallgemeinerungsfähigkeit unseres Modells überprüfen können.
# [Scikit-Learn](https://scikit-learn.org) bietet uns [hier](https://scikit-learn.org/stable/auto_examples/model_selection/plot_cv_indices.html#sphx-glr-auto-examples-model-selection-plot-cv-indices-py) verschiedene Strategien an, wie wir aus unseren Trainingsdaten einen Testdatensatz absondern können. Wir könnten einfach [zufällig splitten](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.ShuffleSplit.html#sklearn.model_selection.ShuffleSplit). Das ist naiv. Lieber eine [k-fache Kreuzvalidierung](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.KFold.html#sklearn.model_selection.KFold). Aber was, wenn zufälligerweise eine Klasse nur im Testdatensatz auftaucht, und gar nicht im Trainingsdatensatz?! Also [stratifizieren](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.StratifiedKFold.html#sklearn.model_selection.StratifiedKFold) wir. Ok- und was ist, wenn wir überprüfen wollen, dass wir in Bezug auf eine bestimmte Untergruppierung (z.B. nach Geschlecht, Ethnie,...) gut von einer Gruppe auf eine andere verallgemeinern können müssen? Dann darf eine [Gruppe nur in einem Fold vorkommen](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.StratifiedGroupKFold.html#sklearn.model_selection.StratifiedGroupKFold). Sie sehen- richtig zu splitten kann herausfordernd sein!
# Hier jedenfalls möchten wir zumindest stratifizieren. Wir nehmen mal [StratifiedKFold](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.StratifiedKFold.html#sklearn.model_selection.StratifiedKFold), um unsere Daten zu splitten.

# %%
Xtrain,Xtest,ytrain,ytest = train_test_split(df[['Dateiname','Basisname']],df.Klassenlabel,test_size=0.2,train_size=0.8,stratify =df.Klassenlabel,random_state=42)
# Das Fixieren des random_state bedeutet, dass immer der gleiche Split gemacht wird. Dadurch wird verhindert, dass durch mehrfaches durchlaufen immer mal wieder andere Daten für das Training
# benutzt werden. Denn dadurch würde man sich letztlich beim Training alle Daten anschauen, auch die Testdaten. Subtiler Punkt- aber m.E. good practice!
#Die Grössen der Arrays:
print(Xtrain.shape,Xtest.shape,ytrain.shape,ytest.shape)
print("Trainingsdaten")
display(ytrain.value_counts())
print("\nTestdaten")
display(ytest.value_counts())
print('\nKlassenverhältnis:')
#Von den Trainingsdaten gibt es in jeder Klasse etwa gleichviel mehr als in den Testdaten:
ytest.value_counts()/ytrain.value_counts()
# Out:
# (138, 2) (35, 2) (138,) (35,)
# Trainingsdaten
# Klassenlabel
# Keimkraft       52
# Laugengipfel    48
# Buttergipfel    38
# Name: count, dtype: int64
# Testdaten
# Klassenlabel
# Keimkraft       13
# Laugengipfel    12
# Buttergipfel    10
# Name: count, dtype: int64
# Klassenverhältnis:
# Klassenlabel
# Keimkraft       0.250000
# Laugengipfel    0.250000
# Buttergipfel    0.263158
# Name: count, dtype: float64

# %% [markdown]
# Die Ausgaben oben zeigen die Anzahl Beispiele pro Klasse in den Training- und Testdaten sowie das Verhältnis pro Klasse. Das Verhältnis sollte für alle Klassen etwa gleich gross sein- dies nennt sich *stratifiziertes Training-Test-Splitten*.

# %%
display(Xtrain.head())
ytrain
# Out:
#                                              Dateiname  \
# 89     ../02_Alle_Gipfel/Buttergipfel_low_light_01.jpg
# 69         ../02_Alle_Gipfel/Buttergipfel_light_25.jpg
# 50     ../02_Alle_Gipfel/Buttergipfel_low_light_35.jpg
# 118        ../02_Alle_Gipfel/Buttergipfel_light_39.jpg
# 83   ../02_Alle_Gipfel/Keimkraft_Gipfel_low_light_1...
#
#                                              Basisname
# 89     ../02_Alle_Gipfel/Buttergipfel_low_light_01.jpg
# 69         ../02_Alle_Gipfel/Buttergipfel_light_25.jpg
# 50     ../02_Alle_Gipfel/Buttergipfel_low_light_35.jpg
# 118        ../02_Alle_Gipfel/Buttergipfel_light_39.jpg
# 83   ../02_Alle_Gipfel/Keimkraft_Gipfel_low_light_1...
# 89     Buttergipfel
# 69     Buttergipfel
# 50     Buttergipfel
# 118    Buttergipfel
# 83        Keimkraft
#            ...
# 133       Keimkraft
# 146    Laugengipfel
# 32     Laugengipfel
# 48     Buttergipfel
# 80     Laugengipfel
# Name: Klassenlabel, Length: 138, dtype: object

# %% [markdown]
# #### Shutil - High-level File Operations
# Wir kopieren nun die Daten in Unterordner von `pfad_zu_lcl_colab/2_Baumstruktur/`. Die Unterordner sollen die Klassennamen (Farben) sein.

# %%
#Kopiere die Trainigsdaten
for Basisname,voller_Dateiname, label in zip(Xtrain.Basisname,Xtrain.Dateiname, ytrain):
    src = voller_Dateiname
    #dst = Path('/tmp','2_Baumstruktur',label)
    dst_train = Ausgabepfad/'Baumstruktur_train'/label

    dst_train.mkdir(exist_ok=True,parents=True)
    shutil.copy(src,dst_train/Basisname.name)
print(f"Trainingsdateien wurden nach {str(dst_train.parent)} kopiert.")
#Kopiere die Testdaten
for Basisname,voller_Dateiname, label in zip(Xtest.Basisname,Xtest.Dateiname, ytest):
    src = voller_Dateiname

    dst_test = Ausgabepfad/'Baumstruktur_test'/label

    dst_test.mkdir(exist_ok=True,parents=True)
    shutil.copy(src,dst_test/Basisname.name)
print(f"Testdateien wurden nach {str(dst_test.parent)} kopiert.")
# Out:
# Trainingsdateien wurden nach Output/Baumstruktur_train kopiert.
# Testdateien wurden nach Output/Baumstruktur_test kopiert.

# %% [markdown]
# Überprüfen wir die Struktur! Die Klassenverzeichnisse sind hier:

# %%
# !echo "Training-Baumstruktur:"
# !ls "{dst_train.parent}"
# !echo "Test-Baumstruktur:"
# !ls "{dst_test.parent}"
# Out:
# Training-Baumstruktur:
# Buttergipfel Keimkraft    Laugengipfel
# Test-Baumstruktur:
# Buttergipfel Keimkraft    Laugengipfel

# %% [markdown]
# Und darunter befinden sich die zur Klasse zugehörigen Bilder:

# %%
# !ls "{dst_test.parent}"/*
# Out:
# Output/Baumstruktur_test/Buttergipfel:
# Buttergipfel_light_07.jpg     Buttergipfel_light_27.jpg
# Buttergipfel_light_11.jpg     Buttergipfel_low_light_05.jpg
# Buttergipfel_light_18.jpg     Buttergipfel_low_light_09.jpg
# Buttergipfel_light_19.jpg     Buttergipfel_low_light_28.jpg
# Buttergipfel_light_20.jpg     Buttergipfel_low_light_31.jpg
#
# Output/Baumstruktur_test/Keimkraft:
# Keimkraft_Gipfel_light_01.jpg     Keimkraft_Gipfel_light_38.jpg
# Keimkraft_Gipfel_light_07.jpg     Keimkraft_Gipfel_low_light_02.jpg
# Keimkraft_Gipfel_light_19.jpg     Keimkraft_Gipfel_low_light_03.jpg
# Keimkraft_Gipfel_light_22.jpg     Keimkraft_Gipfel_low_light_05.jpg
# Keimkraft_Gipfel_light_23.jpg     Keimkraft_Gipfel_low_light_12.jpg
# Keimkraft_Gipfel_light_31.jpg     Keimkraft_Gipfel_low_light_37.jpg
# Keimkraft_Gipfel_light_34.jpg
#
# Output/Baumstruktur_test/Laugengipfel:
# Laugengipfel_light_04.jpg     Laugengipfel_light_46.jpg
# Laugengipfel_light_05.jpg     Laugengipfel_low_light_09.jpg
# Laugengipfel_light_14.jpg     Laugengipfel_low_light_23.jpg
# Laugengipfel_light_27.jpg     Laugengipfel_low_light_35.jpg
# Laugengipfel_light_31.jpg     Laugengipfel_low_light_41.jpg
# Laugengipfel_light_39.jpg     Laugengipfel_low_light_44.jpg

# %% [markdown]
# Nun wollen wir diese zwei Baumstrukturen herunterladen:

# %%
! echo "-Trainingdaten-"
! zip -r training_Baumstruktur.zip {dst_train.parent}/*|tail -n5
! echo "-Testdaten-"
! zip -r testing_Baumstruktur.zip {dst_test.parent}/*|tail -n5
# Out:
# -Trainingdaten-
#   adding: Output/Baumstruktur_train/Laugengipfel/Laugengipfel_low_light_04.jpg (deflated 1%)
#   adding: Output/Baumstruktur_train/Laugengipfel/Laugengipfel_low_light_38.jpg (deflated 0%)
#   adding: Output/Baumstruktur_train/Laugengipfel/Laugengipfel_light_15.jpg (deflated 0%)
#   adding: Output/Baumstruktur_train/Laugengipfel/Laugengipfel_light_29.jpg (deflated 0%)
#   adding: Output/Baumstruktur_train/Laugengipfel/Laugengipfel_low_light_11.jpg (deflated 1%)
# -Testdaten-
#   adding: Output/Baumstruktur_test/Laugengipfel/Laugengipfel_low_light_44.jpg (deflated 0%)
#   adding: Output/Baumstruktur_test/Laugengipfel/Laugengipfel_light_04.jpg (deflated 1%)
#   adding: Output/Baumstruktur_test/Laugengipfel/Laugengipfel_light_05.jpg (deflated 1%)
#   adding: Output/Baumstruktur_test/Laugengipfel/Laugengipfel_light_39.jpg (deflated 0%)
#   adding: Output/Baumstruktur_test/Laugengipfel/Laugengipfel_light_14.jpg (deflated 1%)

# %% [markdown]
# **Gratulation!!!** Damit sind wir bereit für das Training eines neuronalen Netzes. Weiter geht's im Notebook `2_training/Training.ipynb.

# %%
#Excel export der Medianwerte aller Bilder
results = []
for fn in pfad_zu_daten.iterdir():
    if not fn.suffix.lower() in ['.jpg']:  # nur Bilddateien
        continue

    im = oe.load_file(fn)
    hsv = rgb_to_hsv(im / 255.)
    hsv[..., :2] *= 255
    medians = np.median(hsv, axis=(0, 1))
    results.append({
        'Filename': fn.name,
        'Median_H': medians[0],
        'Median_S': medians[1],
        'Median_V': medians[2],
    })

df_medians = pd.DataFrame(results)

mean_row = df_medians.mean(numeric_only=True).to_frame().T
mean_row.insert(0, 'Filename', 'Mittelwert')
df_medians = pd.concat([df_medians, mean_row], ignore_index=True)

df_medians.to_csv("Output/median_werte.csv", index=False)
