# %% [markdown]
# # Adaption der Objektextraktion
# Hallo! Wir wollen beliebige, selbstgewählte Objektkategorien auf Fotos (mit einfachem Hintergrund) erkennen. Sie brauchen also Fotos. Laden Sie diese auf Google-Drive hoch, oder nutzen Sie vorerst mal die [Giraffen-Puzzleteile](https://drive.google.com/drive/folders/1hXzFL_2Ot5PM3hvQCsgFhFeHV4wtG8E-?usp=drive_link). Die Daten sind auch im [dsci-Sharepoint-Ordner](https://ostch.sharepoint.com/:f:/r/teams/TS-FHS-IPM/Shared%20Documents/lehre%20und%20weiterbildung/21_Winf_MSc/10%20Module/DSCI/HS2024/Praktikum/Daten_Giraffe?csf=1&web=1&e=0OQ5db) abgelegt.
#
# Ziel dieses Notebooks ist es, den Hintergrund der Bilder so gut zu "verstehen", dass das Skript `objekt_extraction.py` anschliessend aus allen Fotos die Objekte extrahieren kann. Auf einem Foto können mehrere Objekte abgebildet sein, wir extrahieren dann aber pro Objekt ein Bild. "verstehen" bedeutet gewisse Parameterwerte zu bestimmen, mit denen die Objektextraktion zuverlässig funktioniert.
#
# Am Ende dieses Notebooks kennen wir diese Parameterwerte, und es wird das Skript `object_extraction.py` mit diesen Parameterwerten ausgeführt. Es extrahiert von allen Ihren Bildern die Ausschnitte (mit Objekten drin), welche wir für die Klassifizierung später brauchen.
#
# Die Objektextraktion im Skript object_extraction.py kann je nach Beleuchtungsverhältnissen etc. unterschiedlich gut klappen und muss allenfalls adaptiert werden. Mit diesem Notebook können die einzelnen Verarbeitungsschritte dieses Skripts detailliert nachvollzogen werden. Die Parameter, deren Werte wir bestimmen müssen, heissen:

# %% [markdown]
# ## Setup und Zugriff zu den Bilddaten

# %%
#Import python File
import object_extraction as oe

#Import Libraries
from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow
from skimage.measure import label
import os
import logging
import re
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import train_test_split
import shutil
from IPython.display import FileLink

# %%
pr = 408,230 #PREPROCESSING_RESOLUTION, --preprocessing_resolution
fr = 0.05  #FRACTION_OF_ROWS_TO_REMOVE, --fraction_of_rows_to_remove
fc = 0.0   #FRACTION_OF_COLS_TO_REMOVE, --fraction_of_cols_to_remove
vth = 0.3    #VALUE_THRESHOLD, --value_threshold
es = 8     #EROSION_SIZE, --erosion_size
ds = 10     #DILATION_SIZE, --dilation_size
mpx = 8000 #MINIMUM NUMBER OF PIXELS, --minimum_number_of_pixels
Bilddateiendung = 'jpg' #Dateiendung der Bilder, ohne ".", Achtung: 'jpg' ist nicht 'JPG'
fv=0 #value_to_fill: Wert, mit dem die abgeschnittenen Ränder aufgefüllt werden sollen

pfad_zu_daten = Path('./Gipfel_dunkel')
# Path('./Gipfel_dunkel')
Ausgabepfad = Path("./Output")

# %% [markdown]
# Laden wir ein Bild!

# %%
def show_image(im):
    imshow(im)
    ax = plt.gca()
    ax.set_xticks([]); ax.set_yticks([]);
    return ax

def choose_an_image():
    """
    Wähle eine Datei aus <pfad_zu_daten> und stelle es dar
    """
    Bilddatei_Liste = pd.Series(pfad_zu_daten.iterdir())
    fn = Bilddatei_Liste.sample(1).values[0]
    im = oe.load_file(fn)
    return im

im = choose_an_image()
show_image(im)
# Out:
# <Axes: >

# %%
from matplotlib.colors import rgb_to_hsv
rgb_to_hsv(im/255.).shape
hsv_im = rgb_to_hsv(im/255.)
channel_medians = np.median(hsv_im, axis=(0,1))
print(channel_medians)
# Out:
# [0.11111111 0.34883721 0.21960784]

# %% [markdown]
# # Adaption der Parameter
# Wir haben Zugriff auf die Bilddaten, nun möchten wir die Parameterwerte auswählen, welche die Objekte gut vom Hintergrund isolieren. Die Funktion `process_file` erledigt das.
#
# Das Vorgehen dabei ist Folgendes:
# 1. Lade das Bild und reduziere die Auflösung: Parameter **`pr`** enthält ein Tupel mit der Anzahl Pixelzeilen und der Anzahl Pixelspalten. Dies dient hauptsächlich der Beschleunigung der weiteren Verarbeitung.
# 2. Schneide jeweils an den Rändern einen Prozentsatz der Zeilen bzw. Spalten ab: Der Prozentsatz der Zeilen ist durch **`fr`**, jener der Spalten durch **`fc`** gegeben.
# 3. Es wird ein Schwellwert auf den value-Wert (in der hsv-Farbdarstellung) angewendet, um den dunklen (`sign`=+1) oder hellen (`sign`=-1) Hintergrund zu erkennen. Dies ergibt eine Maske (binärer Array), welcher Vordergrundpixel identifiziert.
# 4. Es werden kleine Artefakte auf der Maske durch Erosion und Dilatation entfernt. Die Parameter `es` und `ds` geben die Grössen der Erosions- und Dilatationsmasken an.
# 5. Die Objekte werden ausgeschnitten, d.h. separate Objekte werden identifiziert, und um jedes Objekt wird eine enge rechteckige *Bounding Box* gesetzt.
# 6. Sollte der Ausschnitt weniger als **`mpx`** Pixel enthalten, wird er verworfen. Dies ist nötig, weil manchmal Reflexionen o.ä. zusätzliche kleine Ausschnitte erzeugen, welche aber nicht ein Objekt enthalten.
# 7. Ein neues Bild wird abgespeichert, welches nur noch das (ausgeschnittene) Bildelement enthält.
#
#
# Wenn dies gelingt, sind die Bilder in einer geeigneten Form für Deep Learning.
#
# Im Folgenden wird dieser Vorgang für ein (von Ihnen gewähltes) Bild durchgeführt. Passen Sie die Parameter so an, dass die Extraktion gut gelingt.
# Die Parameter sollten Sie hier anpassen:

# %% [markdown]
# ### Schritt 0: Laden des Bildes

# %%
show_image(im);
aufloesung = im.shape
print(f'Das Bild hat folgende angepasste Auflösung: Höhe: {aufloesung[0]}px, Breite: {aufloesung[1]}px, Farbkanäle: {aufloesung[2]}')
# Out:
# Das Bild hat folgende angepasste Auflösung: Höhe: 5712px, Breite: 3213px, Farbkanäle: 3

# %% [markdown]
# ### Schritt 1: Auflösungsreduktion

# %% [markdown]
# Die Bilder können zu hoch aufgelöst sein für unsere Anwendung, wodurch sich die Rechenzeit der folgenden Operationen vervielfacht. Die Vorverarbeitungsroutine `object_extraction.py` beginnt daher damit, mit der `--preprocessing_resolution` (oder `-pr`) das Bild zu verkleinern:

# %%
#im_resized = (255*resize(im,pr)).astype('uint8') #Wird doch schon in load_file gemacht...
im_resized = oe.resize(im,pr)
show_image(im_resized);
angepasste_Aufloesung = im_resized.shape
print(f'Das Bild hat folgende angepasste Auflösung: Höhe: {angepasste_Aufloesung[0]}px, Breite: {angepasste_Aufloesung[1]}px, Farbkanäle: {angepasste_Aufloesung[2]}')
# Out:
# Das Bild hat folgende angepasste Auflösung: Höhe: 408px, Breite: 230px, Farbkanäle: 3

# %% [markdown]
# ## Schritt 2: Ränder abschneiden
# Als nächstes müssen ev. die Ränder des Bildes überdeckt werden. Damit können Artefakte beseitigt werden, z.B. wenn der schwarze Hintergrund nicht bis an den Rand des Bildes reicht. `fraction_of_rows_to_remove` und `fraction_of_cols_to_remove` geben an, wieviel abgeschnitten wird. Aufgefüllt werden die Pixel mit dem Wert `value_to_fill=0` (in allen Farbkanälen).

# %% [markdown]
# 📋 **Aufgabe 1:** Finden Sie für Ihre Bilder passende Werte für `fraction_of_rows_to_remove` und `fraction_of_cols_to_remove`.

# %%
im_filled = oe.fill_borders(im_resized,value_to_fill=fv,fraction_of_rows_to_remove=fr,
                         fraction_of_cols_to_remove=fc)
show_image(im_filled);

# %% [markdown]
# ## Schritt 3: Hintergrundschwellwert bestimmen
# Wählen Sie zunächst sign=+1 für Schwarzen Hintergrund oder sign=-1 für weissen Hintergrund.
#
# Als nächstes soll ein Schwellwert im Farbraum das Objekt vom Hintergrund isolieren. Wir arbeiten im *hsv*-Raum: hue, saturation und value sind die drei Farbdimensionen, für welche jeweils ein Mindestwert (für sign=+1) bzw. Maximalwert (für sign=-1) für Vordergrundpixel festgelegt werden kann. Berechnet wird konkret: `mask = sign*im_hsv[:,:,2]>value_schwellwert*sign` (etc.).

# %% [markdown]
# 📋 **Aufgabe 2:** Finden Sie Werte für `hue_schwellwert`, `saturation_schwellwert` und `value_schwellwert` so, dass die Maske möglichst gut zum Objektumriss passt. Bei der Wahl der Schwellwerte muss man aufpassen, dass sie nicht nur auf diesem einen Bild passen, sondern auch auf allen anderen!

# %%
mask = oe.generate_mask_with_hsv_threshold(im_filled, hue_threshold=None,saturation_threshold=None,value_threshold=vth) #0-255, 0-255, 0-1

plt.figure();show_image(mask);

masked_image = oe.create_masked_image(im_filled,mask)
plt.figure();show_image(masked_image);

# %% [markdown]
# ## Schritt 4: Erosion und Dilatationsfilgergrössen bestimmen

# %% [markdown]
# Wenn Hintergrundregionen übrigbleiben, dann ergibt dies zusätzliche Trainingsbilder, welche nicht einer Klasse zugeordnet sind- und es kostet auch viel Rechenzeit. Kleine, isolierte Maskenpixel möchten wir daher als nächstes durch Erosion entfernen.

# %% [markdown]
# 📋 **Aufgabe 3:** Finden Sie Werte für es und ds, welche möglichst keine vereinzelte Hintergrundpixel in der Maske übrig lassen:

# %%
morphed_mask = oe.morphology_transform(mask,shape = oe.square,erosion_size=es,dilation_size=ds)
show_image(morphed_mask);

# %% [markdown]
# Ev. haben Sie auch Glück, und Sie sehen oben nur eine einzige zusammenhängende gelbe Struktur? Dann können Sie die Werte so lassen, wie sie sind!

# %% [markdown]
# `create_mask` ist nun einfach eine Routine, welche die obigen Schritte der Maskenbildung zusammenfasst. Sie sollte das gleiche Bild `morphed_mask` wie oben erstellen:

# %%
morphed_mask,im_filled  = oe.create_mask(im_resized,
                                      fraction_of_rows_to_remove=fr,fraction_of_cols_to_remove=fc,
                                      hue_threshold=None,saturation_threshold=None,value_threshold=vth,
                                      erosion_size=es,dilation_size=ds)
show_image(morphed_mask);

# %% [markdown]
# Nun wird die Maske benutzt, um das Objekt (oder die Objekte) aus dem Bild auszuschneiden:

# %%
masked_image = oe.create_masked_image(im_filled,morphed_mask)
show_image(masked_image);
#masked_image.shape

# %% [markdown]
# Hier sollte ein Bild zu sehen sein, welches einen komplett schwarzen Hintergrund hat, und nur die relevanten Objekte zeigt. Als nächstes hätten wir gerne von jedem Objekt ein separates Bild, so dass wir darauf unseren Bildklassifikator trainieren können.

# %% [markdown]
# ## Schritt 5: Objekte ausschneiden
# Wir haben den Hintergrund eliminiert. Damit ist es nun leichter, die Objekte voneinander zu trennen. Die Funktion "label" von [scikit-image](https://scikit-image.org/docs/stable/api/skimage.measure.html#skimage.measure.label) tut dies:

# %%
label_img = label(morphed_mask)
show_image(label_img)
plt.colorbar();

# %% [markdown]
# Falls das obige Bild wie eine Maske aussieht: Vermutlich liegt nur ein Bild vor- deren Pixel wird dann mit dem Wert "1" aufgefüllt. Wäre ein zweites Objekt vorhanden, würde dieses mit dem Wert "2" aufgefüllt und wäre in einer leicht anderen Farbe sichtbar. Aus diesem gelabelten Bild werden nun Teilbilder extrahiert, welche jeweils nur ein Objekt enthalten:

# %%
label_img.shape,masked_image.shape
# Out:
# ((408, 230), (408, 230, 3))

# %%
regionlist,regions = oe.extract_regions(label_img,masked_image,fraction_of_rows_to_remove=fr)
regionen = len(regionlist)
print(f"Das Bild hat {regionen} Regionen.")
# Out:
# Das Bild hat 6 Regionen.

# %% [markdown]
# Alle obigen Schritte sind in der Funktion image_preprocessing zusammengefasst:

# %%
regionlist,regions,mask,masked_image = oe.image_preprocessing(im,
                                                           fraction_of_rows_to_remove=fr,
                                                           fraction_of_cols_to_remove=fc,
                                                           value_threshold=vth,
                                                           erosion_size=es,dilation_size=ds)
print(f"Anzahl gefundene Bereiche: {len(regionlist)}")
# Out:
# Anzahl gefundene Bereiche: 809

# %%
label_img.shape,masked_image.shape,len(regions)
# Out:
# ((408, 230), (5712, 3213, 3), 809)

# %%
show_image(masked_image)
# Out:
# <Axes: >

# %% [markdown]
# ## Schritt 6: Kleine Objekte (Artefakte) ignorieren
# Manchmal sind einige der gefundenen Regionen viel zu klein, um echte Objekte zu sein. Es gibt eine Option `--minimum-number-of-pixels` bzw. `-mpx`, welche Regionen unterdrückt, welche zu klein sind. Die Grösse der Regionen wird hier ausgegeben, um diesen Parameter gut einstellen zu können.

# %%
if len(regions)<10:
    for ireg,reg in enumerate(regions):
        print(f"Region {ireg}: {int(reg.area):>6}")
else:
    #for ireg,reg in enumerate(regions):
    #    print(f"{int(reg.area):<3} ",end='')

    plt.hist([reg.area for reg in regions],bins=np.logspace(1,6,100))
    plt.gca().set_xscale('log') #ev. sieht man damit etwas mehr
    plt.gca().set_yscale('log')

# %% [markdown]
# Schauen wir uns die extrahierten Regionen an - es sollten nicht zu viele sein.

# %% [markdown]
# 📋 **Aufgabe 4:** Bestimmen Sie einen geeigneten Wert von `mpx`, so dass nur relevante Regionen übrig bleiben. Tragen Sie den Wert in die Parameterliste ein.
#
# Der `mpx`-Wert wird in der nächsten Zelle verwendet:

# %%
relevante_regionen =  [reg for reg in regions if reg.area >= mpx]
if len(relevante_regionen)<20:
    for reg in relevante_regionen:
        plt.figure();
        plt.imshow(reg.image_intensity);
        plt.xticks([]);plt.yticks([]) # Wir brauchen keine x- und y-Achse
else:
    print(f"Das würde {len(relevante_regionen)} Graphiken erzeugen! Ich mache lieber nichts...")

# %% [markdown]
# Sehen Sie hier Ihre extrahierten Objekte, und keine (oder nur wenige) Artefakte?
# Ja?
# Wirklich?
# **Cool!**
# Dann können wir nun versuchen, alle weiteren Daten zu verarbeiten. Das kann  in der Kommandozeile wie folgt erreicht werden:

# %%
imgfns = list(Path('./Gipfel_dunkel').glob('*.'+Bilddateiendung))
#path('./Gipfel_dunkel')
imgfns[:5]
# Out:
# [PosixPath('Gipfel_dunkel/Laugengipfel_low_light_34.jpg'),
#  PosixPath('Gipfel_dunkel/Laugengipfel_low_light_20.jpg'),
#  PosixPath('Gipfel_dunkel/Laugengipfel_low_light_21.jpg'),
#  PosixPath('Gipfel_dunkel/Laugengipfel_low_light_35.jpg'),
#  PosixPath('Gipfel_dunkel/Laugengipfel_low_light_09.jpg')]

# %%
yta = True #args.yes_to_all
outputpath = Ausgabepfad
outputpath_Ausschnitte = os.path.join(outputpath, 'Ausschnitte')
oe.ask_path_creation(outputpath_Ausschnitte,yes_to_all=yta)

fraction_of_rows_to_remove = float(fr)
fraction_of_cols_to_remove = float(fc)
preprocessing_resolution = [int(f) for f in pr]
# print('preprocessing_resolution ',preprocessing_resolution )
erosion_size= oe.intOrNone(es)
dilation_size= oe.intOrNone(ds)
hue_threshold = None#intOrNone(hth)
value_threshold = vth#None#intOrNone(vth)
saturation_threshold = None #intOrNone(sth)
write_summary_file = False
num_cores = 1 #int(args.num_cores)
minimum_number_of_pixels = int(mpx)

kwargs = {'fraction_of_rows_to_remove':fr,'fraction_of_cols_to_remove':fc,'hue_threshold':hue_threshold,'saturation_threshold':saturation_threshold,'value_threshold':vth,
        'erosion_size':erosion_size,'dilation_size':dilation_size,'min_num_pixels':minimum_number_of_pixels,'outputpath':outputpath_Ausschnitte,'preprocessing_resolution':preprocessing_resolution}
# Out:
# INFO:object_extraction:Der Pfad Output/Ausschnitte konnte nicht gefunden werden.
# INFO:object_extraction:Pfad Output/Ausschnitte wurde erstellt

# %%
NrFilesToProcess = None # None eingeben für alle
kwargs['num_cores']=1
logger = logging.getLogger(__name__)
logger.setLevel(logging.INFO)
oe.main(imgfns[:NrFilesToProcess],kwargs)
# Out:
# Processing images:   0%|          | 0/92 [00:00<?, ?it/s]INFO:object_extraction:Shapes of extracted regions: [(367, 190, 3)]
# Processing images:   1%|          | 1/92 [00:02<03:22,  2.23s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(367, 187, 3)]
# Processing images:   2%|▏         | 2/92 [00:04<03:09,  2.11s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(342, 182, 3)]
# Processing images:   3%|▎         | 3/92 [00:06<03:03,  2.07s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(367, 179, 3)]
# Processing images:   4%|▍         | 4/92 [00:08<03:00,  2.05s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(367, 180, 3)]
# Processing images:   5%|▌         | 5/92 [00:10<02:57,  2.04s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(16, 18, 3), (344, 175, 3)]
# INFO:object_extraction:skipping region: num_pix=267,shape:(16, 18, 3),area:267.0, as num_pix is < 8000
# Processing images:   7%|▋         | 6/92 [00:12<02:54,  2.03s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(367, 168, 3)]
# Processing images:   8%|▊         | 7/92 [00:14<02:51,  2.02s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(367, 170, 3)]
# Processing images:   9%|▊         | 8/92 [00:16<02:46,  1.98s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(367, 173, 3)]
# Processing images:  10%|▉         | 9/92 [00:18<02:44,  1.98s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(13, 21, 3), (251, 199, 3), (35, 35, 3)]
# INFO:object_extraction:skipping region: num_pix=269,shape:(13, 21, 3),area:269.0, as num_pix is < 8000
# INFO:object_extraction:skipping region: num_pix=1043,shape:(35, 35, 3),area:1043.0, as num_pix is < 8000
# Processing images:  11%|█         | 10/92 [00:20<02:41,  1.97s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(367, 163, 3), (11, 11, 3)]
# INFO:object_extraction:skipping region: num_pix=121,shape:(11, 11, 3),area:121.0, as num_pix is < 8000
# Processing images:  12%|█▏        | 11/92 [00:22<02:38,  1.96s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(367, 216, 3)]
# Processing images:  13%|█▎        | 12/92 [00:24<02:37,  1.97s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(367, 199, 3), (24, 31, 3), (10, 11, 3)]
# INFO:object_extraction:skipping region: num_pix=478,shape:(24, 31, 3),area:478.0, as num_pix is < 8000
# INFO:object_extraction:skipping region: num_pix=110,shape:(10, 11, 3),area:110.0, as num_pix is < 8000
# Processing images:  14%|█▍        | 13/92 [00:26<02:36,  1.98s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(16, 21, 3), (246, 199, 3), (35, 30, 3)]
# INFO:object_extraction:skipping region: num_pix=268,shape:(16, 21, 3),area:268.0, as num_pix is < 8000
# INFO:object_extraction:skipping region: num_pix=811,shape:(35, 30, 3),area:811.0, as num_pix is < 8000
# Processing images:  15%|█▌        | 14/92 [00:28<02:33,  1.97s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(367, 184, 3)]
# Processing images:  16%|█▋        | 15/92 [00:29<02:31,  1.96s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(367, 199, 3), (10, 13, 3)]
# INFO:object_extraction:skipping region: num_pix=130,shape:(10, 13, 3),area:130.0, as num_pix is < 8000
# Processing images:  17%|█▋        | 16/92 [00:32<02:30,  1.98s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(367, 205, 3)]
# Processing images:  18%|█▊        | 17/92 [00:34<02:29,  2.00s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(160, 148, 3), (28, 27, 3)]
# INFO:object_extraction:skipping region: num_pix=489,shape:(28, 27, 3),area:489.0, as num_pix is < 8000
# Processing images:  20%|█▉        | 18/92 [00:35<02:26,  1.98s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(367, 187, 3), (8, 19, 3)]
# INFO:object_extraction:skipping region: num_pix=190,shape:(8, 19, 3),area:190.0, as num_pix is < 8000
# Processing images:  21%|██        | 19/92 [00:37<02:22,  1.95s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(331, 155, 3)]
# Processing images:  22%|██▏       | 20/92 [00:39<02:21,  1.97s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(367, 214, 3), (12, 6, 3)]
# INFO:object_extraction:skipping region: num_pix=72,shape:(12, 6, 3),area:72.0, as num_pix is < 8000
# Processing images:  23%|██▎       | 21/92 [00:41<02:19,  1.97s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(326, 167, 3), (51, 54, 3), (12, 14, 3), (29, 23, 3)]
# INFO:object_extraction:skipping region: num_pix=1586,shape:(51, 54, 3),area:1586.0, as num_pix is < 8000
# INFO:object_extraction:skipping region: num_pix=166,shape:(12, 14, 3),area:166.0, as num_pix is < 8000
# INFO:object_extraction:skipping region: num_pix=525,shape:(29, 23, 3),area:525.0, as num_pix is < 8000
# Processing images:  24%|██▍       | 22/92 [00:43<02:18,  1.98s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(367, 184, 3)]
# Processing images:  25%|██▌       | 23/92 [00:45<02:16,  1.97s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(12, 38, 3), (10, 10, 3), (356, 161, 3)]
# INFO:object_extraction:skipping region: num_pix=521,shape:(12, 38, 3),area:521.0, as num_pix is < 8000
# INFO:object_extraction:skipping region: num_pix=100,shape:(10, 10, 3),area:100.0, as num_pix is < 8000
# Processing images:  26%|██▌       | 24/92 [00:47<02:13,  1.97s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(170, 103, 3), (28, 22, 3)]
# INFO:object_extraction:skipping region: num_pix=455,shape:(28, 22, 3),area:455.0, as num_pix is < 8000
# Processing images:  27%|██▋       | 25/92 [00:49<02:11,  1.96s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(367, 189, 3)]
# Processing images:  28%|██▊       | 26/92 [00:51<02:09,  1.97s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(8, 10, 3), (314, 144, 3)]
# INFO:object_extraction:skipping region: num_pix=100,shape:(8, 10, 3),area:100.0, as num_pix is < 8000
# Processing images:  29%|██▉       | 27/92 [00:53<02:07,  1.96s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(367, 179, 3)]
# Processing images:  30%|███       | 28/92 [00:55<02:06,  1.97s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(367, 181, 3)]
# Processing images:  32%|███▏      | 29/92 [00:57<02:05,  1.99s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(367, 180, 3), (11, 11, 3)]
# INFO:object_extraction:skipping region: num_pix=121,shape:(11, 11, 3),area:121.0, as num_pix is < 8000
# Processing images:  33%|███▎      | 30/92 [00:59<02:01,  1.96s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(367, 214, 3)]
# Processing images:  34%|███▎      | 31/92 [01:01<01:59,  1.96s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(321, 167, 3), (11, 10, 3), (29, 23, 3)]
# INFO:object_extraction:skipping region: num_pix=110,shape:(11, 10, 3),area:110.0, as num_pix is < 8000
# INFO:object_extraction:skipping region: num_pix=533,shape:(29, 23, 3),area:533.0, as num_pix is < 8000
# Processing images:  35%|███▍      | 32/92 [01:03<01:57,  1.96s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(176, 119, 3), (16, 18, 3)]
# INFO:object_extraction:skipping region: num_pix=222,shape:(16, 18, 3),area:222.0, as num_pix is < 8000
# Processing images:  36%|███▌      | 33/92 [01:05<01:54,  1.94s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(136, 146, 3), (28, 22, 3)]
# INFO:object_extraction:skipping region: num_pix=461,shape:(28, 22, 3),area:461.0, as num_pix is < 8000
# Processing images:  37%|███▋      | 34/92 [01:07<01:53,  1.95s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(367, 175, 3)]
# Processing images:  38%|███▊      | 35/92 [01:09<01:51,  1.95s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(211, 186, 3), (15, 18, 3), (31, 25, 3)]
# INFO:object_extraction:skipping region: num_pix=246,shape:(15, 18, 3),area:246.0, as num_pix is < 8000
# INFO:object_extraction:skipping region: num_pix=600,shape:(31, 25, 3),area:600.0, as num_pix is < 8000
# Processing images:  39%|███▉      | 36/92 [01:11<01:47,  1.93s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(230, 169, 3), (29, 24, 3)]
# INFO:object_extraction:skipping region: num_pix=589,shape:(29, 24, 3),area:589.0, as num_pix is < 8000
# Processing images:  40%|████      | 37/92 [01:13<01:46,  1.93s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(367, 187, 3)]
# Processing images:  41%|████▏     | 38/92 [01:15<01:44,  1.94s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(158, 147, 3), (14, 22, 3), (11, 10, 3), (22, 26, 3), (32, 11, 3)]
# INFO:object_extraction:skipping region: num_pix=256,shape:(14, 22, 3),area:256.0, as num_pix is < 8000
# INFO:object_extraction:skipping region: num_pix=110,shape:(11, 10, 3),area:110.0, as num_pix is < 8000
# INFO:object_extraction:skipping region: num_pix=384,shape:(22, 26, 3),area:384.0, as num_pix is < 8000
# INFO:object_extraction:skipping region: num_pix=291,shape:(32, 11, 3),area:291.0, as num_pix is < 8000
# Processing images:  42%|████▏     | 39/92 [01:17<01:42,  1.94s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(367, 176, 3)]
# Processing images:  43%|████▎     | 40/92 [01:18<01:41,  1.95s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(313, 188, 3)]
# Processing images:  45%|████▍     | 41/92 [01:20<01:39,  1.96s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(286, 187, 3), (14, 14, 3)]
# INFO:object_extraction:skipping region: num_pix=185,shape:(14, 14, 3),area:185.0, as num_pix is < 8000
# Processing images:  46%|████▌     | 42/92 [01:23<01:39,  1.98s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(367, 204, 3)]
# Processing images:  47%|████▋     | 43/92 [01:24<01:36,  1.97s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(228, 169, 3), (29, 24, 3)]
# INFO:object_extraction:skipping region: num_pix=568,shape:(29, 24, 3),area:568.0, as num_pix is < 8000
# Processing images:  48%|████▊     | 44/92 [01:27<01:36,  2.02s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(8, 11, 3), (11, 12, 3), (261, 218, 3), (12, 14, 3), (31, 34, 3)]
# INFO:object_extraction:skipping region: num_pix=110,shape:(8, 11, 3),area:110.0, as num_pix is < 8000
# INFO:object_extraction:skipping region: num_pix=132,shape:(11, 12, 3),area:132.0, as num_pix is < 8000
# INFO:object_extraction:skipping region: num_pix=161,shape:(12, 14, 3),area:161.0, as num_pix is < 8000
# INFO:object_extraction:skipping region: num_pix=937,shape:(31, 34, 3),area:937.0, as num_pix is < 8000
# Processing images:  49%|████▉     | 45/92 [01:29<01:36,  2.05s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(8, 19, 3), (367, 179, 3), (21, 13, 3)]
# INFO:object_extraction:skipping region: num_pix=190,shape:(8, 19, 3),area:190.0, as num_pix is < 8000
# INFO:object_extraction:skipping region: num_pix=242,shape:(21, 13, 3),area:242.0, as num_pix is < 8000
# Processing images:  50%|█████     | 46/92 [01:31<01:33,  2.04s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(303, 169, 3), (12, 11, 3)]
# INFO:object_extraction:skipping region: num_pix=130,shape:(12, 11, 3),area:130.0, as num_pix is < 8000
# Processing images:  51%|█████     | 47/92 [01:33<01:30,  2.01s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(170, 112, 3), (28, 22, 3)]
# INFO:object_extraction:skipping region: num_pix=457,shape:(28, 22, 3),area:457.0, as num_pix is < 8000
# Processing images:  52%|█████▏    | 48/92 [01:35<01:27,  1.98s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(103, 154, 3)]
# Processing images:  53%|█████▎    | 49/92 [01:36<01:23,  1.95s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(170, 82, 3)]
# Processing images:  54%|█████▍    | 50/92 [01:38<01:21,  1.94s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(367, 201, 3), (11, 10, 3)]
# INFO:object_extraction:skipping region: num_pix=110,shape:(11, 10, 3),area:110.0, as num_pix is < 8000
# Processing images:  55%|█████▌    | 51/92 [01:40<01:18,  1.92s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(367, 186, 3)]
# Processing images:  57%|█████▋    | 52/92 [01:42<01:17,  1.94s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(159, 147, 3), (11, 13, 3), (10, 13, 3), (12, 16, 3), (28, 17, 3), (23, 23, 3), (15, 10, 3), (40, 31, 3), (19, 24, 3)]
# INFO:object_extraction:skipping region: num_pix=140,shape:(11, 13, 3),area:140.0, as num_pix is < 8000
# INFO:object_extraction:skipping region: num_pix=130,shape:(10, 13, 3),area:130.0, as num_pix is < 8000
# INFO:object_extraction:skipping region: num_pix=174,shape:(12, 16, 3),area:174.0, as num_pix is < 8000
# INFO:object_extraction:skipping region: num_pix=359,shape:(28, 17, 3),area:359.0, as num_pix is < 8000
# INFO:object_extraction:skipping region: num_pix=441,shape:(23, 23, 3),area:441.0, as num_pix is < 8000
# INFO:object_extraction:skipping region: num_pix=146,shape:(15, 10, 3),area:146.0, as num_pix is < 8000
# INFO:object_extraction:skipping region: num_pix=842,shape:(40, 31, 3),area:842.0, as num_pix is < 8000
# INFO:object_extraction:skipping region: num_pix=429,shape:(19, 24, 3),area:429.0, as num_pix is < 8000
# Processing images:  58%|█████▊    | 53/92 [01:44<01:16,  1.97s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(162, 78, 3), (43, 20, 3)]
# INFO:object_extraction:skipping region: num_pix=647,shape:(43, 20, 3),area:647.0, as num_pix is < 8000
# Processing images:  59%|█████▊    | 54/92 [01:46<01:15,  1.98s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(367, 177, 3), (25, 12, 3)]
# INFO:object_extraction:skipping region: num_pix=255,shape:(25, 12, 3),area:255.0, as num_pix is < 8000
# Processing images:  60%|█████▉    | 55/92 [01:48<01:12,  1.96s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(226, 146, 3), (14, 14, 3), (11, 12, 3), (10, 12, 3), (35, 30, 3)]
# INFO:object_extraction:skipping region: num_pix=186,shape:(14, 14, 3),area:186.0, as num_pix is < 8000
# INFO:object_extraction:skipping region: num_pix=128,shape:(11, 12, 3),area:128.0, as num_pix is < 8000
# INFO:object_extraction:skipping region: num_pix=120,shape:(10, 12, 3),area:120.0, as num_pix is < 8000
# INFO:object_extraction:skipping region: num_pix=704,shape:(35, 30, 3),area:704.0, as num_pix is < 8000
# Processing images:  61%|██████    | 56/92 [01:51<01:14,  2.07s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(367, 187, 3)]
# Processing images:  62%|██████▏   | 57/92 [01:53<01:12,  2.06s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(68, 89, 3), (93, 211, 3), (54, 29, 3), (29, 12, 3)]
# INFO:object_extraction:skipping region: num_pix=2155,shape:(68, 89, 3),area:2155.0, as num_pix is < 8000
# INFO:object_extraction:skipping region: num_pix=1073,shape:(54, 29, 3),area:1073.0, as num_pix is < 8000
# INFO:object_extraction:skipping region: num_pix=274,shape:(29, 12, 3),area:274.0, as num_pix is < 8000
# Processing images:  63%|██████▎   | 58/92 [01:55<01:09,  2.05s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(235, 145, 3), (11, 10, 3), (15, 13, 3), (29, 16, 3)]
# INFO:object_extraction:skipping region: num_pix=110,shape:(11, 10, 3),area:110.0, as num_pix is < 8000
# INFO:object_extraction:skipping region: num_pix=187,shape:(15, 13, 3),area:187.0, as num_pix is < 8000
# INFO:object_extraction:skipping region: num_pix=395,shape:(29, 16, 3),area:395.0, as num_pix is < 8000
# Processing images:  64%|██████▍   | 59/92 [01:57<01:06,  2.02s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(160, 99, 3)]
# Processing images:  65%|██████▌   | 60/92 [01:58<01:03,  2.00s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(142, 191, 3), (12, 17, 3), (12, 11, 3), (10, 11, 3), (16, 12, 3), (11, 10, 3), (15, 9, 3)]
# INFO:object_extraction:skipping region: num_pix=196,shape:(12, 17, 3),area:196.0, as num_pix is < 8000
# INFO:object_extraction:skipping region: num_pix=130,shape:(12, 11, 3),area:130.0, as num_pix is < 8000
# INFO:object_extraction:skipping region: num_pix=110,shape:(10, 11, 3),area:110.0, as num_pix is < 8000
# INFO:object_extraction:skipping region: num_pix=151,shape:(16, 12, 3),area:151.0, as num_pix is < 8000
# INFO:object_extraction:skipping region: num_pix=110,shape:(11, 10, 3),area:110.0, as num_pix is < 8000
# INFO:object_extraction:skipping region: num_pix=124,shape:(15, 9, 3),area:124.0, as num_pix is < 8000
# Processing images:  66%|██████▋   | 61/92 [02:00<01:01,  1.98s/it]/Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:161: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = erosion(mask.copy(),shape(erosion_size))
# /Users/remofankhauser/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:162: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   mask = dilation(mask,shape(dilation_size))
# INFO:object_extraction:Shapes of extracted regions: [(8, 12, 3), (367, 205, 3), (10, 10, 3)]
# INFO:object_extraction:skipping region: num_pix=120,shape:(8, 12, 3),area:120.0, as num_pix is < 8000
# INFO:object_extraction:skipping region: num_pix=100,shape:(10, 10, 3),area:100.0, as num_pix is < 8000
# Processing images:  67%|██████▋   | 62/92 [02:04<01:00,  2.01s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[324], line 5
#       3 logger = logging.getLogger(__name__)
#       4 logger.setLevel(logging.INFO)
# ----> 5 oe.main(imgfns[:NrFilesToProcess],kwargs)
#
# File ~/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:526, in main(imgfns, kwargs)
#     524 if 'write_summary_file' in kwargs: del kwargs['write_summary_file']
#     525 for fn in tqdm(imgfns, desc="Processing images"):
# --> 526     continue_the_loop = process_file(fn, **kwargs)
#     527     if not continue_the_loop:
#     528         break
#
# File ~/Github/MSc_WI_DSCI/03_Objektextraktion/object_extraction.py:421, in process_file(fn, fraction_of_rows_to_remove, fraction_of_cols_to_remove, hue_threshold, saturation_threshold, value_threshold, erosion_size, dilation_size, min_num_pixels, outputpath, write_summary_file, preprocessing_resolution, value_to_fill)
#     419 if preprocessing_resolution is not None:
#     420     if preprocessing_resolution[0]< im.shape[0] and preprocessing_resolution[1]< im.shape[1]:
# --> 421         im = (255*resize(im,preprocessing_resolution)).astype('uint8') #resize ergibt ein Bild im mit Wertebereich (0,1)
#     422     else:
#     423         logger.warning(f'preprocessing resolution {preprocessing_resolution} ist nicht kleiner als die ursprÃƒÂ¼ngliche BildgrÃƒÂ¶sse {im.shape}. BildgrÃƒÂ¶sse wird nicht verÃƒÂ¤ndert')
#
# File ~/Github/MSc_WI_DSCI/.venv/lib/python3.10/site-packages/skimage/transform/_warps.py:196, in resize(image, output_shape, order, mode, cval, clip, preserve_range, anti_aliasing, anti_aliasing_sigma)
#     191         elif np.any((anti_aliasing_sigma > 0) & (factors <= 1)):
#     192             warn(
#     193                 "Anti-aliasing standard deviation greater than zero but "
#     194                 "not down-sampling along all axes"
#     195             )
# --> 196     filtered = ndi.gaussian_filter(
#     197         image, anti_aliasing_sigma, cval=cval, mode=ndi_mode
#     198     )
#     199 else:
#     200     filtered = image
#
# File ~/Github/MSc_WI_DSCI/.venv/lib/python3.10/site-packages/scipy/ndimage/_filters.py:379, in gaussian_filter(input, sigma, order, output, mode, cval, truncate, radius, axes)
#     377 if len(axes) > 0:
#     378     for axis, sigma, order, mode, radius in axes:
# --> 379         gaussian_filter1d(input, sigma, axis, order, output,
#     380                           mode, cval, truncate, radius=radius)
#     381         input = output
#     382 else:
#
# File ~/Github/MSc_WI_DSCI/.venv/lib/python3.10/site-packages/scipy/ndimage/_filters.py:277, in gaussian_filter1d(input, sigma, axis, order, output, mode, cval, truncate, radius)
#     275 # Since we are calling correlate, not convolve, revert the kernel
#     276 weights = _gaussian_kernel1d(sigma, order, lw)[::-1]
# --> 277 return correlate1d(input, weights, axis, output, mode, cval, 0)
#
# File ~/Github/MSc_WI_DSCI/.venv/lib/python3.10/site-packages/scipy/ndimage/_filters.py:134, in correlate1d(input, weights, axis, output, mode, cval, origin)
#     130     raise ValueError('Invalid origin; origin must satisfy '
#     131                      '-(len(weights) // 2) <= origin <= '
#     132                      '(len(weights)-1) // 2')
#     133 mode = _ni_support._extend_mode_to_code(mode)
# --> 134 _nd_image.correlate1d(input, weights, axis, output, mode, cval,
#     135                       origin)
#     136 return output
#
# KeyboardInterrupt:

# %% [markdown]
# Alternativ kann die Ausgabe der folgenden Zelle genutzt werden, um in der Kommandozeile das Skript [object_extraction.py](https://gitlab.ost.ch/beat.toedtli/learning-city-lab/-/blob/main/1_object_extraction/object_extraction.py?ref_type=heads)[im Verzeichnis [1_object_extraction](https://gitlab.ost.ch/beat.toedtli/learning-city-lab/-/tree/main/1_object_extraction?ref_type=heads) auszuführen.

# %%
##cmd = f"python3 '{pfad_zu_object_extraction}/object_extraction.py' \
#-y -o '{Ausgabepfad}' -pr {pr[0]},{pr[1]} -fr {fr} -fc {fc} -es {es} -ds {ds} \
#-vth {vth} -mpx {mpx} f'{pfad_zu_daten_string}/*.{Bilddateiendung}'"
#print("Der Kommandozeilenbefehl lautet:\n",cmd)

# %%
# #Die Ausschnitte sind nun hier:
# print(Ausgabepfad/'Ausschnitte')
# # hier einige Beispiele:
# !ls {'"'+str(Ausgabepfad/'Ausschnitte')+'"'}|head -n 5

# %% [markdown]
# Wir können uns die Ausschnitte anschauen:

# %%
# fn = Ausgabepfad/'Ausschnitte'/'Buttergipfel_light_0_06.jpg'
# if fn.exists():
#     im = plt.imread(fn)
#     show_image(im);

# %% [markdown]
# Bevor wir die Bilder herunterladen, wollen wir sie in Unterordner pro Klasse anordnen.

# %% [markdown]
# # Bilden von Unterordner pro Klasse
# Keras, unsere Deep Learning Bibliothek, hat eine einfache Routine, um Kategorisierte Bilder zu laden: Dazu müssen alle Bilder einer Klasse in einem Unterordner liegen, welcher als Namen die Klassenbezeichnung trägt. Diese Zuordnung kann natürlich von Hand vorgenommen werden. Im Fall des Giraffendatensatzes ist das Klassenlabel aber bereits im Dateinamen der Bilder codiert.

# %% [markdown]
# #### Reguläre Ausdrücke

# %%
# re.sub(r'^([^_]+).*$', r'\1', "Laugengipfel_low_light_0_10.jpg")

# %% [markdown]
# Der reguläre Ausdruck `^([^-]*)-.*$` hat's durchaus in sich, ist aber verständlicher, wenn man folgendes weiss:
# - `^` bezeichnet den Beginn einer Zeichenkette
# - `$` bezeichnet das Ende einer Zeichenkette
# - `.` bezeichnet ein beliebiges Zeichen
# - `*` meint "Null-mal, einmal oder beliebig oft". Gemeint ist hier das Zeichen davor ("."), als "kein oder beliebig viele beliebige Zeichen".
# - `( )` Die Klammern gehören zusammen und bilden eine Gruppe: alle Zeichen dazwischen werden in einer Variablen abgespeichert, welche "\1" heisst. Dies sind die einzigen Zeichen, welche nach der Substitution die verbleibende Zeichenkette ausmachen: Im zweiten Argument von `re.sub` steht, womit ein "gematchtes Muster" (engl. matched pattern) im String ersetzt wird.
# - In eckigen Klammern, `[]`, können Zeichen aufgezählt werden, die auftauchen dürfen. Innerhalb von eckigen Klammern bedeutet `^` *nicht* den Beginn des Strings, sondern eine Negation. Der Ausdruck `[^-]` bezeichnet daher ein beliebiges Zeichen, welches aber nicht das Minuszeichen sein darf.
#
# Insgesamt sagt der Ausdruck `'^([^-]*)-.*$'` also so etwas wie:
# *Eine Zeichenkette matcht, wenn sie mit einer beliebigen Folge von Zeichen beginnt, welche nicht das Zeichen "-" ist, gefolgt von einem Minuszeichen. Diese Zeichen vor dem Minus bilden die Gruppe 1. Nach dieser Gruppe muss also ein "-" folgen, und danach dürfen noch beliebig viele beliebige Zeichen folgen bis zum Ende der Zeichenkette. Ersetze diese ganze Zeichenkette (von Anfang bis Ende) mit der Gruppe.*
#
# In einfacherer Sprache ausgedrückt wird die Zeichenkette vor dem Minuszeichen extrahiert- sie enthält ja den Klassennamen.

# %% [markdown]
# #### Pandas DataFrames
# Pandas DataFrames sind sehr nützliche tabellenartige Strukturen. Sie eignen sich v.a. für die Datenanalyse und Visualisierung von strukturierten Daten. Im Folgenden werden diese genutzt, um das Klassenlabel zu bestimmen, welches für die Erstellung der Baumstruktur nützlich ist.

# %%
#volle_Dateinamen = [full_file_name for full_file_name in (Ausgabepfad/'Ausschnitte').glob('*.'+Bilddateiendung)]
#Basisnamen =  [full_file_name for full_file_name in (Ausgabepfad/'Ausschnitte').glob('*.'+Bilddateiendung)]

#Klassenlabel = [re.sub(r'^([^_]+).*$', r'\1', bn.name) for bn in Basisnamen] #Wende den regulären Ausdruck an
#df = pd.DataFrame({'Dateiname':volle_Dateinamen,'Basisname':Basisnamen,'Klassenlabel':Klassenlabel})
#df


#Erzeuge trrain und testset aus allen Bildern und nicht nur aus Ausschnitten
# pfad_zu_bilder = Path('../02_Alle_Gipfel')

# volle_Dateinamen = [full_file_name for full_file_name in (pfad_zu_bilder).glob('*.'+Bilddateiendung)]
# Basisnamen =  [full_file_name for full_file_name in (pfad_zu_bilder).glob('*.'+Bilddateiendung)]

# Klassenlabel = [re.sub(r'^([^_]+).*$', r'\1', bn.name) for bn in Basisnamen] #Wende den regulären Ausdruck an
# df = pd.DataFrame({'Dateiname':volle_Dateinamen,'Basisname':Basisnamen,'Klassenlabel':Klassenlabel})
# df

# %% [markdown]
# #### Train-Test-Split
# An dieser Stelle lohnt es sich, kurz innezuhalten: Unsere grandiose Strategie ist es, aus Bildern Objekte zu extrahieren und auf diesen dann ein Modell zu trainieren. Aber wir können nicht alle Daten als Trainingsdaten verwenden, sonst haben wir nichts mehr, um die *Generalisierungsfähigkeit* unseres Modells zu messen!
# Die Realität ist, dass wir nur ungern später nochmals neue Daten aufnehmen wollen. Die Liste in `df` oben ist alles, was uns zur Verfügung steht. Es macht daher Sinn, bereits jetzt einen Teil dieser Daten zurückzulegen und zu *schwören* diese Daten nicht für das Training zu benutzen. Wir brauchen ca. 20% *frische* Daten, an denen wir die Verallgemeinerungsfähigkeit unseres Modells überprüfen können.
# [Scikit-Learn](https://scikit-learn.org) bietet uns [hier](https://scikit-learn.org/stable/auto_examples/model_selection/plot_cv_indices.html#sphx-glr-auto-examples-model-selection-plot-cv-indices-py) verschiedene Strategien an, wie wir aus unseren Trainingsdaten einen Testdatensatz absondern können. Wir könnten einfach [zufällig splitten](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.ShuffleSplit.html#sklearn.model_selection.ShuffleSplit). Das ist naiv. Lieber eine [k-fache Kreuzvalidierung](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.KFold.html#sklearn.model_selection.KFold). Aber was, wenn zufälligerweise eine Klasse nur im Testdatensatz auftaucht, und gar nicht im Trainingsdatensatz?! Also [stratifizieren](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.StratifiedKFold.html#sklearn.model_selection.StratifiedKFold) wir. Ok- und was ist, wenn wir überprüfen wollen, dass wir in Bezug auf eine bestimmte Untergruppierung (z.B. nach Geschlecht, Ethnie,...) gut von einer Gruppe auf eine andere verallgemeinern können müssen? Dann darf eine [Gruppe nur in einem Fold vorkommen](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.StratifiedGroupKFold.html#sklearn.model_selection.StratifiedGroupKFold). Sie sehen- richtig zu splitten kann herausfordernd sein!
# Hier jedenfalls möchten wir zumindest stratifizieren. Wir nehmen mal [StratifiedKFold](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.StratifiedKFold.html#sklearn.model_selection.StratifiedKFold), um unsere Daten zu splitten.

# %%
# Xtrain,Xtest,ytrain,ytest = train_test_split(df[['Dateiname','Basisname']],df.Klassenlabel,test_size=0.2,train_size=0.8,stratify =df.Klassenlabel,random_state=42)
# # Das Fixieren des random_state bedeutet, dass immer der gleiche Split gemacht wird. Dadurch wird verhindert, dass durch mehrfaches durchlaufen immer mal wieder andere Daten für das Training
# # benutzt werden. Denn dadurch würde man sich letztlich beim Training alle Daten anschauen, auch die Testdaten. Subtiler Punkt- aber m.E. good practice!
# #Die Grössen der Arrays:
# print(Xtrain.shape,Xtest.shape,ytrain.shape,ytest.shape)
# print("Trainingsdaten")
# display(ytrain.value_counts())
# print("\nTestdaten")
# display(ytest.value_counts())
# print('\nKlassenverhältnis:')
# #Von den Trainingsdaten gibt es in jeder Klasse etwa gleichviel mehr als in den Testdaten:
# ytest.value_counts()/ytrain.value_counts()

# %% [markdown]
# Die Ausgaben oben zeigen die Anzahl Beispiele pro Klasse in den Training- und Testdaten sowie das Verhältnis pro Klasse. Das Verhältnis sollte für alle Klassen etwa gleich gross sein- dies nennt sich *stratifiziertes Training-Test-Splitten*.

# %%
# display(Xtrain.head())
# ytrain

# %% [markdown]
# #### Shutil - High-level File Operations
# Wir kopieren nun die Daten in Unterordner von `pfad_zu_lcl_colab/2_Baumstruktur/`. Die Unterordner sollen die Klassennamen (Farben) sein.

# %%
# #Kopiere die Trainigsdaten
# for Basisname,voller_Dateiname, label in zip(Xtrain.Basisname,Xtrain.Dateiname, ytrain):
#     src = voller_Dateiname
#     #dst = Path('/tmp','2_Baumstruktur',label)
#     dst_train = Ausgabepfad/'Baumstruktur_train'/label

#     dst_train.mkdir(exist_ok=True,parents=True)
#     shutil.copy(src,dst_train/Basisname.name)
# print(f"Trainingsdateien wurden nach {str(dst_train.parent)} kopiert.")
# #Kopiere die Testdaten
# for Basisname,voller_Dateiname, label in zip(Xtest.Basisname,Xtest.Dateiname, ytest):
#     src = voller_Dateiname

#     dst_test = Ausgabepfad/'Baumstruktur_test'/label

#     dst_test.mkdir(exist_ok=True,parents=True)
#     shutil.copy(src,dst_test/Basisname.name)
# print(f"Testdateien wurden nach {str(dst_test.parent)} kopiert.")

# %% [markdown]
# Überprüfen wir die Struktur! Die Klassenverzeichnisse sind hier:

# %%
# !echo "Training-Baumstruktur:"
# !ls "{dst_train.parent}"
# !echo "Test-Baumstruktur:"
# !ls "{dst_test.parent}"

# %% [markdown]
# Und darunter befinden sich die zur Klasse zugehörigen Bilder:

# %%
# !ls "{dst_test.parent}"/*

# %% [markdown]
# Nun wollen wir diese zwei Baumstrukturen herunterladen:

# %%
# ! echo "-Trainingdaten-"
# ! zip -r training_Baumstruktur.zip {dst_train.parent}/*|tail -n5
# ! echo "-Testdaten-"
# ! zip -r testing_Baumstruktur.zip {dst_test.parent}/*|tail -n5

# %% [markdown]
# **Gratulation!!!** Damit sind wir bereit für das Training eines neuronalen Netzes. Weiter geht's im Notebook `2_training/Training.ipynb.

# %%
# #Excel export der Medianwerte (V-channel)
# results = []
# for fn in pfad_zu_daten.iterdir():
#     if fn.suffix.lower() != '.jpg':
#         continue

#     im = oe.load_file(fn)
#     im = oe.resize(im, pr)
#     v_channel = rgb_to_hsv(im)[..., 2]
#     median_v = np.median(v_channel)

#     results.append({
#         'Filename': fn.name,
#         'Median_V': median_v,
#     })

# df_medians = pd.DataFrame(results)

# mean_row = df_medians.mean(numeric_only=True).to_frame().T
# mean_row.insert(0, 'Filename', 'Mittelwert')
# df_medians = pd.concat([df_medians, mean_row], ignore_index=True)

# df_medians.to_csv("Output/median_werte.csv", index=False)
