# %% [markdown]
# # Model training
# In diesem Notebook trainieren wir ein Neuronales Netz auf den Trainingsdaten, welche wir im Schritt [Objektextraktion](https://www.kaggle.com/code/toedtlifhsg/giraffenpuzzle-objektextraktion) erstellt haben. Die Daten sollten in einer sog. Baumstruktur angeordnet sein: Wir brauchen ein Verzeichnis für jede Klasse, und darin alle Bilder dieser Klasse.

# %% [markdown]
# Zunächst müssen wir unsere Objektbilder finden. Dies sind Bilder mit einer engen *Bounding Box* um das Objekt herum:

# %% [markdown]
# In der nächsten Zelle extrahieren wir die Klasse aus dem Dateinamen des Bildes

# %%
#Import Libraries
from pathlib import Path
import numpy as np
import pandas as pd
from collections import defaultdict
import shutil
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras import layers
#import scikitplot as skplt
import os,datetime

# %%
files = [f for f in Path('./Alle_Gipfel').glob('*')]
s = files[0].name
idx = s.find('_')
Klassenliste = []
filenameliste = [fn for fn in Path('./Alle_Gipfel').glob('*')]
for filename in filenameliste:
    idx=filename.name.find('_')
    klasse = filename.name[:idx]
    Klassenliste.append(klasse)
len(Klassenliste)
Klassennamen = np.unique(Klassenliste).tolist()

# %%
Anzahl_Trainingsbeispiele = np.floor(pd.Series(Klassenliste).value_counts()*0.6).astype('int')
Anzahl_Trainingsbeispiele
# Out:
# Keimkraft       39
# Laugengipfel    36
# Buttergipfel    28
# .DS              0
# Name: count, dtype: int64

# %% [markdown]
# Nun erstellen wir die Baumstruktur, und zwar unter dem folgenden Pfad (nicht in allen Pfaden lassen sich Unterverzeichnisse erstellen!):

# %%
Baumstrukturpfad = './'
Baumstrukturpfad=Path(Baumstrukturpfad)
(Baumstrukturpfad/'Baumstruktur_train').mkdir(parents=True,exist_ok=True)
(Baumstrukturpfad/'Baumstruktur_test').mkdir(parents=True,exist_ok=True)
for klasse in Klassennamen:
    pfad_train = (Baumstrukturpfad/'Baumstruktur_train'/klasse)
    pfad_test = (Baumstrukturpfad/'Baumstruktur_test'/klasse)

    pfad_train.mkdir(parents=True,exist_ok=True)
    pfad_test.mkdir(parents=True,exist_ok=True)

# %% [markdown]
# [DefaultDict-Dictionaries](https://www.python-kurs.eu/python3_dictionaries.php) sind im folgenden nützlich. [Dieses Video](https://ingo-janssen.de/python-erweiterte-datentypen-was-ist-defaultdict/) gibt eine gute Einführung.

# %%
already_copied=defaultdict(lambda :0) #defaultdict's sind Dictionaries mit einem Default-Returnwert, hier 0 
already_copied['noch nicht existierender Key']
# Out:
# 0

# %% [markdown]
# Wir bauen damit nun eine if/else-Klausel, so dass die in `Anzahl_Trainingsbeispiele` angegebene Anzahl Dateien als Trainingsdaten verwendet  (in das Unterverzeichnis 'train' kopiert) werden, und der Rest als Testdaten verwendet werden.

# %%
"""
train_or_test=dict()
i=0
for ifile,(filename,klasse) in enumerate(zip(filenameliste,Klassenliste)):
    if ifile<6: #einfach, um ein paar Erklärungen zu erhalten, aber nicht zu viele
        print('kopiere',filename,'nach',Baumstrukturpfad/klasse/filename.name)
    elif ifile==6:
        print('...')
    if already_copied[klasse]<Anzahl_Trainingsbeispiele[klasse]:
        shutil.copyfile(filename,Baumstrukturpfad/'train'/klasse/filename.name)
        already_copied[klasse]+=1 # zähle mit, wieviele Beispiele schon in das Verzeichnis 'train' kopiert wurden.
        train_or_test[filename.name]='train'
    else:
        shutil.copyfile(filename,Baumstrukturpfad/'test'/klasse/filename.name)
        train_or_test[filename.name]='test'
    
print('Done.')
"""
# Out:
# kopiere Alle_Gipfel/Laugengipfel_low_light_34.jpg nach Laugengipfel/Laugengipfel_low_light_34.jpg
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 9
#       7     print('...')
#       8 if already_copied[klasse]<Anzahl_Trainingsbeispiele[klasse]:
# ----> 9     shutil.copyfile(filename,Baumstrukturpfad/'train'/klasse/filename.name)
#      10     already_copied[klasse]+=1 # zähle mit, wieviele Beispiele schon in das Verzeichnis 'train' kopiert wurden.
#      11     train_or_test[filename.name]='train'
#
# File /opt/homebrew/Caskroom/miniforge/base/lib/python3.10/shutil.py:256, in copyfile(src, dst, follow_symlinks)
#     254 with open(src, 'rb') as fsrc:
#     255     try:
# --> 256         with open(dst, 'wb') as fdst:
#     257             # macOS
#     258             if _HAS_FCOPYFILE:
#     259                 try:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'train/Laugengipfel/Laugengipfel_low_light_34.jpg'

# %% [markdown]
# Überprüfen wir, dass die Bilder an die richtige Stelle kopiert wurden!

# %% [markdown]
# Wir sollten im Folgenden *nur noch Trainingsbeispiele zum Training des neuronalen Netzes verwenden*. Die Testbeispiele nutzen wir erst, wenn das Neuronale Netzwerk fertig optimiert ist und kurz vor der Inbetriebnahme steht.

# %%
#os.environ["TF_CPP_MIN_LOG_LEVEL"] = '1'
#os.environ["CUDA_VISIBLE_DEVICES"] = "-1" #dies schaltet die GPU aus. GPU-Nutzung führt bei mir zu einem Kernel-Crash... 

#tf.config.list_physical_devices('GPU') #Wenn keine GPU Verfügbar ist, ist das nicht weiter schlimm (nur langsamer)

# %% [markdown]
# Die Unterverzeichnisse von `path` (2_labelling/Beispiel/Bauteile/) stellen die Klassen dar, welche gelernt werden. In jedem Unterverzeichniss sollten sich Bilder dieser Klasse befinden.

# %%
Datensatzname = 'Gipfeli'  #Unbedingt anpassen! Das Trainierte Modell wird später mit diesem String bezeichnet.

# %%
Baumstrukturpfad = Path(os.path.expanduser(Baumstrukturpfad))
downloadable_output_path = './Output' #Nach Klick auf "Save Version" wird der Inhalt dieses Verzeichnisses als Output zugänglich.
model_output_path = os.path.join(downloadable_output_path,'Model')  # kann angepasst werden! Gut überprüfen
if not os.path.exists(model_output_path):
    os.mkdir(model_output_path)
print(f'Modell wird nach {model_output_path} geschrieben')
# Out:
# Modell wird nach ./Output/Model geschrieben

# %% [markdown]
# **In der letzten Zelle sollten die Klassen der Aufgabe angezeigt werden (nicht etwa die einzelnen Dateien). Ansonsten ist die Zeile mit `path=...` anzupassen!**
# Wir trainieren auf Bildern, welche 64x64 Pixel gross sein sollten. Wenn sie es im obigen Pfad nicht sind, werden sie entsprechend angepasst.

# %%
image_size=(128,128)
batch_size=32

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  Baumstrukturpfad/'train',
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=image_size,
  batch_size=batch_size)

val_ds = tf.keras.utils.image_dataset_from_directory(
  Baumstrukturpfad/'train',  #es ist wichtig, dass zur Validierung keine Testdaten verwendet werden!
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=image_size,
  batch_size=batch_size)
# Out:
# Found 138 files belonging to 3 classes.
# Using 111 files for training.
# Found 138 files belonging to 3 classes.
# Using 27 files for validation.

# %% [markdown]
# Keras hat nun alle Unterverzeichnisse eingelesen. Die Reihenfolge der Klassennamen können wir so ausgeben:

# %%
class_names = train_ds.class_names
class_names
# Out:
# ['Buttergipfel', 'Keimkraft', 'Laugengipfel']

# %% [markdown]
# Unser Modell wird später einfach nur z.B. "Klasse 3" ausspucken. Dies bedeutet dann, dass ein Bild der Klasse vorliegt, welche den namen des 4. Eintrags in obiger Liste hat.
#
# Schauen wir uns ein paar Trainingsbilder an! Wenn Sie denken ,dass diese Bilder für das neuronale Netz eine zu geringe Auflösung haben, als dass etwas erkannt werden könnte: dann kann weiter oben der Wert der Variablen image_size angepasst werden. `image_size=(64,64)` sollte aber meist ausreichen.

# %%
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
    for i in range(5):
        ax = plt.subplot(3, 2, i + 1)
        im = images[i].numpy().astype("uint8")
        plt.imshow(im)
        plt.title(class_names[labels[i]])
        plt.axis("off")
# Out:
# 2025-10-09 22:17:07.245052: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %% [markdown]
# Die folgende Zelle versucht, die Hardware gut auszulasten. Es gäbe [viel dazu zu sagen](https://www.tensorflow.org/guide/data_performance), aber sagen wir einfach, dass die Daten für einen raschen Zugriff vorbereitet werden:

# %%
train_ds = train_ds.cache().shuffle(100).prefetch(buffer_size=tf.data.AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=tf.data.AUTOTUNE)

# %% [markdown]
# Nun definieren wir unser Modell! Hier können Sie Schichten von Neuronalen Netzen hinzufügen, die Aktivierungsfunktionen verändern und vieles mehr. Wichtig ist, dass `num_classes` stimmt, die Anzahl der Klassen und gleichzeitig die Anzahl Neuronen in der letzten (Ausgabe-)Schicht. Und natürlich die Grösse des Eingabebildes, `image_size`.

# %%
#functional API (https://keras.io/guides/functional_api/):
num_classes = len(class_names)
color_image_size=(*image_size,3)
def make_model():
    img_inputs = tf.keras.Input(shape=color_image_size,name='Eingabe')
    
    x = layers.Rescaling(1./255, input_shape=color_image_size)(img_inputs)
    x = layers.RandomFlip("horizontal")(x)
    x = layers.RandomRotation(0.5)(x)
    x = layers.Conv2D(16, 3, padding='same', activation='relu')(x)
    x = layers.MaxPooling2D()(x)
    x = layers.Conv2D(32, 3, padding='same', activation='relu')(x)
    x = layers.MaxPooling2D()(x)
    x = layers.Conv2D(64, 3, padding='same', activation='relu')(x)
    x = layers.MaxPooling2D()(x)
    x = layers.Flatten()(x)
    x = layers.Dense(128, activation='relu')(x)
    outputs = layers.Dense(num_classes,name='Ausgabe',activation='softmax')(x)
    
    model = tf.keras.Model(inputs=img_inputs,outputs=outputs,name='Conv-Model-Standard') #Geben Sie Ihrem Modell doch einen hübschen, wiedererkennbaren Namen!
    return model 

model = make_model()

model.summary()
# Out:
# Model: "Conv-Model-Standard"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ Eingabe (InputLayer)            │ (None, 128, 128, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ rescaling_7 (Rescaling)         │ (None, 128, 128, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ random_flip_7 (RandomFlip)      │ (None, 128, 128, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ random_rotation_7               │ (None, 128, 128, 3)    │             0 │
# │ (RandomRotation)                │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_20 (Conv2D)              │ (None, 128, 128, 16)   │           448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_20 (MaxPooling2D) │ (None, 64, 64, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_21 (Conv2D)              │ (None, 64, 64, 32)     │         4,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_21 (MaxPooling2D) │ (None, 32, 32, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_22 (Conv2D)              │ (None, 32, 32, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_22 (MaxPooling2D) │ (None, 16, 16, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_7 (Flatten)             │ (None, 16384)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 128)            │     2,097,280 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Ausgabe (Dense)                 │ (None, 3)              │           387 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,121,251 (8.09 MB)
#  Trainable params: 2,121,251 (8.09 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# Kompilieren des Modells heisst, dass der Gradientenabstieg und das Lernverfahren spezifiziert werden, und der low-level Code vorbereitet wird, welcher dann später die Hauptarbeit leistet.

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
              metrics=['accuracy'])

# %% [markdown]
# Es ist immer gut zu verstehen, was während des Trainings passiert- und allenfalls im richtigen Moment zu reagieren. Tensorboard ist eine Web-Applikation, mit der Sie den Trainingsfortschritt verfolgen können. EarlyStopping ist ein Callback, der genau das tut: Er unterbricht das Training, sobald sich die gemonitorte Grösse (hier die Validierungsgenauigkeit) nicht mehr verbessert.

# %%
early_stopping_callback = tf.keras.callbacks.EarlyStopping(monitor='val_accuracy',patience=100) #patience = 0? patience = 40? patience=200?

# %% [markdown]
# Und...**LOS GEHT'S!** Je nach Grösse des Trainingsdatensatzes kann die nächste Zeile länger dauern. Die Anzahl Epochen kann auch limitiert werden. Stellen Sie sie vorerst so ein, dass Sie sich das Warten *leisten* können. Ev. ist es besser, vorerst mal ein sehr schlechtes Modell zu erzeugen- einfach um zu sehen, ob der Rest des Codes auch wirklich funktioniert.

# %%
epochs=100000000
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs,
  callbacks=[early_stopping_callback]
)
# Out:
# Epoch 1/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 113ms/step - accuracy: 0.2883 - loss: 1.6728 - val_accuracy: 0.4074 - val_loss: 1.2065
# Epoch 2/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.3694 - loss: 1.1172 - val_accuracy: 0.4074 - val_loss: 1.0747
# Epoch 3/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.3604 - loss: 1.0956 - val_accuracy: 0.4444 - val_loss: 1.0813
# Epoch 4/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.3243 - loss: 1.0959 - val_accuracy: 0.4444 - val_loss: 1.0861
# Epoch 5/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.3153 - loss: 1.0942 - val_accuracy: 0.4444 - val_loss: 1.0767
# Epoch 6/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.3243 - loss: 1.0916 - val_accuracy: 0.4444 - val_loss: 1.0690
# Epoch 7/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.3514 - loss: 1.0897 - val_accuracy: 0.4815 - val_loss: 1.0588
# Epoch 8/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.3514 - loss: 1.0859 - val_accuracy: 0.4444 - val_loss: 1.0636
# Epoch 9/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.3694 - loss: 1.0822 - val_accuracy: 0.4444 - val_loss: 1.0468
# Epoch 10/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.3964 - loss: 1.0735 - val_accuracy: 0.4815 - val_loss: 1.0549
# Epoch 11/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.4414 - loss: 1.0665 - val_accuracy: 0.5556 - val_loss: 1.0471
# Epoch 12/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.4685 - loss: 1.0451 - val_accuracy: 0.4074 - val_loss: 1.0479
# Epoch 13/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.5315 - loss: 1.0253 - val_accuracy: 0.4444 - val_loss: 0.9250
# Epoch 14/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.4324 - loss: 1.0153 - val_accuracy: 0.4444 - val_loss: 1.0532
# Epoch 15/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.5856 - loss: 0.9740 - val_accuracy: 0.6667 - val_loss: 0.9461
# Epoch 16/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.4955 - loss: 0.9792 - val_accuracy: 0.5926 - val_loss: 0.9593
# Epoch 17/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.6216 - loss: 0.9122 - val_accuracy: 0.5185 - val_loss: 0.8725
# Epoch 18/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.5676 - loss: 0.9004 - val_accuracy: 0.4444 - val_loss: 1.0288
# Epoch 19/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.6486 - loss: 0.8458 - val_accuracy: 0.7037 - val_loss: 0.8513
# Epoch 20/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.6126 - loss: 0.8008 - val_accuracy: 0.4074 - val_loss: 1.0509
# Epoch 21/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.6036 - loss: 0.7898 - val_accuracy: 0.6296 - val_loss: 0.9023
# Epoch 22/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.5766 - loss: 0.7840 - val_accuracy: 0.6667 - val_loss: 0.7118
# Epoch 23/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.6577 - loss: 0.7711 - val_accuracy: 0.5185 - val_loss: 0.8282
# Epoch 24/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.6036 - loss: 0.7785 - val_accuracy: 0.4074 - val_loss: 1.0599
# Epoch 25/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.6757 - loss: 0.7185 - val_accuracy: 0.7037 - val_loss: 0.6734
# Epoch 26/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.6126 - loss: 0.8148 - val_accuracy: 0.2593 - val_loss: 1.2661
# Epoch 27/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.6126 - loss: 0.7902 - val_accuracy: 0.7778 - val_loss: 0.6518
# Epoch 28/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.4955 - loss: 0.9593 - val_accuracy: 0.7037 - val_loss: 0.6902
# Epoch 29/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.6306 - loss: 0.8083 - val_accuracy: 0.2963 - val_loss: 1.1644
# Epoch 30/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7297 - loss: 0.7217 - val_accuracy: 0.7407 - val_loss: 0.6443
# Epoch 31/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.6036 - loss: 0.7839 - val_accuracy: 0.7037 - val_loss: 0.6944
# Epoch 32/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.7297 - loss: 0.6762 - val_accuracy: 0.4815 - val_loss: 0.8788
# Epoch 33/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.7838 - loss: 0.6428 - val_accuracy: 0.7778 - val_loss: 0.6525
# Epoch 34/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.6486 - loss: 0.6954 - val_accuracy: 0.7778 - val_loss: 0.6420
# Epoch 35/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.7477 - loss: 0.6302 - val_accuracy: 0.6296 - val_loss: 0.7148
# Epoch 36/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7387 - loss: 0.5764 - val_accuracy: 0.6667 - val_loss: 0.6442
# Epoch 37/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.7027 - loss: 0.5918 - val_accuracy: 0.6296 - val_loss: 0.7982
# Epoch 38/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.7658 - loss: 0.5952 - val_accuracy: 0.5556 - val_loss: 0.6932
# Epoch 39/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.7297 - loss: 0.5613 - val_accuracy: 0.6667 - val_loss: 0.5939
# Epoch 40/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.6847 - loss: 0.6020 - val_accuracy: 0.6667 - val_loss: 0.6627
# Epoch 41/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.8108 - loss: 0.5304 - val_accuracy: 0.6667 - val_loss: 0.5470
# Epoch 42/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.8018 - loss: 0.5414 - val_accuracy: 0.7037 - val_loss: 0.6803
# Epoch 43/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.7748 - loss: 0.5323 - val_accuracy: 0.7037 - val_loss: 0.5561
# Epoch 44/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.7658 - loss: 0.5807 - val_accuracy: 0.7037 - val_loss: 0.5602
# Epoch 45/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.7568 - loss: 0.5123 - val_accuracy: 0.7407 - val_loss: 0.5477
# Epoch 46/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.8649 - loss: 0.4713 - val_accuracy: 0.6667 - val_loss: 0.8728
# Epoch 47/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.7387 - loss: 0.5653 - val_accuracy: 0.7037 - val_loss: 0.5540
# Epoch 48/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.7748 - loss: 0.4844 - val_accuracy: 0.7037 - val_loss: 0.7566
# Epoch 49/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.8468 - loss: 0.3907 - val_accuracy: 0.6667 - val_loss: 0.4736
# Epoch 50/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.8468 - loss: 0.4549 - val_accuracy: 0.4815 - val_loss: 1.2735
# Epoch 51/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.8198 - loss: 0.4739 - val_accuracy: 0.6667 - val_loss: 0.4412
# Epoch 52/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.7207 - loss: 0.5409 - val_accuracy: 0.6296 - val_loss: 0.8273
# Epoch 53/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.7387 - loss: 0.5847 - val_accuracy: 0.7778 - val_loss: 0.5439
# Epoch 54/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.6937 - loss: 0.5911 - val_accuracy: 0.7778 - val_loss: 0.5289
# Epoch 55/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.8378 - loss: 0.4336 - val_accuracy: 0.4815 - val_loss: 1.1268
# Epoch 56/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.8649 - loss: 0.4554 - val_accuracy: 0.7778 - val_loss: 0.4191
# Epoch 57/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.7928 - loss: 0.4309 - val_accuracy: 0.7037 - val_loss: 0.7406
# Epoch 58/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.8829 - loss: 0.3901 - val_accuracy: 0.7407 - val_loss: 0.7093
# Epoch 59/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.8739 - loss: 0.3711 - val_accuracy: 0.7037 - val_loss: 0.7916
# Epoch 60/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.8829 - loss: 0.3567 - val_accuracy: 0.7407 - val_loss: 0.7511
# Epoch 61/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.8649 - loss: 0.3663 - val_accuracy: 0.7037 - val_loss: 0.7534
# Epoch 62/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9009 - loss: 0.3388 - val_accuracy: 0.6296 - val_loss: 1.0824
# Epoch 63/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.8739 - loss: 0.3402 - val_accuracy: 0.7407 - val_loss: 0.6270
# Epoch 64/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.8468 - loss: 0.3479 - val_accuracy: 0.5185 - val_loss: 1.3051
# Epoch 65/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.8559 - loss: 0.4062 - val_accuracy: 0.6667 - val_loss: 0.8335
# Epoch 66/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.8649 - loss: 0.3011 - val_accuracy: 0.6667 - val_loss: 0.9457
# Epoch 67/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.9279 - loss: 0.3222 - val_accuracy: 0.7037 - val_loss: 0.7342
# Epoch 68/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.8739 - loss: 0.3537 - val_accuracy: 0.7037 - val_loss: 0.8236
# Epoch 69/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.8919 - loss: 0.2857 - val_accuracy: 0.6296 - val_loss: 1.0029
# Epoch 70/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9009 - loss: 0.2983 - val_accuracy: 0.7037 - val_loss: 0.7152
# Epoch 71/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.8739 - loss: 0.3367 - val_accuracy: 0.7037 - val_loss: 0.8859
# Epoch 72/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.8649 - loss: 0.3377 - val_accuracy: 0.7778 - val_loss: 0.7749
# Epoch 73/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.8649 - loss: 0.2916 - val_accuracy: 0.7037 - val_loss: 1.0888
# Epoch 74/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.8739 - loss: 0.2971 - val_accuracy: 0.7407 - val_loss: 0.7308
# Epoch 75/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.9009 - loss: 0.2997 - val_accuracy: 0.7407 - val_loss: 0.8283
# Epoch 76/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.8919 - loss: 0.2867 - val_accuracy: 0.7778 - val_loss: 0.7634
# Epoch 77/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.8739 - loss: 0.2698 - val_accuracy: 0.7407 - val_loss: 0.8558
# Epoch 78/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.8919 - loss: 0.2748 - val_accuracy: 0.7778 - val_loss: 0.5728
# Epoch 79/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9279 - loss: 0.2327 - val_accuracy: 0.7778 - val_loss: 0.4608
# Epoch 80/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.8919 - loss: 0.2876 - val_accuracy: 0.8519 - val_loss: 0.5147
# Epoch 81/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.9279 - loss: 0.2477 - val_accuracy: 0.7778 - val_loss: 0.5553
# Epoch 82/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.9369 - loss: 0.2176 - val_accuracy: 0.7778 - val_loss: 0.5594
# Epoch 83/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.8739 - loss: 0.2715 - val_accuracy: 0.7778 - val_loss: 0.7245
# Epoch 84/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9279 - loss: 0.2386 - val_accuracy: 0.7778 - val_loss: 0.8601
# Epoch 85/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.8649 - loss: 0.2951 - val_accuracy: 0.7778 - val_loss: 0.7845
# Epoch 86/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.8829 - loss: 0.3169 - val_accuracy: 0.7407 - val_loss: 0.6299
# Epoch 87/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9009 - loss: 0.2703 - val_accuracy: 0.7778 - val_loss: 0.7303
# Epoch 88/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9279 - loss: 0.2013 - val_accuracy: 0.7407 - val_loss: 1.0661
# Epoch 89/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.9279 - loss: 0.2102 - val_accuracy: 0.8148 - val_loss: 0.7169
# Epoch 90/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.9279 - loss: 0.1947 - val_accuracy: 0.8148 - val_loss: 0.6095
# Epoch 91/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.9099 - loss: 0.2081 - val_accuracy: 0.7778 - val_loss: 0.7354
# Epoch 92/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9009 - loss: 0.2571 - val_accuracy: 0.7407 - val_loss: 0.7174
# Epoch 93/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.8739 - loss: 0.3087 - val_accuracy: 0.7778 - val_loss: 0.6940
# Epoch 94/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9099 - loss: 0.2805 - val_accuracy: 0.8148 - val_loss: 0.5918
# Epoch 95/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9279 - loss: 0.1915 - val_accuracy: 0.8148 - val_loss: 0.8262
# Epoch 96/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9009 - loss: 0.1935 - val_accuracy: 0.7778 - val_loss: 0.7843
# Epoch 97/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.9189 - loss: 0.2359 - val_accuracy: 0.8889 - val_loss: 0.3664
# Epoch 98/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9279 - loss: 0.1977 - val_accuracy: 0.6667 - val_loss: 1.1065
# Epoch 99/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9009 - loss: 0.2495 - val_accuracy: 0.8148 - val_loss: 0.4548
# Epoch 100/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.8919 - loss: 0.2236 - val_accuracy: 0.7778 - val_loss: 0.5107
# Epoch 101/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.9279 - loss: 0.1915 - val_accuracy: 0.8519 - val_loss: 0.2957
# Epoch 102/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9459 - loss: 0.2024 - val_accuracy: 0.8148 - val_loss: 0.5744
# Epoch 103/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.8919 - loss: 0.2447 - val_accuracy: 0.8519 - val_loss: 0.3566
# Epoch 104/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.9550 - loss: 0.1633 - val_accuracy: 0.8519 - val_loss: 0.4104
# Epoch 105/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.9459 - loss: 0.1468 - val_accuracy: 0.7407 - val_loss: 0.6840
# Epoch 106/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9550 - loss: 0.1218 - val_accuracy: 0.8148 - val_loss: 0.5785
# Epoch 107/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.9550 - loss: 0.1409 - val_accuracy: 0.8148 - val_loss: 0.6791
# Epoch 108/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9459 - loss: 0.1532 - val_accuracy: 0.8519 - val_loss: 0.4188
# Epoch 109/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9189 - loss: 0.1532 - val_accuracy: 0.7778 - val_loss: 0.7839
# Epoch 110/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.9550 - loss: 0.1119 - val_accuracy: 0.8519 - val_loss: 0.4136
# Epoch 111/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.9640 - loss: 0.1255 - val_accuracy: 0.8889 - val_loss: 0.4652
# Epoch 112/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9730 - loss: 0.1213 - val_accuracy: 0.8519 - val_loss: 0.4963
# Epoch 113/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9730 - loss: 0.1422 - val_accuracy: 0.8148 - val_loss: 0.5733
# Epoch 114/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9640 - loss: 0.1007 - val_accuracy: 0.8889 - val_loss: 0.3224
# Epoch 115/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9730 - loss: 0.1055 - val_accuracy: 0.8148 - val_loss: 0.6474
# Epoch 116/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.9640 - loss: 0.1023 - val_accuracy: 0.8519 - val_loss: 0.4456
# Epoch 117/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9369 - loss: 0.1422 - val_accuracy: 0.8519 - val_loss: 0.4137
# Epoch 118/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 0.9640 - loss: 0.1119 - val_accuracy: 0.8889 - val_loss: 0.5632
# Epoch 119/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9550 - loss: 0.0959 - val_accuracy: 0.8889 - val_loss: 0.5280
# Epoch 120/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9550 - loss: 0.1319 - val_accuracy: 0.6667 - val_loss: 0.9477
# Epoch 121/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9279 - loss: 0.1919 - val_accuracy: 0.8889 - val_loss: 0.3071
# Epoch 122/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.8919 - loss: 0.2584 - val_accuracy: 0.7778 - val_loss: 0.7832
# Epoch 123/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.9189 - loss: 0.1638 - val_accuracy: 0.7778 - val_loss: 0.6099
# Epoch 124/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.9189 - loss: 0.1839 - val_accuracy: 0.8148 - val_loss: 0.2059
# Epoch 125/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.9640 - loss: 0.1895 - val_accuracy: 0.7407 - val_loss: 0.6367
# Epoch 126/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.9009 - loss: 0.1796 - val_accuracy: 0.9259 - val_loss: 0.3515
# Epoch 127/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9369 - loss: 0.1594 - val_accuracy: 0.7778 - val_loss: 0.4105
# Epoch 128/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.9279 - loss: 0.1638 - val_accuracy: 0.8889 - val_loss: 0.2396
# Epoch 129/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.9279 - loss: 0.1572 - val_accuracy: 0.8519 - val_loss: 0.3549
# Epoch 130/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.9640 - loss: 0.0838 - val_accuracy: 0.8519 - val_loss: 0.3026
# Epoch 131/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9910 - loss: 0.0622 - val_accuracy: 0.8519 - val_loss: 0.3445
# Epoch 132/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.9820 - loss: 0.0638 - val_accuracy: 0.8519 - val_loss: 0.2458
# Epoch 133/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.9910 - loss: 0.0575 - val_accuracy: 0.8519 - val_loss: 0.2560
# Epoch 134/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9910 - loss: 0.0581 - val_accuracy: 0.8519 - val_loss: 0.2819
# Epoch 135/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 1.0000 - loss: 0.0539 - val_accuracy: 0.8889 - val_loss: 0.2779
# Epoch 136/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 1.0000 - loss: 0.0397 - val_accuracy: 0.8889 - val_loss: 0.2812
# Epoch 137/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9910 - loss: 0.0579 - val_accuracy: 0.8148 - val_loss: 0.3814
# Epoch 138/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.9730 - loss: 0.0776 - val_accuracy: 0.8889 - val_loss: 0.2709
# Epoch 139/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.9730 - loss: 0.0722 - val_accuracy: 0.7778 - val_loss: 0.4413
# Epoch 140/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.9730 - loss: 0.0591 - val_accuracy: 0.8889 - val_loss: 0.2304
# Epoch 141/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.9820 - loss: 0.0578 - val_accuracy: 0.8519 - val_loss: 0.3516
# Epoch 142/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.9820 - loss: 0.0569 - val_accuracy: 0.8519 - val_loss: 0.2841
# Epoch 143/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.9910 - loss: 0.0594 - val_accuracy: 0.8519 - val_loss: 0.2503
# Epoch 144/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.9640 - loss: 0.0644 - val_accuracy: 0.8889 - val_loss: 0.3004
# Epoch 145/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.9730 - loss: 0.0534 - val_accuracy: 0.7407 - val_loss: 0.6820
# Epoch 146/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.9820 - loss: 0.0598 - val_accuracy: 0.8889 - val_loss: 0.1914
# Epoch 147/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.9910 - loss: 0.0440 - val_accuracy: 0.9259 - val_loss: 0.3513
# Epoch 148/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 1.0000 - loss: 0.0515 - val_accuracy: 0.8519 - val_loss: 0.3966
# Epoch 149/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.9910 - loss: 0.0526 - val_accuracy: 0.8519 - val_loss: 0.2162
# Epoch 150/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.9910 - loss: 0.0323 - val_accuracy: 0.7778 - val_loss: 0.3934
# Epoch 151/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.9910 - loss: 0.0396 - val_accuracy: 0.8889 - val_loss: 0.2608
# Epoch 152/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9910 - loss: 0.0327 - val_accuracy: 0.8889 - val_loss: 0.1317
# Epoch 153/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.9820 - loss: 0.0495 - val_accuracy: 0.7407 - val_loss: 0.5193
# Epoch 154/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.9730 - loss: 0.0626 - val_accuracy: 0.8889 - val_loss: 0.1818
# Epoch 155/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9820 - loss: 0.0442 - val_accuracy: 0.8889 - val_loss: 0.1771
# Epoch 156/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.9910 - loss: 0.0413 - val_accuracy: 0.9259 - val_loss: 0.1271
# Epoch 157/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.9910 - loss: 0.0427 - val_accuracy: 0.8519 - val_loss: 0.3690
# Epoch 158/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.9820 - loss: 0.0439 - val_accuracy: 0.8889 - val_loss: 0.1512
# Epoch 159/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.9910 - loss: 0.0332 - val_accuracy: 0.9630 - val_loss: 0.1311
# Epoch 160/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 1.0000 - loss: 0.0141 - val_accuracy: 0.9630 - val_loss: 0.1885
# Epoch 161/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 1.0000 - loss: 0.0246 - val_accuracy: 0.8889 - val_loss: 0.2483
# Epoch 162/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 1.0000 - loss: 0.0108 - val_accuracy: 0.8889 - val_loss: 0.2380
# Epoch 163/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 1.0000 - loss: 0.0207 - val_accuracy: 0.8519 - val_loss: 0.1660
# Epoch 164/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 1.0000 - loss: 0.0189 - val_accuracy: 0.9259 - val_loss: 0.1714
# Epoch 165/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 1.0000 - loss: 0.0149 - val_accuracy: 0.9259 - val_loss: 0.2166
# Epoch 166/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 1.0000 - loss: 0.0173 - val_accuracy: 0.8889 - val_loss: 0.2082
# Epoch 167/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 1.0000 - loss: 0.0125 - val_accuracy: 0.8889 - val_loss: 0.2518
# Epoch 168/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 1.0000 - loss: 0.0203 - val_accuracy: 0.8519 - val_loss: 0.1808
# Epoch 169/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.9910 - loss: 0.0216 - val_accuracy: 0.8519 - val_loss: 0.2319
# Epoch 170/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 1.0000 - loss: 0.0192 - val_accuracy: 0.8519 - val_loss: 0.1679
# Epoch 171/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 1.0000 - loss: 0.0126 - val_accuracy: 0.8519 - val_loss: 0.4006
# Epoch 172/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9820 - loss: 0.0289 - val_accuracy: 0.8889 - val_loss: 0.1767
# Epoch 173/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.9820 - loss: 0.0475 - val_accuracy: 0.8519 - val_loss: 0.4383
# Epoch 174/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9820 - loss: 0.0352 - val_accuracy: 0.9630 - val_loss: 0.1226
# Epoch 175/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9910 - loss: 0.0325 - val_accuracy: 0.8519 - val_loss: 0.3266
# Epoch 176/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.9910 - loss: 0.0283 - val_accuracy: 0.8519 - val_loss: 0.4108
# Epoch 177/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.9820 - loss: 0.0525 - val_accuracy: 0.7037 - val_loss: 0.7439
# Epoch 178/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 1.0000 - loss: 0.0328 - val_accuracy: 0.8889 - val_loss: 0.1667
# Epoch 179/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.9820 - loss: 0.0399 - val_accuracy: 0.9259 - val_loss: 0.2259
# Epoch 180/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.9730 - loss: 0.0589 - val_accuracy: 0.8148 - val_loss: 0.4493
# Epoch 181/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.9640 - loss: 0.0808 - val_accuracy: 0.8519 - val_loss: 0.4315
# Epoch 182/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9820 - loss: 0.0567 - val_accuracy: 1.0000 - val_loss: 0.0536
# Epoch 183/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.9730 - loss: 0.0789 - val_accuracy: 0.8519 - val_loss: 0.4108
# Epoch 184/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.9640 - loss: 0.0638 - val_accuracy: 0.8889 - val_loss: 0.2561
# Epoch 185/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 1.0000 - loss: 0.0177 - val_accuracy: 0.9259 - val_loss: 0.1688
# Epoch 186/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.9910 - loss: 0.0440 - val_accuracy: 0.9630 - val_loss: 0.1645
# Epoch 187/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 1.0000 - loss: 0.0226 - val_accuracy: 0.7778 - val_loss: 0.4613
# Epoch 188/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.9550 - loss: 0.0874 - val_accuracy: 0.9630 - val_loss: 0.1846
# Epoch 189/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.9369 - loss: 0.1689 - val_accuracy: 0.8148 - val_loss: 0.6309
# Epoch 190/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.9009 - loss: 0.2568 - val_accuracy: 0.8889 - val_loss: 0.5395
# Epoch 191/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.7928 - loss: 0.5845 - val_accuracy: 0.8519 - val_loss: 0.4635
# Epoch 192/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.9099 - loss: 0.2473 - val_accuracy: 0.8519 - val_loss: 0.3113
# Epoch 193/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.9279 - loss: 0.2624 - val_accuracy: 0.8519 - val_loss: 0.4299
# Epoch 194/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.8378 - loss: 0.5273 - val_accuracy: 0.4444 - val_loss: 2.2476
# Epoch 195/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.8649 - loss: 0.3993 - val_accuracy: 0.9259 - val_loss: 0.4105
# Epoch 196/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.8829 - loss: 0.4267 - val_accuracy: 0.7037 - val_loss: 0.9105
# Epoch 197/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.9099 - loss: 0.1650 - val_accuracy: 0.9259 - val_loss: 0.1310
# Epoch 198/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.9640 - loss: 0.1403 - val_accuracy: 0.8889 - val_loss: 0.2510
# Epoch 199/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.9820 - loss: 0.0947 - val_accuracy: 0.9259 - val_loss: 0.1534
# Epoch 200/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.9910 - loss: 0.0744 - val_accuracy: 0.9630 - val_loss: 0.1056
# Epoch 201/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 1.0000 - loss: 0.0450 - val_accuracy: 1.0000 - val_loss: 0.0709
# Epoch 202/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.9910 - loss: 0.0340 - val_accuracy: 1.0000 - val_loss: 0.0768
# Epoch 203/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.9550 - loss: 0.1007 - val_accuracy: 1.0000 - val_loss: 0.0340
# Epoch 204/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9910 - loss: 0.0551 - val_accuracy: 1.0000 - val_loss: 0.0791
# Epoch 205/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.9910 - loss: 0.0365 - val_accuracy: 1.0000 - val_loss: 0.0695
# Epoch 206/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9820 - loss: 0.0510 - val_accuracy: 1.0000 - val_loss: 0.0640
# Epoch 207/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9910 - loss: 0.0484 - val_accuracy: 1.0000 - val_loss: 0.0726
# Epoch 208/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9910 - loss: 0.0342 - val_accuracy: 1.0000 - val_loss: 0.0480
# Epoch 209/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 1.0000 - loss: 0.0214 - val_accuracy: 1.0000 - val_loss: 0.0409
# Epoch 210/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 1.0000 - loss: 0.0163 - val_accuracy: 1.0000 - val_loss: 0.0673
# Epoch 211/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 1.0000 - loss: 0.0252 - val_accuracy: 1.0000 - val_loss: 0.0430
# Epoch 212/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.9820 - loss: 0.0367 - val_accuracy: 1.0000 - val_loss: 0.0411
# Epoch 213/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 1.0000 - loss: 0.0181 - val_accuracy: 0.9630 - val_loss: 0.0912
# Epoch 214/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 1.0000 - loss: 0.0164 - val_accuracy: 0.9630 - val_loss: 0.0946
# Epoch 215/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 1.0000 - loss: 0.0137 - val_accuracy: 1.0000 - val_loss: 0.0533
# Epoch 216/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 1.0000 - loss: 0.0139 - val_accuracy: 1.0000 - val_loss: 0.0570
# Epoch 217/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 1.0000 - loss: 0.0135 - val_accuracy: 1.0000 - val_loss: 0.0407
# Epoch 218/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 1.0000 - loss: 0.0108 - val_accuracy: 1.0000 - val_loss: 0.0448
# Epoch 219/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 1.0000 - loss: 0.0144 - val_accuracy: 0.9630 - val_loss: 0.0787
# Epoch 220/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 1.0000 - loss: 0.0125 - val_accuracy: 0.9259 - val_loss: 0.1383
# Epoch 221/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 1.0000 - loss: 0.0104 - val_accuracy: 0.9259 - val_loss: 0.0975
# Epoch 222/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 1.0000 - loss: 0.0112 - val_accuracy: 0.9259 - val_loss: 0.0996
# Epoch 223/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 1.0000 - loss: 0.0117 - val_accuracy: 0.9259 - val_loss: 0.1076
# Epoch 224/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 1.0000 - loss: 0.0150 - val_accuracy: 0.8889 - val_loss: 0.1467
# Epoch 225/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 1.0000 - loss: 0.0068 - val_accuracy: 0.8889 - val_loss: 0.1665
# Epoch 226/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 1.0000 - loss: 0.0092 - val_accuracy: 0.9259 - val_loss: 0.1155
# Epoch 227/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 1.0000 - loss: 0.0070 - val_accuracy: 0.9259 - val_loss: 0.0799
# Epoch 228/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 1.0000 - loss: 0.0053 - val_accuracy: 0.9630 - val_loss: 0.0901
# Epoch 229/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 1.0000 - loss: 0.0065 - val_accuracy: 0.9259 - val_loss: 0.1007
# Epoch 230/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 1.0000 - loss: 0.0113 - val_accuracy: 0.9259 - val_loss: 0.1071
# Epoch 231/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 1.0000 - loss: 0.0104 - val_accuracy: 0.9259 - val_loss: 0.1074
# Epoch 232/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 1.0000 - loss: 0.0085 - val_accuracy: 0.9259 - val_loss: 0.1039
# Epoch 233/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9910 - loss: 0.0182 - val_accuracy: 0.9259 - val_loss: 0.0998
# Epoch 234/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.9910 - loss: 0.0261 - val_accuracy: 0.9630 - val_loss: 0.0747
# Epoch 235/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 1.0000 - loss: 0.0116 - val_accuracy: 0.9630 - val_loss: 0.0604
# Epoch 236/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 1.0000 - loss: 0.0069 - val_accuracy: 0.9259 - val_loss: 0.1125
# Epoch 237/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 1.0000 - loss: 0.0135 - val_accuracy: 0.8889 - val_loss: 0.1613
# Epoch 238/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 1.0000 - loss: 0.0120 - val_accuracy: 0.8889 - val_loss: 0.1319
# Epoch 239/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 1.0000 - loss: 0.0067 - val_accuracy: 0.9630 - val_loss: 0.0802
# Epoch 240/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 1.0000 - loss: 0.0062 - val_accuracy: 0.9630 - val_loss: 0.0650
# Epoch 241/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 1.0000 - loss: 0.0035 - val_accuracy: 0.9630 - val_loss: 0.0694
# Epoch 242/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 1.0000 - loss: 0.0085 - val_accuracy: 0.9630 - val_loss: 0.0700
# Epoch 243/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 1.0000 - loss: 0.0058 - val_accuracy: 0.9630 - val_loss: 0.0927
# Epoch 244/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 1.0000 - loss: 0.0046 - val_accuracy: 0.9259 - val_loss: 0.1002
# Epoch 245/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 1.0000 - loss: 0.0036 - val_accuracy: 0.9259 - val_loss: 0.1014
# Epoch 246/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 1.0000 - loss: 0.0062 - val_accuracy: 0.9630 - val_loss: 0.0949
# Epoch 247/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 1.0000 - loss: 0.0055 - val_accuracy: 0.9259 - val_loss: 0.1161
# Epoch 248/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 1.0000 - loss: 0.0055 - val_accuracy: 0.9630 - val_loss: 0.0980
# Epoch 249/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 1.0000 - loss: 0.0047 - val_accuracy: 0.9630 - val_loss: 0.0546
# Epoch 250/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 1.0000 - loss: 0.0080 - val_accuracy: 0.9630 - val_loss: 0.0536
# Epoch 251/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 1.0000 - loss: 0.0080 - val_accuracy: 0.8889 - val_loss: 0.1859
# Epoch 252/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 1.0000 - loss: 0.0106 - val_accuracy: 0.9630 - val_loss: 0.0943
# Epoch 253/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 1.0000 - loss: 0.0096 - val_accuracy: 0.9259 - val_loss: 0.0930
# Epoch 254/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 1.0000 - loss: 0.0067 - val_accuracy: 0.8889 - val_loss: 0.1328
# Epoch 255/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 1.0000 - loss: 0.0076 - val_accuracy: 0.8889 - val_loss: 0.1638
# Epoch 256/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 1.0000 - loss: 0.0037 - val_accuracy: 0.9630 - val_loss: 0.1093
# Epoch 257/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 1.0000 - loss: 0.0042 - val_accuracy: 0.9630 - val_loss: 0.0874
# Epoch 258/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 1.0000 - loss: 0.0045 - val_accuracy: 0.9259 - val_loss: 0.0979
# Epoch 259/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 1.0000 - loss: 0.0060 - val_accuracy: 0.9259 - val_loss: 0.1140
# Epoch 260/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 1.0000 - loss: 0.0049 - val_accuracy: 0.9630 - val_loss: 0.0954
# Epoch 261/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 1.0000 - loss: 0.0054 - val_accuracy: 0.9259 - val_loss: 0.1195
# Epoch 262/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 1.0000 - loss: 0.0032 - val_accuracy: 0.8889 - val_loss: 0.1407
# Epoch 263/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 1.0000 - loss: 0.0036 - val_accuracy: 0.8889 - val_loss: 0.1364
# Epoch 264/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 1.0000 - loss: 0.0047 - val_accuracy: 0.9630 - val_loss: 0.0972
# Epoch 265/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 1.0000 - loss: 0.0113 - val_accuracy: 0.9259 - val_loss: 0.1112
# Epoch 266/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 1.0000 - loss: 0.0101 - val_accuracy: 0.9630 - val_loss: 0.0937
# Epoch 267/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 1.0000 - loss: 0.0027 - val_accuracy: 0.8889 - val_loss: 0.1653
# Epoch 268/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 1.0000 - loss: 0.0060 - val_accuracy: 0.8889 - val_loss: 0.1336
# Epoch 269/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 1.0000 - loss: 0.0048 - val_accuracy: 0.9259 - val_loss: 0.1388
# Epoch 270/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 1.0000 - loss: 0.0046 - val_accuracy: 0.8889 - val_loss: 0.1333
# Epoch 271/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 1.0000 - loss: 0.0082 - val_accuracy: 0.9259 - val_loss: 0.1369
# Epoch 272/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 1.0000 - loss: 0.0055 - val_accuracy: 0.9259 - val_loss: 0.1657
# Epoch 273/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 1.0000 - loss: 0.0035 - val_accuracy: 0.8889 - val_loss: 0.1842
# Epoch 274/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 1.0000 - loss: 0.0047 - val_accuracy: 0.8889 - val_loss: 0.1588
# Epoch 275/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 0.9259 - val_loss: 0.1282
# Epoch 276/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 0.9630 - val_loss: 0.1109
# Epoch 277/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 1.0000 - loss: 0.0023 - val_accuracy: 0.9630 - val_loss: 0.1106
# Epoch 278/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 0.9630 - val_loss: 0.1068
# Epoch 279/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.9630 - val_loss: 0.1103
# Epoch 280/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 1.0000 - loss: 0.0025 - val_accuracy: 0.9259 - val_loss: 0.1337
# Epoch 281/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 1.0000 - loss: 0.0047 - val_accuracy: 0.8889 - val_loss: 0.1630
# Epoch 282/100000000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 0.8889 - val_loss: 0.1661

# %% [markdown]
# Das Modell hat hier (hoffentlich) fertig trainiert, und keinen Fehler produziert (möglich wären z.B. OutofMemory-Fehler o.ä.). Überprüfen Sie das! Denn nur bei Erfolgreichem Training lohnt es sich nun, die Validierungsgenauigkeit angeben zu lassen.

# %%
loss, metrics = model.evaluate(val_ds)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.8889 - loss: 0.1661

# %%
loss, metrics ,history.history.keys()
# Out:
# (0.16609933972358704,
#  0.8888888955116272,
#  dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss']))

# %% [markdown]
# Das `history`-Objekt ist interessant, um zu sehen, wie der Trainingsverlauf war (wenn Sie das nicht schon auf Tensorboard gesehen haben.

# %%
plt.plot(history.history['accuracy'],label='acc')
plt.plot(history.history['val_accuracy'],label='val_acc')
plt.plot(history.history['loss'],label='loss')
plt.plot(history.history['val_loss'],label='val_loss')
plt.legend()
#plt.savefig('Trainingskurven.png')

# %% [markdown]
# Es lohnt sich, die Zeile
#
#     early_stopping_callback = tf.keras.callbacks.EarlyStopping(monitor='val_accuracy',patience=20)
#
# mal auf
#
#     early_stopping_callback = tf.keras.callbacks.EarlyStopping(monitor='val_accuracy',patience=200)
#
# o.ä. zu setzen, und ab der Zelle welche die Modelldefinition enthält (mit `model = keras.Model(...)`) den Code nochmals auszuführen (das Modell enthält die aktuellen Gewichte und trainiert bei erneutem Ausführen der `.fit`-Methode das bisherige Modell weiter, anstatt wieder neu bei zufällig initialisierten Gewichten zu beginnen!). Das Modell wird dann deutlich länger trainiert.

# %% [markdown]
# ![Trainingskurven.PNG](attachment:9a5e1b07-5a39-4763-a28a-81d7ebe52116.PNG)

# %% [markdown]
# Beachten Sie, wie die Validierungsgenauigkeit schon lange stagniert, der Validierungsloss, d.h. der Wert der Verlustfunktion ausgewertet auf dem Validierungsdatensatz, seit etwa der 40. Epoche nur noch zunimmt. Der Validierungsdatensatz ist hier zu klein, um mehr sagen zu können, aber auch die Validierungsgenauigkeit scheint nach etwa der 40. Epoche abzunehmen! Es ist daher Wohl sinnvoll, dieses Modell auf diesem Datensatz nur 40 Epochen lang zu trainieren.
#
# Dazu können Sie also nochmals das Modell erstellen, die Anzahl Epochen auf 40 setzen und Ihr finales Modell trainieren.
#
# ### Modell eine vorgegebene Anzahl Epochen lang trainieren

# %%
vorgegebene_Anzahl_Epochen = 100 # Hier den Wert gemäss dem obigen Plot anpassen!
final_model = make_model() # Die bisherigen Gewichte sind damit zurückgesetzt, d.h. es wird nicht weitertrainiert, sondern nochmals ganz von vorne.
final_model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
              metrics=['accuracy'])

final_history = final_model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=vorgegebene_Anzahl_Epochen
)
# Out:
# Epoch 1/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 109ms/step - accuracy: 0.3063 - loss: 1.3286 - val_accuracy: 0.1481 - val_loss: 1.2261
# Epoch 2/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.3063 - loss: 1.1222 - val_accuracy: 0.1481 - val_loss: 1.1122
# Epoch 3/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.3423 - loss: 1.0996 - val_accuracy: 0.4074 - val_loss: 1.0891
# Epoch 4/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.3694 - loss: 1.0981 - val_accuracy: 0.4074 - val_loss: 1.0802
# Epoch 5/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.3694 - loss: 1.0957 - val_accuracy: 0.4074 - val_loss: 1.0830
# Epoch 6/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.3694 - loss: 1.0967 - val_accuracy: 0.4074 - val_loss: 1.0895
# Epoch 7/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.3694 - loss: 1.0946 - val_accuracy: 0.4074 - val_loss: 1.0858
# Epoch 8/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.3694 - loss: 1.0929 - val_accuracy: 0.4074 - val_loss: 1.0813
# Epoch 9/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.4324 - loss: 1.0912 - val_accuracy: 0.4074 - val_loss: 1.0691
# Epoch 10/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.3694 - loss: 1.0892 - val_accuracy: 0.5926 - val_loss: 1.0911
# Epoch 11/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.4685 - loss: 1.0854 - val_accuracy: 0.4444 - val_loss: 1.0484
# Epoch 12/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.3874 - loss: 1.0805 - val_accuracy: 0.4074 - val_loss: 1.0414
# Epoch 13/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.4505 - loss: 1.0601 - val_accuracy: 0.6667 - val_loss: 1.0750
# Epoch 14/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.5946 - loss: 1.0483 - val_accuracy: 0.4815 - val_loss: 1.0040
# Epoch 15/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.5676 - loss: 1.0049 - val_accuracy: 0.3333 - val_loss: 1.1368
# Epoch 16/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.4775 - loss: 0.9980 - val_accuracy: 0.5185 - val_loss: 0.8729
# Epoch 17/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.6036 - loss: 0.9437 - val_accuracy: 0.6296 - val_loss: 0.8830
# Epoch 18/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.4775 - loss: 0.9274 - val_accuracy: 0.4074 - val_loss: 1.2140
# Epoch 19/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.4955 - loss: 1.0162 - val_accuracy: 0.4444 - val_loss: 0.9801
# Epoch 20/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.4144 - loss: 1.0080 - val_accuracy: 0.3704 - val_loss: 1.0436
# Epoch 21/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.4505 - loss: 0.9884 - val_accuracy: 0.7778 - val_loss: 0.7976
# Epoch 22/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.4955 - loss: 0.8891 - val_accuracy: 0.6667 - val_loss: 0.7969
# Epoch 23/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.7027 - loss: 0.8525 - val_accuracy: 0.8148 - val_loss: 0.8002
# Epoch 24/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.7297 - loss: 0.7744 - val_accuracy: 0.7778 - val_loss: 0.7163
# Epoch 25/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.6577 - loss: 0.7365 - val_accuracy: 0.7407 - val_loss: 0.7278
# Epoch 26/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.7658 - loss: 0.6737 - val_accuracy: 0.7407 - val_loss: 0.6152
# Epoch 27/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.7477 - loss: 0.6429 - val_accuracy: 0.7037 - val_loss: 0.6487
# Epoch 28/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.7297 - loss: 0.6383 - val_accuracy: 0.7407 - val_loss: 0.5567
# Epoch 29/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.8018 - loss: 0.5370 - val_accuracy: 0.7037 - val_loss: 0.5951
# Epoch 30/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.7207 - loss: 0.6119 - val_accuracy: 0.8148 - val_loss: 0.4803
# Epoch 31/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.8288 - loss: 0.4416 - val_accuracy: 0.7778 - val_loss: 0.4540
# Epoch 32/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.7477 - loss: 0.5317 - val_accuracy: 0.6296 - val_loss: 0.7027
# Epoch 33/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.6937 - loss: 0.6427 - val_accuracy: 0.8148 - val_loss: 0.4861
# Epoch 34/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.6937 - loss: 0.6292 - val_accuracy: 0.8519 - val_loss: 0.4872
# Epoch 35/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.7207 - loss: 0.5786 - val_accuracy: 0.5556 - val_loss: 0.7442
# Epoch 36/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.6667 - loss: 0.6531 - val_accuracy: 0.7778 - val_loss: 0.5843
# Epoch 37/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.8018 - loss: 0.4968 - val_accuracy: 0.7407 - val_loss: 0.5385
# Epoch 38/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.8378 - loss: 0.4550 - val_accuracy: 0.8519 - val_loss: 0.4371
# Epoch 39/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.7748 - loss: 0.4880 - val_accuracy: 0.8148 - val_loss: 0.4097
# Epoch 40/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.8649 - loss: 0.4147 - val_accuracy: 0.8148 - val_loss: 0.4218
# Epoch 41/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.8378 - loss: 0.4195 - val_accuracy: 0.8148 - val_loss: 0.3775
# Epoch 42/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.9099 - loss: 0.3193 - val_accuracy: 0.8889 - val_loss: 0.3807
# Epoch 43/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.9189 - loss: 0.3057 - val_accuracy: 0.8519 - val_loss: 0.3395
# Epoch 44/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.9009 - loss: 0.3106 - val_accuracy: 0.8889 - val_loss: 0.3367
# Epoch 45/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.8829 - loss: 0.3274 - val_accuracy: 0.7407 - val_loss: 0.4065
# Epoch 46/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.8378 - loss: 0.3727 - val_accuracy: 0.8519 - val_loss: 0.3422
# Epoch 47/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.8198 - loss: 0.4056 - val_accuracy: 0.8519 - val_loss: 0.2525
# Epoch 48/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.8378 - loss: 0.3789 - val_accuracy: 0.7037 - val_loss: 0.5471
# Epoch 49/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.8108 - loss: 0.3506 - val_accuracy: 0.8519 - val_loss: 0.3416
# Epoch 50/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.8559 - loss: 0.3451 - val_accuracy: 0.7778 - val_loss: 0.3858
# Epoch 51/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.9369 - loss: 0.2220 - val_accuracy: 0.8889 - val_loss: 0.2936
# Epoch 52/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.9009 - loss: 0.2912 - val_accuracy: 0.8889 - val_loss: 0.3259
# Epoch 53/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.9459 - loss: 0.2156 - val_accuracy: 0.9259 - val_loss: 0.2393
# Epoch 54/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.9279 - loss: 0.2087 - val_accuracy: 0.9259 - val_loss: 0.2498
# Epoch 55/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.9189 - loss: 0.2310 - val_accuracy: 0.8889 - val_loss: 0.2620
# Epoch 56/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9189 - loss: 0.1996 - val_accuracy: 0.9259 - val_loss: 0.2045
# Epoch 57/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.9459 - loss: 0.1717 - val_accuracy: 0.8148 - val_loss: 0.3163
# Epoch 58/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.9279 - loss: 0.1774 - val_accuracy: 0.9630 - val_loss: 0.2124
# Epoch 59/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.9369 - loss: 0.1764 - val_accuracy: 0.9630 - val_loss: 0.1834
# Epoch 60/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.9369 - loss: 0.1637 - val_accuracy: 0.9259 - val_loss: 0.1959
# Epoch 61/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.9730 - loss: 0.1499 - val_accuracy: 0.9630 - val_loss: 0.1310
# Epoch 62/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.9730 - loss: 0.1300 - val_accuracy: 0.9259 - val_loss: 0.1939
# Epoch 63/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.9910 - loss: 0.1198 - val_accuracy: 1.0000 - val_loss: 0.1384
# Epoch 64/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.9730 - loss: 0.1183 - val_accuracy: 1.0000 - val_loss: 0.1399
# Epoch 65/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9820 - loss: 0.1089 - val_accuracy: 0.9630 - val_loss: 0.1594
# Epoch 66/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.9730 - loss: 0.1209 - val_accuracy: 0.8889 - val_loss: 0.1638
# Epoch 67/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.9640 - loss: 0.1130 - val_accuracy: 0.8519 - val_loss: 0.2738
# Epoch 68/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9369 - loss: 0.1229 - val_accuracy: 1.0000 - val_loss: 0.0818
# Epoch 69/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.9910 - loss: 0.0824 - val_accuracy: 1.0000 - val_loss: 0.0918
# Epoch 70/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.9820 - loss: 0.0819 - val_accuracy: 0.9259 - val_loss: 0.1168
# Epoch 71/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.9910 - loss: 0.0617 - val_accuracy: 1.0000 - val_loss: 0.1092
# Epoch 72/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.9550 - loss: 0.0991 - val_accuracy: 0.9259 - val_loss: 0.1246
# Epoch 73/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9730 - loss: 0.0708 - val_accuracy: 0.9630 - val_loss: 0.1294
# Epoch 74/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 1.0000 - loss: 0.0566 - val_accuracy: 0.9630 - val_loss: 0.1454
# Epoch 75/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.9910 - loss: 0.0529 - val_accuracy: 0.9259 - val_loss: 0.1841
# Epoch 76/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.9730 - loss: 0.0703 - val_accuracy: 1.0000 - val_loss: 0.0675
# Epoch 77/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.9820 - loss: 0.0770 - val_accuracy: 0.9630 - val_loss: 0.1567
# Epoch 78/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 0.9910 - loss: 0.0546 - val_accuracy: 0.9630 - val_loss: 0.0754
# Epoch 79/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.9820 - loss: 0.0642 - val_accuracy: 0.8889 - val_loss: 0.1705
# Epoch 80/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.9910 - loss: 0.0548 - val_accuracy: 1.0000 - val_loss: 0.0590
# Epoch 81/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.9910 - loss: 0.0454 - val_accuracy: 0.9630 - val_loss: 0.0913
# Epoch 82/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.9730 - loss: 0.0966 - val_accuracy: 0.7778 - val_loss: 0.8499
# Epoch 83/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9099 - loss: 0.1863 - val_accuracy: 0.8519 - val_loss: 0.3079
# Epoch 84/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.9099 - loss: 0.2400 - val_accuracy: 0.6296 - val_loss: 0.7499
# Epoch 85/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.8108 - loss: 0.5590 - val_accuracy: 1.0000 - val_loss: 0.1006
# Epoch 86/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.8468 - loss: 0.5184 - val_accuracy: 0.6667 - val_loss: 1.0218
# Epoch 87/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.8829 - loss: 0.2896 - val_accuracy: 0.7037 - val_loss: 0.4414
# Epoch 88/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.8739 - loss: 0.2767 - val_accuracy: 0.7407 - val_loss: 0.8257
# Epoch 89/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.8829 - loss: 0.2376 - val_accuracy: 0.8519 - val_loss: 0.2870
# Epoch 90/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.9369 - loss: 0.1653 - val_accuracy: 0.7778 - val_loss: 0.4777
# Epoch 91/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.9369 - loss: 0.1413 - val_accuracy: 0.8519 - val_loss: 0.2802
# Epoch 92/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.9550 - loss: 0.1081 - val_accuracy: 0.9630 - val_loss: 0.1558
# Epoch 93/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.9910 - loss: 0.0952 - val_accuracy: 0.8889 - val_loss: 0.3338
# Epoch 94/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.9820 - loss: 0.0663 - val_accuracy: 0.8889 - val_loss: 0.2266
# Epoch 95/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.9820 - loss: 0.0881 - val_accuracy: 0.9630 - val_loss: 0.1939
# Epoch 96/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.9730 - loss: 0.1079 - val_accuracy: 0.9259 - val_loss: 0.1860
# Epoch 97/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.9730 - loss: 0.1262 - val_accuracy: 0.9630 - val_loss: 0.1485
# Epoch 98/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.9820 - loss: 0.0631 - val_accuracy: 0.9630 - val_loss: 0.2203
# Epoch 99/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.9820 - loss: 0.0519 - val_accuracy: 1.0000 - val_loss: 0.0860
# Epoch 100/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9550 - loss: 0.0928 - val_accuracy: 0.9259 - val_loss: 0.2205

# %%
plt.plot(final_history.history['accuracy'],label='acc')
plt.plot(final_history.history['val_accuracy'],label='val_acc')
plt.plot(final_history.history['loss'],label='loss')
plt.plot(final_history.history['val_loss'],label='val_loss')
plt.legend();

# %% [markdown]
# ## Evaluation mit Validierungsdatensatz
# Eine angemessene Evaluation der Güte des Modells sollte auf dem Validierungsdatensatz passieren. Der Beispiel-Datensatz ist allerdings sehr klein! Entsprechend sind hier keine besonders robusten Resultate zu erwarten.

# %%
#images = np.asarray(list(val_ds2.map(lambda x, y: x)))
y = np.asarray(list(val_ds.unbatch().map(lambda x, y: y)))
y.shape
# Out:
# (27,)

# %%
yhat = final_model.predict(val_ds)
yhatnum = yhat.argmax(axis=1)
yhatnum
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# array([2, 0, 2, 2, 2, 2, 0, 1, 1, 2, 1, 1, 2, 1, 1, 2, 1, 2, 2, 1, 1, 2,
#        2, 2, 2, 0, 0])

# %%
#skplt.metrics.plot_confusion_matrix?

# %%
y_str = np.array(class_names)[y]
yhat_str = np.array(class_names)[yhatnum]

# %%
fig,axlist = plt.subplots(1,2,figsize=(25,10));
skplt.metrics.plot_confusion_matrix(y_str, yhat_str, normalize=True,ax=axlist[0]);axlist[0].tick_params(axis='x', rotation=45)
skplt.metrics.plot_confusion_matrix(y_str, yhat_str, normalize=False,ax=axlist[1]);axlist[1].tick_params(axis='x', rotation=45)

# %% [markdown]
# # Abspeichern des Modells als Keras-Modell

# %%
Keras_Dateiname = f'model_{Datensatzname}.keras'
voller_Keras_Dateiname = str(Path(model_output_path)/Keras_Dateiname)
final_model.save(voller_Keras_Dateiname)
print(f'Keras-Modell nach {voller_Keras_Dateiname} abgespeichert.')

# %% [markdown]
# So kann man das Modell wieder laden:
#
#     model = tf.keras.models.load_model(voller_Keras_Dateiname)
#
# (Es gibt aber verwirrend viele Formate- .h5, .keras, etc. Siehe auch [hier](https://www.tensorflow.org/tutorials/keras/save_and_load). Wir möchten uns an das .h5-Format halten.)
# Der folgende Befehl kann zur Vorhersage genutzt werden:

# %%
loaded_model = tf.keras.models.load_model(voller_Keras_Dateiname)

# %%
loaded_model.predict(val_ds)

# %% [markdown]
# Das wär's! Nach dem Speichern ("Save Version" in Kaggle) kann das Modell heruntergeladen werden. Vergessen Sie nicht, welche Bilder Trainingsbilder, und welche Testbilder sind. Ein Modell, das overfittet, wird auf den Trainingsdaten eine viel bessere Performanz zeigen, als auf den Testbildern. Nur jene der Testbilder darf rapportiert werden, denn nur so gut ist die Verallgemeinerungsleistung des neuronalen Netzes. Wir speichern daher noch eine Excel-Datei mit den entsprechenden Zuordnungen ab:

# %%
ser = pd.Series(train_or_test)
ser

# %%
ser.to_excel('train_test_split.xlsx')
ser.value_counts()

# %% [markdown]
# Weiter geht's mit dem Notebook [Giraffenpuzzle-Evaluation](https://www.kaggle.com/code/toedtlifhsg/giraffenpuzzle-evaluation). Dort wollen wir die Performanz eines Modells evaluieren.
